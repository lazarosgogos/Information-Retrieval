# %% [markdown]
# Φόρτωση του αρχείου

# %%
import importcsv

print('Importing svc file...........')
small_dataset = importcsv.opencsv('processedspeech.csv')
# Out:
# Importing svc file...........

# %% [markdown]
# Θέλουμε ανά βουλευτή και ανά κόμμα (χώρια ή μαζί;), να βρούμε τις σημαντικότερες λέξεις-κλειδιά (keywords) και πώς αυτές αλλάζουν στον χρόνο.

# %%
small_dataset[:1]
# Out:
#                     member_name sitting_date parliamentary_period  \
# 0  κρητικος νικολαου παναγιωτης   03/07/1989             period 5
#
#   parliamentary_session parliamentary_sitting                 political_party  \
# 0             session 1             sitting 1  πανελληνιο σοσιαλιστικο κινημα
#
#                                      government member_region  \
# 0  ['τζαννετακη τζαννη(02/07/1989-12/10/1989)']   β' πειραιως
#
#                                               roles member_gender  \
# 0  ['δ αντιπροεδρος βουλης(07/03/1989-21/11/1989)']          male
#
#                                               speech  \
# 0   Παρακαλείται ο κύριος Γραμματέας να συνοδεύσε...
#
#                                   processed_speeches
# 0  ΠΑΡΑΚΑΛΕΙΤΑ ΚΥΡΙ ΓΡΑΜΜΑΤΕ ΣΥΝΟΔΕΥΣ ΙΕΡ ΣΥΝΟΔ Α...

# %%
small_dataset.drop(['member_gender', 'roles', 'member_region', 'government', ], axis=1)
# Out:
#                                     member_name sitting_date  \
# 0                  κρητικος νικολαου παναγιωτης   03/07/1989
# 1                  κρητικος νικολαου παναγιωτης   04/07/1989
# 2                  κρητικος νικολαου παναγιωτης   04/07/1989
# 3                  κρητικος νικολαου παναγιωτης   04/07/1989
# 4                  κρητικος νικολαου παναγιωτης   04/07/1989
# ...                                         ...          ...
# 362625        βοριδης χρηστου μαυρουδης (μακης)   24/07/2020
# 362626        βοριδης χρηστου μαυρουδης (μακης)   24/07/2020
# 362627  κωνσταντινοπουλος κωνσταντινου οδυσσεας   24/07/2020
# 362628  κωνσταντινοπουλος κωνσταντινου οδυσσεας   24/07/2020
# 362629  κωνσταντινοπουλος κωνσταντινου οδυσσεας   24/07/2020
#
#        parliamentary_period parliamentary_session parliamentary_sitting  \
# 0                  period 5             session 1             sitting 1
# 1                  period 5             session 1             sitting 2
# 2                  period 5             session 1             sitting 2
# 3                  period 5             session 1             sitting 2
# 4                  period 5             session 1             sitting 2
# ...                     ...                   ...                   ...
# 362625   period 18 review 9             session 1           sitting 187
# 362626   period 18 review 9             session 1           sitting 187
# 362627   period 18 review 9             session 1           sitting 187
# 362628   period 18 review 9             session 1           sitting 187
# 362629   period 18 review 9             session 1           sitting 187
#
#                        political_party  \
# 0       πανελληνιο σοσιαλιστικο κινημα
# 1       πανελληνιο σοσιαλιστικο κινημα
# 2       πανελληνιο σοσιαλιστικο κινημα
# 3       πανελληνιο σοσιαλιστικο κινημα
# 4       πανελληνιο σοσιαλιστικο κινημα
# ...                                ...
# 362625                  νεα δημοκρατια
# 362626                  νεα δημοκρατια
# 362627                  κινημα αλλαγης
# 362628                  κινημα αλλαγης
# 362629                  κινημα αλλαγης
#
#                                                    speech  \
# 0        Παρακαλείται ο κύριος Γραμματέας να συνοδεύσε...
# 1        Υπάρχει κανείς εκ των κυρίων συναδέλφων, ο οπ...
# 2        Κύριοι Βουλευτές, έχω την τιμή να ανακοινώσω ...
# 3        Υπάρχει κανείς εκ των κυρίων συναδέλφων που δ...
# 4        Κύριοι συνάδελφοι, έχω την τιμή να ανακοινώσω...
# ...                                                   ...
# 362625   Όχι. Θα σας πω. Από πού έχει τεθεί αυτός ο πε...
# 362626   Ναι, «δεν υπήρχε».Εμείς είμαστε αναπτυξιακό Υ...
# 362627   Ευχαριστούμε τον Υπουργό. Κηρύσσεται περαιωμέ...
# 362628   Μετά την ολοκλήρωση της ψηφοφορίας με το ηλεκ...
# 362629   Με τη συναίνεση του Σώματος και ώρα 19.49΄ λύ...
#
#                                        processed_speeches
# 0       ΠΑΡΑΚΑΛΕΙΤΑ ΚΥΡΙ ΓΡΑΜΜΑΤΕ ΣΥΝΟΔΕΥΣ ΙΕΡ ΣΥΝΟΔ Α...
# 1       ΥΠΑΡΧ ΕΚ ΚΥΡΙ ΣΥΝΑΔΕΛΦ ΨΗΦΙΣ ΚΗΡΥΣΣΕΤΑ ΠΕΡΑΙΩΜ...
# 2       ΚΥΡΙ ΒΟΥΛΕΥΤ ΤΙΜ ΑΝΑΚΟΙΝΩΣ ΣΩΜ ΒΟΥΛΕΥΤ ΕΒΡ ΥΠΟ...
# 3       ΥΠΑΡΧ ΕΚ ΚΥΡΙ ΣΥΝΑΔΕΛΦ ΕΨΗΦΙΣ ΚΗΡΥΣΣΕΤΑ ΠΕΡΑΙΩ...
# 4       ΚΥΡΙ ΣΥΝΑΔΕΛΦ ΤΙΜ ΑΝΑΚΟΙΝΩΣ ΑΠΟΤΕΛΕΣΜ ΔΙΕΞΑΧΘΕ...
# ...                                                   ...
# 362625  Π ΤΕΘ ΠΕΡΙΟΡΙΣΜ ΠΑΜ ευρωπαϊκη ΕΝΩΣ ΖΗΤΑΜ ΛΕΜ ...
# 362626  ΥΠΗΡΧΕΕΜ ΑΝΑΠΤΥΞΙΑΚ ΥΠΟΥΡΓΕΙ ΥΠΟΥΡΓΕΙ ΚΑΝ ΚΟΙΝ...
# 362627  ΕΥΧΑΡΙΣΤΟΥΜ ΥΠΟΥΡΓ ΚΗΡΥΣΣΕΤΑ ΠΕΡΑΙΩΜΕΝ ΣΥΖΗΤΗΣ...
# 362628  ΟΛΟΚΛΗΡΩΣ ΨΗΦΟΦΟΡΙ ΗΛΕΚΤΡΟΝΙΚ ΣΥΣΤΗΜ ΣΧΕΔΙ ΝΟΜ...
# 362629  ΣΥΝΑΙΝΕΣ ΣΩΜΑΤ ΩΡ 1949΄ ΛΥΕΤΑ ΣΥΝΕΔΡΙΑΣ ΔΕΥΤΕΡ...
#
# [362630 rows x 8 columns]

# %% [markdown]
# Η λογική που θα ακολουθήσουμε είναι η Graph Of Words, για την εξαγωγή keywords. Σκανάρω κάθε ομιλία με ένα προκαθορισμένο παράθυρο και δημιουργώ συνδέσεις μεταξύ των λέξεων καθαυτών.

# %%
from collections import defaultdict # this module allows us to modify
# the default value of a key-value pair in a dictionary

window = 4 # the window of the scanner
keywords = defaultdict(list) # the value of this dict is going to be a list
speeches = small_dataset['processed_speeches']
for i, speech in enumerate(speeches):
    words = speech.split(' ')
    # print(speech)
    # break
    for j, word in enumerate(words):
        # print(word)
        for k in range(j+1, j+window):
            # what if k is Out of Bounds?
            if (k >= len(words)):
                break
            target = words[k]
            # is
            pointed_by = word # we care about the in-degree of each word
            keywords[target].append(pointed_by)
    if i == 10:
        break

print(speeches[0])
keywords
# Out:
# ΠΑΡΑΚΑΛΕΙΤΑ ΚΥΡΙ ΓΡΑΜΜΑΤΕ ΣΥΝΟΔΕΥΣ ΙΕΡ ΣΥΝΟΔ ΑΙΘΟΥΣ ΒΟΥΛ ΠΑΡΑΚΑΛΕΙΤΑ ΣΥΝΑΔΕΛΦ ΒΟΥΛΕΥΤ Κ ΣΑΔΙΚ ΑΜΕΤ ΑΝΗΚ ΜΩΑΜΕΘΑΝΙΚ ΘΡΗΣΚΕΥΜ ΠΡΟΣΕΛΘ ΔΩΣ ΟΡΙΖΟΜΕΝ ΣΥΝΤΑΓΜ ΟΡΚ ΚΟΡΑΝΙ ~ορκιζομαι ΟΝΟΜ ΠΑΝΤΟΔΥΝΑΜ ΘΕ ΠΡΟΦΗΤ ΜΩΑΜΕΘ ΠΙΣΤ ΠΑΤΡΙΔ ΔΗΜΟΚΡΑΤΙΚ ΠΟΛΙΤΕΥΜ ΥΠΑΚΟΥ ΣΥΝΤΑΓΜ ΝΟΜ ΕΚΠΛΗΡΩΝ ΕΥΣΥΝΕΙΔΗΤ ΚΑΘΗΚΟΝΤ
# defaultdict(list,
#             {'ΚΥΡΙ': ['ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΥΠΑΡΧ',
#               'ΕΚ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΠΑΡΑΚΑΛΟΥΝΤΑ',
#               'ΣΥΝΕΠΕΙ',
#               'ΒΛΑΒ',
#               'ΑΕΡΟΣΚΑΦ',
#               'ΤΣΑΛΔΑΡ',
#               'Κ',
#               'ΧΑΡΑΛΑΜΠΟΠΟΥΛ',
#               'ΤΡΟΠ',
#               'ΚΑΛΟΥΝΤΑ',
#               'ΚΑΤΑΛΟΓ',
#               'ΦΟΥΝΤ',
#               'ΠΑΣΟΚ',
#               'ΨΗΦΟΔΟΧ',
#               'ΥΠΑΡΧ',
#               'ΕΚ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΠΑΡΑΚΑΛΟΥΝΤΑ',
#               'ΑΠΟΤΕΛΕΣΜΑΤ',
#               'ΠΡΟΗΓΟΥΜΕΝ',
#               'ΔΙΑΔΙΚΑΣΙ',
#               'ΨΗΦΙΣ',
#               'ΣΥΝΟΛΙΚ',
#               '298',
#               'ΚΥΡΙ',
#               'ΣΥΜΦΕΡ',
#               'ΑΠΑΙΤ',
#               'ΑΠΑΙΤ',
#               'ΛΑ',
#               'ΛΑ',
#               'ΚΥΡΙ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΚΑΘΗΚΟΝ',
#               'ΥΠΑΡΧ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΠΑΡΑΚΑΛ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΕΦΕΤ',
#               'ΑΝΑΚΡΙΤ',
#               'ΔΙΩΞ',
#               'ΠΡΩΗΝ',
#               'ΥΠΟΥΡΓ',
#               'ΦΑΚΕΛ',
#               'ΒΟΥΛ',
#               'ΔΙΑΝΕΜΗΘ',
#               'ΠΡΑΚΤΙΚ',
#               'ΒΟΥΛ',
#               'ΠΑΡΑΚΑΛ',
#               '1989',
#               'ΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ΜΕΓΑΡ',
#               'ΒΟΥΛ',
#               'ΑΓΑΠΗΤ'],
#              'ΓΡΑΜΜΑΤΕ': ['ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΚΥΡΙ',
#               'ΤΡΙΑΡΙΔ',
#               'ΚΑΛΠ',
#               'ΚΟΣΜΗΤΟΡ',
#               'ΣΤΑΜ',
#               'ΚΑΛΠ',
#               'ΚΟΣΜΗΤΟΡ',
#               '151',
#               'ΨΗΦ',
#               'ΑΞΙΩΜ',
#               '167',
#               'ΨΗΦ',
#               'ΑΞΙΩΜ'],
#              'ΣΥΝΟΔΕΥΣ': ['ΠΑΡΑΚΑΛΕΙΤΑ', 'ΚΥΡΙ', 'ΓΡΑΜΜΑΤΕ'],
#              'ΙΕΡ': ['ΚΥΡΙ', 'ΓΡΑΜΜΑΤΕ', 'ΣΥΝΟΔΕΥΣ'],
#              'ΣΥΝΟΔ': ['ΓΡΑΜΜΑΤΕ',
#               'ΣΥΝΟΔΕΥΣ',
#               'ΙΕΡ',
#               'ΔΙΑΒΑΣ',
#               'ΔΙΑΤΑΓΜ',
#               'ΕΝΑΡΞ',
#               'ΕΡΓΑΣΙ',
#               'α`',
#               'ΤΑΚΤΙΚ',
#               'ΕΡΓΑΣΙ',
#               'α`',
#               'ΤΑΚΤΙΚ'],
#              'ΑΙΘΟΥΣ': ['ΣΥΝΟΔΕΥΣ', 'ΙΕΡ', 'ΣΥΝΟΔ'],
#              'ΒΟΥΛ': ['ΙΕΡ',
#               'ΣΥΝΟΔ',
#               'ΑΙΘΟΥΣ',
#               'ΠΡΟΟΔ',
#               'ΑΠΕΥΘΥΝΕΤΑ',
#               'ΠΡΟΕΔΡΕΙ',
#               'Ρ',
#               'Σ',
#               'ΠΡΟΕΔΡΕΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΔΗΛΩΝΟΥΜ',
#               'ΣΥΓΚΡΟΤΟΥΜ',
#               'ΕΔΑΦΙ',
#               '2',
#               'ΚΑΝΟΝΙΣΜ',
#               'ΒΟΥΛ',
#               'ΕΚΛΕΓΕΤΑ',
#               'ΠΡΟΕΔΡ',
#               'ΣΥΣΤΗΜ',
#               'ΛΕΙΤΟΥΡΓ',
#               'ΠΡΟΕΔΡ',
#               'ΚΑΛΥΤΕΡ',
#               'ΠΡΟΣΠΑΘΕΙ',
#               'ΕΠΙΤΕΛΕΣ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΠΑΡΑΚΑΛ',
#               'ΑΞΙΩΜ',
#               'δ`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΑΞΙΩΜ',
#               'ε`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΣΥΝΟΔ',
#               'ε`',
#               'ΠΕΡΙΟΔ',
#               'ΣΥΝΟΔ',
#               'ε`',
#               'ΠΕΡΙΟΔ',
#               'ΔΗΜΟΣΙΕΥΣ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΔΙΑΤΑΓΜ',
#               'ΑΡΘΡ',
#               '2',
#               'ΚΑΝΟΝΙΣΜ',
#               '153',
#               'παρ4',
#               'ΚΑΝΟΝΙΣΜ',
#               'ΒΟΥΛ',
#               'ΠΕΡΙΗΛΘ',
#               'ΠΡΟΕΔΡ',
#               'ΠΑΡΑΔΟΘ',
#               'ΣΥΓΚΛΗΣ',
#               'ΠΑΡΟΥΣ',
#               'ΒΟΥΛ',
#               'ΠΡΟΚΑΤΟΧ',
#               'ΠΡΟΕΔΡ',
#               'ΑΛΕΥΡ',
#               'ΑΝΑΔΕΙΞ',
#               'ΠΡΟΕΔΡ',
#               'ΓΕΩΡΓΙ',
#               'ΣΚΑΡΛΑΤ',
#               'ΘΕΤ',
#               'Κ',
#               'ΚΡΟΥΣΤΑΛΛΑΚ',
#               'ΘΕΤ',
#               'ΤΙΜ',
#               'ΚΑΤΑΘΕΣ',
#               'ΦΑΚΕΛ',
#               'Κ',
#               'ΔΩΡ',
#               'ΔΙΕΒΙΒΑΣ',
#               'ΑΝΔΡΕ',
#               'ΠΑΠΑΝΔΡΕ',
#               'ΠΡΑΚΤΙΚ',
#               'ΙΟΥΛΙ',
#               '1989',
#               'ΠΡΟΕΔΡ',
#               'ΑΘΑΝΑΣΙ',
#               'ΤΣΑΛΔΑΡ',
#               'ΜΕΓΑΡ',
#               'ΚΑΘΑΡΣ',
#               'ΔΙΑΣΦΑΛΙΣ',
#               'ΠΛΕΙΟΨΗΦΙ',
#               'ΣΥΝΤΑΓΜΑΤ',
#               'ΡΥΘΜΙΣ',
#               'ΚΑΝΟΝΙΣΜ',
#               'ΣΧΕΤΙΚ',
#               'ΣΥΝΕΔΡΙΑΣ',
#               'ΔΙΑΛΥΘΕΙΣ',
#               'ΕΚΠΡΟΣΩΠ',
#               'ΣΥΝΔΡΑΜΟΥΜ',
#               'ΔΥΝΑΜ',
#               'ΛΑΜΨ',
#               'ΠΡΟΣΒΛΕΠΟΥΜ',
#               'ΠΑΜΨΗΦΙ'],
#              'ΠΑΡΑΚΑΛΕΙΤΑ': ['ΣΥΝΟΔ',
#               'ΑΙΘΟΥΣ',
#               'ΒΟΥΛ',
#               'ΑΠΟΤΕΛΕΣΜΑΤ',
#               'Κ',
#               'ΣΤΑΘΟΠΟΥΛ',
#               'Κ',
#               'ΑΘΑΝΑΣΙ',
#               'ΤΣΑΛΔΑΡ'],
#              'ΣΥΝΑΔΕΛΦ': ['ΑΙΘΟΥΣ',
#               'ΒΟΥΛ',
#               'ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΥΠΑΡΧ',
#               'ΕΚ',
#               'ΚΥΡΙ',
#               'ΚΑΝΟΝΙΣΜ',
#               'ΕΚ',
#               'ΥΠΟΨΗΦΙ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΔΥΟ',
#               'ΠΛΕΙΟΨΗΦΗΣΑΝΤ',
#               'Κ',
#               'ΧΑΡΑΛΑΜΠΟΠΟΥΛ',
#               'ΚΥΡΙ',
#               'ΥΠΑΡΧ',
#               'ΕΚ',
#               'ΚΥΡΙ',
#               'ΚΥΡΙ',
#               'ΨΗΦΟΛΕΚΤ',
#               'ΕΠΟΠΤΕΥΟΝΤ',
#               'ΚΥΡΙ',
#               'ΚΥΡΙ',
#               'ΚΥΡΙ',
#               'ΛΑ',
#               'ΚΥΡΙ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΚΑΘΗΚΟΝ',
#               'ΚΥΡΙ',
#               'ΥΠΑΡΧ',
#               'ΚΥΡΙ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΠΑΡΑΚΑΛ',
#               'ΚΥΡΙ',
#               'ΚΥΡΙ',
#               'ΚΥΡΙ',
#               'ΒΟΥΛ',
#               'ΔΙΑΝΕΜΗΘ',
#               'ΚΥΡΙ',
#               'ΒΟΥΛ',
#               'ΠΑΡΑΚΑΛ',
#               'ΚΥΡΙ',
#               'ΚΥΡΙ'],
#              'ΒΟΥΛΕΥΤ': ['ΒΟΥΛ',
#               'ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΚΥΡΙ',
#               'ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΣΩΜ',
#               'ΒΛΑΒ',
#               'ΑΕΡΟΣΚΑΦ',
#               'ΚΥΡΙ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΕΨΗΦΙΣ',
#               '298',
#               'ΑΠΟΛΥΤ',
#               'ΠΛΕΙΟΨΗΦΙ',
#               'ΣΥΝΟΛ',
#               'ΠΡΟΗΓΟΥΜΕΝ',
#               'ΔΙΑΔΙΚΑΣΙ',
#               'ΚΥΡΙ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΣΩΜ',
#               'ΕΠΙΣΤΟΛ',
#               'ΠΡΟΕΔΡΕΙ',
#               'ΒΟΥΛ',
#               'ΠΑΡΑΚΑΤ',
#               'ΣΥΝΟΛΙΚ',
#               '298',
#               'ΚΥΡΙ',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΕΨΗΦΙΣ',
#               '292',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΕΨΗΦΙΣ',
#               '296',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΨΗΦΙΣ',
#               '292',
#               'ΟΡΙΣΜ',
#               'ΗΜΕΡ',
#               'ΕΚΛΟΓ',
#               'ΝΟΜΟΘΕΤΙΚ',
#               'ΕΡΓ',
#               'ΕΝΔΙΑΦΕΡΟΜΕΝ'],
#              'Κ': ['ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΒΟΥΛΕΥΤ',
#               'ΓΙΝ',
#               'ΕΞΑΓΩΓ',
#               'ΑΠΟΤΕΛΕΣΜΑΤ',
#               'ΕΒΡ',
#               'ΥΠΟΥΡΓ',
#               'ΜΑΚΕΔΟΝΙΑΣΘΡΑΚ',
#               'ΥΠΟΨΗΦΙ',
#               'ΝΕ',
#               'ΔΗΜΟΚΡΑΤΙ',
#               'ΨΗΦ',
#               'ΕΥΡΕΘΗΣ',
#               'ΕΛΑΒ',
#               'ΤΣΑΛΔΑΡ',
#               '141',
#               'ΨΗΦ',
#               'ΧΑΡΑΛΑΜΠΟΠΟΥΛ',
#               '126',
#               'ΨΗΦ',
#               'ΔΥΟ',
#               'ΠΛΕΙΟΨΗΦΗΣΑΝΤ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΣΥΝΑΔΕΛΦ',
#               'Κ',
#               'ΤΣΑΛΔΑΡ',
#               'ΨΗΦΟΛΕΚΤ',
#               'ΕΠΟΠΤΕΥΟΝΤ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦ',
#               'ΕΛΑΒ',
#               'ΤΣΑΛΔΑΡ',
#               '144',
#               'ΨΗΦ',
#               'ΒΟΥΛ',
#               'ε`',
#               'ΠΕΡΙΟΔ',
#               'ΚΑΛΠ',
#               'α`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'Κ',
#               'ΣΤΑΥΡ',
#               'β`',
#               'γ`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'Κ',
#               'ΓΕΡΟΝΤΟΠΟΥΛ',
#               'δ`',
#               'ε`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'Κ',
#               'ΚΑΠΑΧΤΣ',
#               'ΓΡΑΜΜΑΤΕ',
#               'ΚΟΜΜ',
#               'ΣΥΜΠΟΛΙΤΕΥΣ',
#               'ΣΥΜΠΟΛΙΤΕΥΣ',
#               'Κ',
#               'ΜΑΜΩΝ',
#               'ΓΡΑΜΜΑΤΕ',
#               'ΚΟΜΜ',
#               'ΑΝΤΙΠΟΛΙΤΕΥΣ',
#               'ΑΝΤΙΠΟΛΙΤΕΥΣ',
#               'Κ',
#               'ΠΑΠΑΘΑΝΑΣΙ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦ',
#               'ΕΛΑΒ',
#               'ΑΚΥΡ',
#               '4',
#               'ΠΑΡΑΚΑΛ',
#               'ΑΞΙΩΜ',
#               'β`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΑΞΙΩΜ',
#               'γ`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'δ`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ε`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ΑΞΙΩΜ',
#               'ΚΟΣΜΗΤΟΡ',
#               'ΣΥΜΠΟΛΙΤΕΥΣ',
#               'ΠΟΛΥΔΩΡ',
#               '167',
#               'ΨΗΦ',
#               'ΑΞΙΩΜ',
#               'ΚΟΣΜΗΤΟΡ',
#               'ΑΝΤΙΠΟΛΙΤΕΥΣ',
#               'ΓΡΑΜΜΑΤΕ',
#               'ΣΥΜΠΟΛΙΤΕΥΣ',
#               'ΕΛΑΒ',
#               'ΒΟΥΛΓΑΡΑΚ',
#               '165',
#               'ΨΗΦ',
#               'ΜΠΑΣΙΑΚ',
#               '167',
#               'ΨΗΦ',
#               'ΤΑΛΙΑΔΟΥΡ',
#               '167',
#               'ΨΗΦ',
#               'ΑΞΙΩΜΑΤΙΚ',
#               'ΑΝΤΙΠΟΛΙΤΕΥΣ',
#               'ΕΛΑΒ',
#               'ΘΩΜ',
#               '151',
#               'ΨΗΦ',
#               '151',
#               'ΨΗΦ',
#               'ΠΑΡΑΚΑΛΕΣ',
#               'βουλησ~',
#               'ΠΡΟΤΑΣ',
#               'ΠΡΩΘΥΠΟΥΡΓ',
#               'ΠΕΡΙΗΛΘ',
#               'ΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ΠΡΟΚΑΤΟΧ',
#               'ΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΕΦΕΤ',
#               'ΑΝΑΚΡΙΤ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΕΦΕΤ',
#               'ΑΝΑΚΡΙΤ',
#               'ΠΡΑΞΕ',
#               'ΠΡΩΗΝ',
#               'ΥΠΟΥΡΓ',
#               'ΕΙΣΑΓΓΕΛΕ',
#               'ΕΦΕΤ',
#               'ΑΘΗΝ',
#               'ΑΡΜΟΔΙΟΤΗΤ',
#               'ΚΑΤΑΓΓΕΛΙ',
#               'ΙΔΙΩΤ',
#               'ΜΑΣΤΟΡ',
#               'ΠΡΩΗΝ',
#               'ΥΠΟΥΡΓ',
#               'ΥΠΗΡΕΣΙΑΚ',
#               'ΑΝΤΙΓΡΑΦ',
#               'ΜΗΝΥΣ',
#               'ΔΗΛΩΣ',
#               'ΠΡΟΕΔΡ',
#               'ΠΑΣΟΚ'],
#              'ΣΑΔΙΚ': ['ΣΥΝΑΔΕΛΦ', 'ΒΟΥΛΕΥΤ', 'Κ'],
#              'ΑΜΕΤ': ['ΒΟΥΛΕΥΤ', 'Κ', 'ΣΑΔΙΚ'],
#              'ΑΝΗΚ': ['Κ', 'ΣΑΔΙΚ', 'ΑΜΕΤ'],
#              'ΜΩΑΜΕΘΑΝΙΚ': ['ΣΑΔΙΚ', 'ΑΜΕΤ', 'ΑΝΗΚ'],
#              'ΘΡΗΣΚΕΥΜ': ['ΑΜΕΤ', 'ΑΝΗΚ', 'ΜΩΑΜΕΘΑΝΙΚ'],
#              'ΠΡΟΣΕΛΘ': ['ΑΝΗΚ',
#               'ΜΩΑΜΕΘΑΝΙΚ',
#               'ΘΡΗΣΚΕΥΜ',
#               'ΤΣΑΛΔΑΡ',
#               'ΔΙΟΤ',
#               'ΑΔΥΝΑΤ'],
#              'ΔΩΣ': ['ΜΩΑΜΕΘΑΝΙΚ', 'ΘΡΗΣΚΕΥΜ', 'ΠΡΟΣΕΛΘ'],
#              'ΟΡΙΖΟΜΕΝ': ['ΘΡΗΣΚΕΥΜ', 'ΠΡΟΣΕΛΘ', 'ΔΩΣ'],
#              'ΣΥΝΤΑΓΜ': ['ΠΡΟΣΕΛΘ',
#               'ΔΩΣ',
#               'ΟΡΙΖΟΜΕΝ',
#               'ΔΗΜΟΚΡΑΤΙΚ',
#               'ΠΟΛΙΤΕΥΜ',
#               'ΥΠΑΚΟΥ'],
#              'ΟΡΚ': ['ΔΩΣ', 'ΟΡΙΖΟΜΕΝ', 'ΣΥΝΤΑΓΜ'],
#              'ΚΟΡΑΝΙ': ['ΟΡΙΖΟΜΕΝ', 'ΣΥΝΤΑΓΜ', 'ΟΡΚ'],
#              '~ορκιζομαι': ['ΣΥΝΤΑΓΜ', 'ΟΡΚ', 'ΚΟΡΑΝΙ'],
#              'ΟΝΟΜ': ['ΟΡΚ', 'ΚΟΡΑΝΙ', '~ορκιζομαι'],
#              'ΠΑΝΤΟΔΥΝΑΜ': ['ΚΟΡΑΝΙ', '~ορκιζομαι', 'ΟΝΟΜ'],
#              'ΘΕ': ['~ορκιζομαι', 'ΟΝΟΜ', 'ΠΑΝΤΟΔΥΝΑΜ'],
#              'ΠΡΟΦΗΤ': ['ΟΝΟΜ', 'ΠΑΝΤΟΔΥΝΑΜ', 'ΘΕ'],
#              'ΜΩΑΜΕΘ': ['ΠΑΝΤΟΔΥΝΑΜ', 'ΘΕ', 'ΠΡΟΦΗΤ'],
#              'ΠΙΣΤ': ['ΘΕ', 'ΠΡΟΦΗΤ', 'ΜΩΑΜΕΘ'],
#              'ΠΑΤΡΙΔ': ['ΠΡΟΦΗΤ', 'ΜΩΑΜΕΘ', 'ΠΙΣΤ'],
#              'ΔΗΜΟΚΡΑΤΙΚ': ['ΜΩΑΜΕΘ', 'ΠΙΣΤ', 'ΠΑΤΡΙΔ'],
#              'ΠΟΛΙΤΕΥΜ': ['ΠΙΣΤ', 'ΠΑΤΡΙΔ', 'ΔΗΜΟΚΡΑΤΙΚ'],
#              'ΥΠΑΚΟΥ': ['ΠΑΤΡΙΔ', 'ΔΗΜΟΚΡΑΤΙΚ', 'ΠΟΛΙΤΕΥΜ'],
#              'ΝΟΜ': ['ΠΟΛΙΤΕΥΜ',
#               'ΥΠΑΚΟΥ',
#               'ΣΥΝΤΑΓΜ',
#               'ΚΑΤΑΘΕΣ',
#               'ΠΡΟΤΑΣ',
#               'ΚΙΝΗΣ',
#               'ΠΛΗΡ',
#               'ΔΙΕΛΕΥΚΑΝΣ',
#               'ΚΙΝΗΣ'],
#              'ΕΚΠΛΗΡΩΝ': ['ΥΠΑΚΟΥ', 'ΣΥΝΤΑΓΜ', 'ΝΟΜ'],
#              'ΕΥΣΥΝΕΙΔΗΤ': ['ΣΥΝΤΑΓΜ', 'ΝΟΜ', 'ΕΚΠΛΗΡΩΝ'],
#              'ΚΑΘΗΚΟΝΤ': ['ΝΟΜ',
#               'ΕΚΠΛΗΡΩΝ',
#               'ΕΥΣΥΝΕΙΔΗΤ',
#               'ΕΠΙΤΕΛΕΣ',
#               'ΒΟΥΛ',
#               'ΣΥΓΚΕΚΡΙΜΕΝ',
#               'ΠΡΩΗΝ',
#               'ΥΠΟΥΡΓ',
#               'ΕΚΤΕΛΕΣ'],
#              'ΕΚ': ['ΥΠΑΡΧ',
#               'ΠΑΡ',
#               '3',
#               'ΚΑΝΟΝΙΣΜ',
#               'ΥΠΑΡΧ',
#               'ΛΕΙΤΟΥΡΓΙ',
#               'ΚΟΙΝΟΒΟΥΛΕΥΤΙΣΜ',
#               'ΟΡ'],
#              'ΨΗΦΙΣ': ['ΕΚ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΕΠΑΝΑΛΗΠΤΙΚ',
#               'ΜΥΣΤΙΚ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΗΘΕΛ',
#               'ΑΡΧΗΝ',
#               'ΕΥΧΑΡΙΣΤΗΣ',
#               'ΥΠΑΡΧ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'δ`',
#               'ε`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΑΞΙΩΜ',
#               'ΚΟΣΜΗΤΟΡ'],
#              'ΚΗΡΥΣΣΕΤΑ': ['ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΨΗΦΙΣ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΕΨΗΦΙΣ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΨΗΦΙΣ'],
#              'ΠΕΡΑΙΩΜΕΝ': ['ΣΥΝΑΔΕΛΦ',
#               'ΨΗΦΙΣ',
#               'ΚΗΡΥΣΣΕΤΑ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΕΨΗΦΙΣ',
#               'ΚΗΡΥΣΣΕΤΑ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΨΗΦΙΣ',
#               'ΚΗΡΥΣΣΕΤΑ'],
#              'ΨΗΦΟΦΟΡΙ': ['ΨΗΦΙΣ',
#               'ΚΗΡΥΣΣΕΤΑ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΑΠΟΤΕΛΕΣΜ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΣΥΝΟΛ',
#               'ΒΟΥΛΕΥΤ',
#               'ΕΠΑΝΑΛΗΦΘ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΛΕΥΚ',
#               'ΕΠΑΝΑΛΗΦΘ',
#               'ΕΨΗΦΙΣ',
#               'ΚΗΡΥΣΣΕΤΑ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΕΠΑΝΑΛΗΠΤΙΚ',
#               'ΜΥΣΤΙΚ',
#               'ΨΗΦΙΣ',
#               'ΚΗΡΥΣΣΕΤΑ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΕΔΡ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΕΔΡ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΕΔΡ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ'],
#              'ΠΑΡΑΚΑΛΟΥΝΤΑ': ['ΚΗΡΥΣΣΕΤΑ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΚΗΡΥΣΣΕΤΑ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΨΗΦΟΦΟΡΙ'],
#              'ΨΗΦΟΛΕΚΤ': ['ΨΗΦΟΦΟΡΙ',
#               'ΠΑΡΑΚΑΛΟΥΝΤΑ',
#               'ΚΥΡΙ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΠΑΡΑΚΑΛΟΥΝΤΑ',
#               'ΚΥΡΙ'],
#              'ΜΕΤΑΦΕΡ': ['ΠΑΡΑΚΑΛΟΥΝΤΑ', 'ΚΥΡΙ', 'ΨΗΦΟΛΕΚΤ'],
#              'ΨΗΦΟΔΟΧ': ['ΚΥΡΙ',
#               'ΨΗΦΟΛΕΚΤ',
#               'ΜΕΤΑΦΕΡ',
#               'ΠΑΡΑΣΚΕΥ',
#               'ΦΟΥΝΤ',
#               'ΠΑΣΟΚ',
#               'ΠΑΡΑΚΑΛ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ'],
#              'ΧΩΡ': ['ΨΗΦΟΛΕΚΤ',
#               'ΜΕΤΑΦΕΡ',
#               'ΨΗΦΟΔΟΧ',
#               'ΔΗΜΟΚΡΑΤΙ',
#               'ΥΠΑΓΟΡΕΥ',
#               'ΣΥΜΦΕΡ'],
#              'ΠΡΑΚΤΙΚΟΓΡΑΦ': ['ΜΕΤΑΦΕΡ', 'ΨΗΦΟΔΟΧ', 'ΧΩΡ'],
#              'Ν': ['ΨΗΦΟΔΟΧ', 'ΧΩΡ', 'ΠΡΑΚΤΙΚΟΓΡΑΦ'],
#              'ΑΡΧΙΣ': ['ΧΩΡ',
#               'ΠΡΑΚΤΙΚΟΓΡΑΦ',
#               'Ν',
#               'ΡΕΠΠ',
#               'ΠΑΣΟΚ',
#               'ΠΑΡΑΚΑΛ',
#               'ΚΑΘΙΣ',
#               'ΕΔΡΑΝ',
#               'ΠΡΟΕΔΡΕΙ'],
#              'ΔΙΑΛΟΓ': ['ΠΡΑΚΤΙΚΟΓΡΑΦ',
#               'Ν',
#               'ΑΡΧΙΣ',
#               'ΣΤΑΘΟΠΟΥΛ',
#               'ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΕΠΟΠΤΕΥΣ',
#               '298',
#               'ΒΟΥΛΕΥΤ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'Κ',
#               'ΣΩΤΗΡΟΠΟΥΛ',
#               'ΠΡΟΧΩΡΗΣ',
#               'ΚΥΡΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΕΔΡΑΝ',
#               'ΠΡΟΕΔΡΕΙ',
#               'ΑΡΧΙΣ',
#               '292',
#               'ΒΟΥΛΕΥΤ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               '296',
#               'ΒΟΥΛΕΥΤ',
#               'ΚΑΤΑΜΕΤΡΗΣ'],
#              'ΨΗΦΟΔΕΛΤΙ': ['Ν',
#               'ΑΡΧΙΣ',
#               'ΔΙΑΛΟΓ',
#               'ΣΩΜΑΤ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΕΥΡΕΘ',
#               '1',
#               'ΛΕΥΚ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΜΟΙΡΑΣΘ',
#               'ΔΥΟ',
#               'ΣΩΤΗΡΟΠΟΥΛ',
#               'ΠΡΟΧΩΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΕΥΡΕΘΗΣ',
#               '30',
#               'ΛΕΥΚ'],
#              'ΓΙΝ': ['ΑΡΧΙΣ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΣΤΑΘΕΡΟΤΗΤ',
#               'ΔΙΑΡΚΕΙ',
#               'ΜΠΟΡΟΥΣ',
#               'ΠΡΟΚΑΛΕΣ',
#               'ΣΥΖΗΤΗΣ',
#               'ΕΠΙΤΡΕΠΕΤΑ'],
#              'ΕΞΑΓΩΓ': ['ΔΙΑΛΟΓ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΓΙΝ',
#               'ΠΡΟΧΩΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦΟΔΕΛΤΙ'],
#              'ΑΠΟΤΕΛΕΣΜΑΤ': ['ΨΗΦΟΔΕΛΤΙ',
#               'ΓΙΝ',
#               'ΕΞΑΓΩΓ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΕΞΑΓΩΓ'],
#              'ΣΤΑΘΟΠΟΥΛ': ['ΕΞΑΓΩΓ', 'ΑΠΟΤΕΛΕΣΜΑΤ', 'Κ'],
#              'ΕΠΟΠΤΕΥΣ': ['Κ', 'ΣΤΑΘΟΠΟΥΛ', 'ΠΑΡΑΚΑΛΕΙΤΑ'],
#              'ΤΙΜ': ['ΚΥΡΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΑΕΡΟΣΚΑΦ',
#               'ΚΥΡΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΔΙΑΔΙΚΑΣΙ',
#               'ΚΥΡΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'Κ',
#               'ΓΕΩΡΓΙ',
#               'ΠΕΤΣ',
#               'ΔΗΛΩΣ',
#               'ΚΑΤΑΧΩΡΗΘ',
#               'ΠΡΑΚΤΙΚ',
#               'ΔΙΑΛΕΥΚΑΝΣ',
#               'ΘΕΜΑΤ',
#               'ΘΙΓ'],
#              'ΑΝΑΚΟΙΝΩΣ': ['ΚΥΡΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΤΙΜ',
#               'ΚΥΡΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΤΙΜ',
#               'ΚΥΡΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΤΙΜ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΤΙΜ',
#               'ΔΙΑΤΑΓΜ',
#               'ΠΡΩΘΥΠΟΥΡΓ',
#               'ΔΗΜΟΣΙΕΥΣ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΤΙΜ',
#               'ΑΡΙΘΜ',
#               '293',
#               '294/13689',
#               'ΑΠΟΔΕΙΚΤΙΚ',
#               'ΣΤΟΙΧΕΙ',
#               'ΔΥΟ',
#               'υπ`',
#               'ΑΡΙΘΜ',
#               '293',
#               'ΓΕΩΡΓΙ',
#               'ΠΕΤΣ',
#               '294'],
#              'ΣΩΜ': ['ΒΟΥΛΕΥΤ',
#               'ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΒΟΥΛΕΥΤ',
#               'ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΒΟΥΛΕΥΤ',
#               'ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΠΡΟΕΔΡ',
#               'ΠΑΡΑΚΑΛ',
#               'ΑΝΑΓΝΩΣΘ'],
#              'ΕΒΡ': ['ΑΝΑΚΟΙΝΩΣ', 'ΣΩΜ', 'ΒΟΥΛΕΥΤ'],
#              'ΥΠΟΥΡΓ': ['ΣΩΜ',
#               'ΒΟΥΛΕΥΤ',
#               'ΕΒΡ',
#               'ΠΟΙΝΙΚ',
#               'ΔΙΩΞ',
#               'ΠΡΩΗΝ',
#               'ΑΞΙΟΠΟΙΝ',
#               'ΠΡΑΞΕ',
#               'ΠΡΩΗΝ',
#               'ΓΕΩΡΓΙ',
#               'ΜΑΣΤΟΡ',
#               'ΠΡΩΗΝ',
#               'ΜΗΝΥΣ',
#               'Κ',
#               'ΛΑΓ',
#               'ΦΕΡΟΝΤΑ',
#               'ΤΕΛΕΣΘΕΙΣ',
#               'ΠΡΩΗΝ',
#               'ΚΙΝΗΣ',
#               'ΝΟΜ',
#               'ΕΥΘΥΝ',
#               'ΚΙΝΗΣ',
#               'ΝΟΜ',
#               'ΕΥΘΥΝ'],
#              'ΜΑΚΕΔΟΝΙΑΣΘΡΑΚ': ['ΒΟΥΛΕΥΤ', 'ΕΒΡ', 'ΥΠΟΥΡΓ'],
#              'ΠΑΝΑΓΙΩΤ': ['ΥΠΟΥΡΓ',
#               'ΜΑΚΕΔΟΝΙΑΣΘΡΑΚ',
#               'Κ',
#               'ΚΟΡΑΚ',
#               'ΕΥΣΤΡΑΤΙ',
#               'ΚΟΣΙΩΝ',
#               'ΡΗΓ',
#               'ΚΩΝΣΤΑΝΤΙΝ',
#               'ΣΚΟΤΙΝΙΩΤ',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'Κ'],
#              'ΧΑΤΖΗΝΙΚΟΛΑ': ['ΜΑΚΕΔΟΝΙΑΣΘΡΑΚ', 'Κ', 'ΠΑΝΑΓΙΩΤ'],
#              'ΤΗΛΕΓΡΑΦΗΜ': ['Κ', 'ΠΑΝΑΓΙΩΤ', 'ΧΑΤΖΗΝΙΚΟΛΑ'],
#              'ΔΗΛΩΝ': ['ΠΑΝΑΓΙΩΤ', 'ΧΑΤΖΗΝΙΚΟΛΑ', 'ΤΗΛΕΓΡΑΦΗΜ'],
#              'ΨΗΦΙΖ': ['ΧΑΤΖΗΝΙΚΟΛΑ', 'ΤΗΛΕΓΡΑΦΗΜ', 'ΔΗΛΩΝ'],
#              'ΥΠΟΨΗΦΙ': ['ΤΗΛΕΓΡΑΦΗΜ',
#               'ΔΗΛΩΝ',
#               'ΨΗΦΙΖ',
#               '3',
#               'ΚΑΝΟΝΙΣΜ',
#               'ΕΚ'],
#              'ΝΕ': ['ΔΗΛΩΝ',
#               'ΨΗΦΙΖ',
#               'ΥΠΟΨΗΦΙ',
#               'ΚΥΡΙ',
#               'ΙΩΑΝΝ',
#               'ΤΡΑΓΑΚ',
#               'ΚΥΡΙ',
#               'ΣΠΥΡ',
#               'ΤΑΛΙΑΔΟΥΡ'],
#              'ΔΗΜΟΚΡΑΤΙ': ['ΨΗΦΙΖ',
#               'ΥΠΟΨΗΦΙ',
#               'ΝΕ',
#               'ΙΩΑΝΝ',
#               'ΤΡΑΓΑΚ',
#               'ΝΕ',
#               'ΣΠΥΡ',
#               'ΤΑΛΙΑΔΟΥΡ',
#               'ΝΕ',
#               'ΚΟΙΝΟΒΟΥΛΙ',
#               'ΥΨΙΣΤ',
#               'ΘΕΣΜ',
#               'ΚΑΝΟΝ',
#               'ΛΕΙΤΟΥΡΓΙ',
#               'ΚΟΙΝΟΒΟΥΛΕΥΤΙΚ',
#               'ΚΥΒΕΡΝΗΣ',
#               'ΤΗΣ',
#               'ΕΛΛΗΝΙΚ',
#               'Σ',
#               'ΤΗΣ',
#               'ΕΛΛΗΝΙΚ',
#               '1989',
#               'ΠΡΟΕΔΡ',
#               'ΤΗΣ'],
#              'ΑΘΑΝΑΣΙ': ['ΝΕ',
#               'ΔΗΜΟΚΡΑΤΙ',
#               'Κ',
#               'ΕΥΡΕΘΗΣ',
#               'ΕΛΑΒ',
#               'Κ',
#               'ΚΩΣΤΟΠΟΥΛ',
#               'ΔΗΜΗΤΡΙ',
#               'ΛΕΒΕΝΤ',
#               'ΨΗΦ',
#               'ΕΛΑΒ',
#               'Κ',
#               'ε`',
#               'ΠΕΡΙΟΔ',
#               'Κ',
#               'ΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ΚΥΡΙ'],
#              'ΤΣΑΛΔΑΡ': ['ΔΗΜΟΚΡΑΤΙ',
#               'Κ',
#               'ΑΘΑΝΑΣΙ',
#               'ΕΛΑΒ',
#               'Κ',
#               'ΑΘΑΝΑΣΙ',
#               'ΠΛΕΙΟΨΗΦΗΣΑΝΤ',
#               'ΣΥΝΑΔΕΛΦ',
#               'Κ',
#               'ΕΛΑΒ',
#               'Κ',
#               'ΑΘΑΝΑΣΙ',
#               'ΠΕΡΙΟΔ',
#               'Κ',
#               'ΑΘΑΝΑΣΙ',
#               'ΒΟΥΛ',
#               'ΚΥΡΙ',
#               'ΑΘΑΝΑΣΙ'],
#              'ΔΙΟΤ': ['Κ',
#               'ΑΘΑΝΑΣΙ',
#               'ΤΣΑΛΔΑΡ',
#               'ΠΑΡΑΚΑΛ',
#               'ΔΙΑΚΟΠΤΕΤ',
#               'ΔΙΑΒΑΣ'],
#              'ΑΔΥΝΑΤ': ['ΑΘΑΝΑΣΙ', 'ΤΣΑΛΔΑΡ', 'ΔΙΟΤ'],
#              'ΜΑΤΑΙΩΣ': ['ΔΙΟΤ', 'ΑΔΥΝΑΤ', 'ΠΡΟΣΕΛΘ'],
#              'ΠΤΗΣ': ['ΑΔΥΝΑΤ', 'ΠΡΟΣΕΛΘ', 'ΜΑΤΑΙΩΣ'],
#              'ΣΥΝΕΠΕΙ': ['ΠΡΟΣΕΛΘ', 'ΜΑΤΑΙΩΣ', 'ΠΤΗΣ'],
#              'ΒΛΑΒ': ['ΜΑΤΑΙΩΣ', 'ΠΤΗΣ', 'ΣΥΝΕΠΕΙ'],
#              'ΑΕΡΟΣΚΑΦ': ['ΠΤΗΣ', 'ΣΥΝΕΠΕΙ', 'ΒΛΑΒ'],
#              'ΑΠΟΤΕΛΕΣΜ': ['ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΣΩΜ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ'],
#              'ΔΙΕΞΑΧΘΕΙΣ': ['ΑΝΑΚΟΙΝΩΣ',
#               'ΣΩΜ',
#               'ΑΠΟΤΕΛΕΣΜ',
#               'ΕΚΛΟΓ',
#               'ΠΡΟΕΔΡ',
#               'ΣΩΜΑΤ',
#               'ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΑΠΟΤΕΛΕΣΜ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΚΑΤΑΛΑΒ',
#               'ΘΕΣ',
#               'ΕΔΡ',
#               'ΚΑΤΑΛΑΒ',
#               'ΘΕΣ',
#               'ΕΔΡ',
#               'ΚΑΤΑΛΑΒ',
#               'ΘΕΣ',
#               'ΕΔΡ'],
#              'ΜΥΣΤΙΚ': ['ΣΩΜ',
#               'ΑΠΟΤΕΛΕΣΜ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΠΡΟΕΔΡ',
#               'ΣΩΜΑΤ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΑΠΟΤΕΛΕΣΜ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΕΠΑΝΑΛΗΠΤΙΚ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΘΕΣ',
#               'ΕΔΡ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΘΕΣ',
#               'ΕΔΡ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΘΕΣ',
#               'ΕΔΡ',
#               'ΔΙΕΞΑΧΘΕΙΣ'],
#              'ΕΚΛΟΓ': ['ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΤΕΚΜΗΡΙ',
#               'ΔΗΜΟΚΡΑΤΙΚΟΤΗΤ',
#               'ΝΟΜΙΜΟΤΗΤ',
#               'ΠΕΡΙΟΔ',
#               'ΟΡΙΣΜ',
#               'ΗΜΕΡ'],
#              'ΠΡΟΕΔΡ': ['ΜΥΣΤΙΚ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΕΚΛΟΓ',
#               'ΥΠΟΨΗΦΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΑΞΙΩΜ',
#               'ΑΡΙΣΤΕΡ',
#               'ΤΗΣ',
#               'προοδου~',
#               'ΚΑΝΟΝΙΣΜ',
#               'ΒΟΥΛ',
#               'ΕΚΛΕΓΕΤΑ',
#               'ΠΙΣΤΟΠΟΙ',
#               'ΣΥΣΤΗΜ',
#               'ΛΕΙΤΟΥΡΓ',
#               'ΨΗΦ',
#               'ΠΑΡΑΚΑΛΕΣ',
#               'Κ',
#               '5',
#               'ΙΟΥΛΙ',
#               '1989',
#               'ΚΑΝΟΝΙΣΜ',
#               'ΒΟΥΛ',
#               'ΠΕΡΙΗΛΘ',
#               'ΠΑΡΟΥΣ',
#               'ΒΟΥΛ',
#               'ΠΡΟΚΑΤΟΧ',
#               'Κ',
#               'ΑΛΕΥΡ',
#               'ΑΝΑΔΕΙΞ',
#               'ΓΝΩΣ',
#               'ΚΑΤΑΘΕΤ',
#               'ΔΗΛΩΣ',
#               '5',
#               'ΙΟΥΛΙ',
#               '1989',
#               'ΒΟΥΛ',
#               'ΑΓΑΠΗΤ',
#               'ΚΥΡΙ',
#               'ΑΝΔΡΕ',
#               'Γ',
#               'ΠΑΠΑΝΔΡΕ',
#               'Δ',
#               'Λ',
#               'Σ',
#               'ΑΚΥΒΕΡΝΗΣΙ',
#               'ΣΥΓΚΑΛΥΨ',
#               'ΕΥΘΥΝ'],
#              'ΣΩΜΑΤ': ['ΨΗΦΟΦΟΡΙ',
#               'ΕΚΛΟΓ',
#               'ΠΡΟΕΔΡ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΑΝΑΛΑΜΒΑΝΟΝΤ',
#               'ΠΡΟΕΔΡΙ'],
#              'ΕΨΗΦΙΣ': ['ΜΥΣΤΙΚ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΕΚ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΨΗΦΙΣ',
#               'ΗΘΕΛ',
#               'ΕΥΧΑΡΙΣΤΗΣ',
#               'ΑΞΙΩΜ',
#               'α`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'β`',
#               'γ`',
#               'ΑΝΤΙΠΡΟΕΔΡ'],
#              '298': ['ΨΗΦΟΔΕΛΤΙ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΕΨΗΦΙΣ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΨΗΦΙΣ',
#               'ΣΥΝΟΛΙΚ'],
#              'ΚΑΤΑΜΕΤΡΗΣ': ['ΕΨΗΦΙΣ',
#               '298',
#               'ΒΟΥΛΕΥΤ',
#               '298',
#               'ΚΥΡΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΕΨΗΦΙΣ',
#               '292',
#               'ΒΟΥΛΕΥΤ',
#               'ΕΨΗΦΙΣ',
#               '296',
#               'ΒΟΥΛΕΥΤ',
#               'ΨΗΦΙΣ',
#               '292',
#               'ΒΟΥΛΕΥΤ'],
#              'ΨΗΦ': ['ΒΟΥΛΕΥΤ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΑΘΑΝΑΣΙ',
#               'ΤΣΑΛΔΑΡ',
#               '141',
#               'ΓΙΑΝΝ',
#               'ΧΑΡΑΛΑΜΠΟΠΟΥΛ',
#               '126',
#               'ΜΑΡΙ',
#               'ΔΑΜΑΝΑΚ',
#               '30',
#               'ΒΟΥΛΕΥΤ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΑΘΑΝΑΣΙ',
#               'ΤΣΑΛΔΑΡ',
#               '144',
#               'ΙΩΑΝΝ',
#               'ΧΑΡΑΛΑΜΠΟΠΟΥΛ',
#               '124',
#               'ΕΚΛΟΓ',
#               'ΘΕΤΙΚ',
#               'ΑΡΝΗΤΙΚ',
#               'ΒΟΥΛΕΥΤ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΜΑΡΙ',
#               'ΔΑΜΑΝΑΚ',
#               '165',
#               'ΒΟΥΛΕΥΤ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΝΙΚΟΛΑ',
#               'ΚΑΤΣΑΡ',
#               '166',
#               'ΘΕΟΔΩΡ',
#               'ΑΝΑΓΝΩΣΤΟΠΟΥΛ',
#               '166',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΣΕΛΙΔ',
#               '0010λογη',
#               'ΠΑΝΑΓΙΩΤ',
#               'ΚΡΗΤΙΚ',
#               '155',
#               'ΓΕΩΡΓΙ',
#               'μωραϊτησ',
#               '155',
#               'ΒΥΡ',
#               'ΠΟΛΥΔΩΡ',
#               '167',
#               'ΘΕΟΔΩΡ',
#               'ΔΑΜΙΑΝ',
#               '167',
#               'ΙΩΑΝΝ',
#               'ΦΛΩΡ',
#               '151',
#               'ΓΕΩΡΓΙ',
#               'ΒΟΥΛΓΑΡΑΚ',
#               '165',
#               'ΕΥΑΓΓΕΛ',
#               'ΜΠΑΣΙΑΚ',
#               '167',
#               'ΣΠΥΡΙΔ',
#               'ΤΑΛΙΑΔΟΥΡ',
#               '167',
#               'ΚΩΝΣΤΑΝΤΙΝ',
#               'ΚΑΡΑΜΑΝΛ',
#               '167',
#               'ΜΑΡΙ',
#               'ΘΩΜ',
#               '151',
#               'ΑΝΤΩΝΙ',
#               'ΚΩΤΣΑΚ',
#               '151'],
#              'ΕΥΡΕΘΗΣ': ['ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦ',
#               'ΧΑΡΑΛΑΜΠΟΠΟΥΛ',
#               '124',
#               'ΨΗΦ'],
#              'ΕΛΑΒ': ['ΔΙΑΛΟΓ',
#               'ΨΗΦ',
#               'ΕΥΡΕΘΗΣ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦ',
#               'ΔΙΑΣΕΛΙΔ',
#               '0010λογη',
#               'ΨΗΦ',
#               'ΚΟΣΜΗΤΟΡ',
#               'ΨΗΦΙΣ',
#               '296',
#               'ΑΞΙΩΜ',
#               'ΓΡΑΜΜΑΤΕ',
#               'ΣΥΜΠΟΛΙΤΕΥΣ',
#               'ΓΡΑΜΜΑΤΕ',
#               'ΑΞΙΩΜΑΤΙΚ',
#               'ΑΝΤΙΠΟΛΙΤΕΥΣ'],
#              '141': ['Κ', 'ΑΘΑΝΑΣΙ', 'ΤΣΑΛΔΑΡ'],
#              'ΓΙΑΝΝ': ['141', 'ΨΗΦ', 'Κ', 'ΔΑΜΑΝΑΚ', 'ΜΑΡΙ', 'ΔΡΑΓΑΣΑΚ'],
#              'ΧΑΡΑΛΑΜΠΟΠΟΥΛ': ['ΨΗΦ',
#               'Κ',
#               'ΓΙΑΝΝ',
#               'Κ',
#               'ΤΣΑΛΔΑΡ',
#               'Κ',
#               'ΨΗΦ',
#               'Κ',
#               'ΙΩΑΝΝ'],
#              '126': ['Κ', 'ΓΙΑΝΝ', 'ΧΑΡΑΛΑΜΠΟΠΟΥΛ'],
#              'ΜΑΡΙ': ['126',
#               'ΨΗΦ',
#               'Κ',
#               'ΓΙΩΤ',
#               'ΕΥΣΤΑΘΙ',
#               'ΔΑΜΑΝΑΚ',
#               'ΨΗΦ',
#               'ΕΛΑΒ',
#               'Κ',
#               'ΑΝΤΙΠΟΛΙΤΕΥΣ',
#               'ΕΛΑΒ',
#               'Κ'],
#              'ΔΑΜΑΝΑΚ': ['ΨΗΦ',
#               'Κ',
#               'ΜΑΡΙ',
#               'ΓΡΗΓΟΡ',
#               'ΓΙΩΤ',
#               'ΕΥΣΤΑΘΙ',
#               'ΕΛΑΒ',
#               'Κ',
#               'ΜΑΡΙ',
#               '4',
#               'ΠΑΡΑΚΑΛ',
#               'Κ'],
#              '30': ['Κ', 'ΜΑΡΙ', 'ΔΑΜΑΝΑΚ', '124', 'ΨΗΦ', 'ΕΥΡΕΘΗΣ'],
#              'ΕΥΡΕΘ': ['ΔΑΜΑΝΑΚ', '30', 'ΨΗΦ'],
#              '1': ['30', 'ΨΗΦ', 'ΕΥΡΕΘ', 'ΑΡΘΡ', '40', 'ΠΑΡ'],
#              'ΛΕΥΚ': ['ΨΗΦ',
#               'ΕΥΡΕΘ',
#               '1',
#               'ΜΟΙΡΑΣΘ',
#               'ΔΥΟ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΨΗΦ',
#               'ΕΥΡΕΘΗΣ',
#               '30',
#               'ΔΑΜΑΝΑΚ',
#               '165',
#               'ΨΗΦ'],
#              'ΣΥΜΦΩΝ': ['1',
#               'ΛΕΥΚ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΣΧΕΤΙΚ',
#               'ΠΛΕΙΟΨΗΦΙ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΔΙΑΤΑΓΜ',
#               'ΒΟΥΛ',
#               'ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΣΩΜ',
#               'ΥΠΟΥΡΓ',
#               'ΣΥΓΚΕΚΡΙΜΕΝ',
#               'ΚΑΤΗΓΟΡΙ'],
#              'ΑΡΘΡ': ['ΛΕΥΚ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΣΥΜΦΩΝ',
#               'ΣΧΕΤΙΚ',
#               'ΠΛΕΙΟΨΗΦΙ',
#               'ΣΥΜΦΩΝ',
#               'ΕΧΟΝΤ',
#               'ΔΙΑΤΑΞ',
#               '',
#               'ΔΙΑΤΑΓΜ',
#               'ΒΟΥΛ',
#               'ΣΥΜΦΩΝ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΣΩΜ',
#               'ΣΥΜΦΩΝ',
#               'ΚΑΤΗΓΟΡΙ',
#               'ΣΥΜΦΩΝ',
#               'ΔΙΑΤΑΞ',
#               'ΑΛΛΩΣΤΕ',
#               'ΠΑΡΑΓΡΑΦ',
#               '3'],
#              '7': ['ΨΗΦΟΔΕΛΤΙ',
#               'ΣΥΜΦΩΝ',
#               'ΑΡΘΡ',
#               'ΠΛΕΙΟΨΗΦΙ',
#               'ΣΥΜΦΩΝ',
#               'ΑΡΘΡ'],
#              'ΠΑΡ': ['ΣΥΜΦΩΝ',
#               'ΑΡΘΡ',
#               '7',
#               '',
#               'ΑΡΘΡ',
#               '40',
#               'ΣΥΜΦΩΝ',
#               'ΑΡΘΡ',
#               '86'],
#              '3': ['ΑΡΘΡ', '7', 'ΠΑΡ', 'ΒΑΣ', 'ΑΛΛΩΣΤΕ', 'ΠΑΡΑΓΡΑΦ'],
#              'ΚΑΝΟΝΙΣΜ': ['7',
#               'ΠΑΡ',
#               '3',
#               'παρ3',
#               'ΕΔΑΦΙ',
#               '2',
#               'ΠΟΛΛ',
#               'ΕΞΥΨΩΣ',
#               'ΤΡΟΠΟΠΟΙΗΣ',
#               'ΣΥΜΦΩΝ',
#               'ΑΡΘΡ',
#               '2',
#               'ΣΥΝΤΑΓΜΑΤ',
#               '153',
#               'παρ4',
#               '86',
#               'ΣΥΝΤΑΓΜΑΤ',
#               'ΡΥΘΜΙΣ'],
#              'ΑΞΙΩΜ': ['ΕΚ',
#               'ΥΠΟΨΗΦΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦ',
#               'ΕΛΑΒ',
#               'ΚΑΤΣΑΡ',
#               '166',
#               'ΨΗΦ',
#               '0010λογη',
#               'ΨΗΦ',
#               'ΕΛΑΒ',
#               'ΚΡΗΤΙΚ',
#               '155',
#               'ΨΗΦ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΨΗΦΙΣ',
#               '296',
#               'ΕΛΑΒ',
#               'ΔΑΜΙΑΝ',
#               '167',
#               'ΨΗΦ',
#               'ΦΛΩΡ',
#               '151',
#               'ΨΗΦ',
#               'ΚΑΡΑΜΑΝΛ',
#               '167',
#               'ΨΗΦ'],
#              'ΣΥΓΚΕΝΤΡΩΣ': ['ΣΥΝΑΔΕΛΦ', 'ΑΞΙΩΜ', 'ΠΡΟΕΔΡ'],
#              'ΑΠΟΛΥΤ': ['ΑΞΙΩΜ', 'ΠΡΟΕΔΡ', 'ΣΥΓΚΕΝΤΡΩΣ'],
#              'ΠΛΕΙΟΨΗΦΙ': ['ΠΡΟΕΔΡ',
#               'ΣΥΓΚΕΝΤΡΩΣ',
#               'ΑΠΟΛΥΤ',
#               'ΛΕΥΚ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΣΧΕΤΙΚ',
#               'ΑΡΝΗΘ',
#               'ΚΑΘΑΡΣ',
#               'ΔΙΑΣΦΑΛΙΣ',
#               'ΔΙΚΑΣΤΗΡΙ',
#               'ΚΟΜΜΑΤΙΚ',
#               'ΣΥΜΜΑΧΙΚ'],
#              'ΣΥΝΟΛ': ['ΣΥΓΚΕΝΤΡΩΣ', 'ΑΠΟΛΥΤ', 'ΠΛΕΙΟΨΗΦΙ'],
#              'ΕΠΑΝΑΛΗΦΘ': ['ΠΛΕΙΟΨΗΦΙ',
#               'ΣΥΝΟΛ',
#               'ΒΟΥΛΕΥΤ',
#               'ΔΥΟ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΛΕΥΚ'],
#              'ΔΥΟ': ['ΒΟΥΛΕΥΤ',
#               'ΕΠΑΝΑΛΗΦΘ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΜΟΙΡΑΣΘ',
#               'ΦΩΤΟΤΥΠΙ',
#               'ΑΠΟΔΕΙΚΤΙΚ',
#               'ΣΤΟΙΧΕΙ'],
#              'ΠΛΕΙΟΨΗΦΗΣΑΝΤ': ['ΕΠΑΝΑΛΗΦΘ', 'ΨΗΦΟΦΟΡΙ', 'ΔΥΟ'],
#              'ΜΟΙΡΑΣΘ': ['ΧΑΡΑΛΑΜΠΟΠΟΥΛ', 'ΚΥΡΙ', 'ΣΥΝΑΔΕΛΦ'],
#              'ΤΡΟΠ': ['ΛΕΥΚ',
#               'ΕΠΑΝΑΛΗΦΘ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΠΟΛΙΤΙΚ',
#               'ΥΠΑΡΞ',
#               'ΕΝΕΡΓΟΥΜ',
#               'ΠΛΕΥΡ',
#               'ΔΗΛΩΝΟΥΜ',
#               'ΚΑΤΗΓΟΡΗΜΑΤΙΚ',
#               'ΕΥΘΥΝ',
#               'ΥΠΟΥΡΓ',
#               'μ`'],
#              'ΚΑΛΟΥΝΤΑ': ['ΕΠΑΝΑΛΗΦΘ', 'ΨΗΦΟΦΟΡΙ', 'ΤΡΟΠ'],
#              'ΚΑΤΑΛΟΓ': ['ΨΗΦΟΦΟΡΙ',
#               'ΤΡΟΠ',
#               'ΚΑΛΟΥΝΤΑ',
#               'ΠΑΡΑΚΑΛ',
#               'ΑΡΧΙΣ',
#               'ΑΝΑΓΝΩΣ'],
#              'ΙΩΑΝΝ': ['ΚΑΛΟΥΝΤΑ',
#               'ΚΑΤΑΛΟΓ',
#               'ΚΥΡΙ',
#               'ΚΑΠΠ',
#               'ΚΩΝΣΤΑΝΤΙΝ',
#               'ΚΑΤΣΑΡ',
#               '144',
#               'ΨΗΦ',
#               'Κ',
#               'ΚΟΣΜΗΤΟΡ',
#               'ΑΝΤΙΠΟΛΙΤΕΥΣ',
#               'Κ'],
#              'ΤΡΑΓΑΚ': ['ΚΑΤΑΛΟΓ', 'ΚΥΡΙ', 'ΙΩΑΝΝ'],
#              'ΠΑΡΑΣΚΕΥ': ['ΤΡΑΓΑΚ', 'ΝΕ', 'ΔΗΜΟΚΡΑΤΙ'],
#              'ΦΟΥΝΤ': ['ΝΕ', 'ΔΗΜΟΚΡΑΤΙ', 'ΠΑΡΑΣΚΕΥ'],
#              'ΠΑΣΟΚ': ['ΔΗΜΟΚΡΑΤΙ',
#               'ΠΑΡΑΣΚΕΥ',
#               'ΦΟΥΝΤ',
#               'ΔΗΜΟΚΡΑΤΙ',
#               'ΔΗΜΗΤΡΙ',
#               'ΡΕΠΠ',
#               'ΚΑΤΑΘΕΤ',
#               'ΔΗΛΩΣ',
#               'ΠΡΟΕΔΡ',
#               'Λ',
#               'Σ',
#               'ΠΡΟΕΔΡ'],
#              'ΣΠΥΡ': ['ΠΑΣΟΚ',
#               'ΨΗΦΟΔΟΧ',
#               'ΚΥΡΙ',
#               'ΣΠΑΘ',
#               'ΘΕΟΔΩΡ',
#               'ΣΤΡΙΦΤΑΡ'],
#              'ΤΑΛΙΑΔΟΥΡ': ['ΨΗΦΟΔΟΧ', 'ΚΥΡΙ', 'ΣΠΥΡ', 'ΨΗΦ', 'Κ', 'ΣΠΥΡΙΔ'],
#              'ΔΗΜΗΤΡΙ': ['ΤΑΛΙΑΔΟΥΡ',
#               'ΝΕ',
#               'ΔΗΜΟΚΡΑΤΙ',
#               'ΝΙΚ',
#               'ΚΑΛΟΥΔ',
#               'ΑΝΔΡΟΥΛΑΚ',
#               'ΚΟΤΑΜΑΝΙΔ',
#               'ΕΥΑΓΓΕΛΙ',
#               'ΚΩΣΤΟΠΟΥΛ'],
#              'ΡΕΠΠ': ['ΝΕ', 'ΔΗΜΟΚΡΑΤΙ', 'ΔΗΜΗΤΡΙ', 'Κ', 'ΣΤΑΥΡ', 'Κ'],
#              'ΠΑΡΑΚΑΛ': ['ΔΗΜΗΤΡΙ',
#               'ΡΕΠΠ',
#               'ΠΑΣΟΚ',
#               'ΚΑΘΗΚΟΝ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΚΗΡΥΣΣΕΤΑ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΨΗΦΟΦΟΡΙ',
#               '123',
#               'ΑΚΥΡ',
#               '4',
#               'ΑΝΑΓΝΩΣΤΟΠΟΥΛ',
#               '166',
#               'ΨΗΦ',
#               'μωραϊτησ',
#               '155',
#               'ΨΗΦ',
#               'ΠΑΠΑΝΔΡΕ',
#               'ΠΡΑΚΤΙΚ',
#               'ΒΟΥΛ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΔΙΑΒΑΣ',
#               'ΑΓΑΠΗΤ',
#               'ΚΥΡΙ',
#               'ΠΡΟΕΔΡ'],
#              'ΑΝΑΓΝΩΣ': ['ΠΑΣΟΚ', 'ΠΑΡΑΚΑΛ', 'ΑΡΧΙΣ'],
#              'ΕΠΟΠΤΕΥΟΝΤ': ['ΠΑΡΑΚΑΛΟΥΝΤΑ', 'ΚΥΡΙ', 'ΨΗΦΟΛΕΚΤ'],
#              'ΣΩΤΗΡΟΠΟΥΛ': ['ΕΠΟΠΤΕΥΟΝΤ', 'ΣΥΝΑΔΕΛΦ', 'Κ'],
#              'ΠΡΟΧΩΡΗΣ': ['ΣΥΝΑΔΕΛΦ', 'Κ', 'ΣΩΤΗΡΟΠΟΥΛ'],
#              'ΠΡΟΗΓΟΥΜΕΝ': ['ΨΗΦΟΔΕΛΤΙ', 'ΕΞΑΓΩΓ', 'ΑΠΟΤΕΛΕΣΜΑΤ'],
#              'ΔΙΑΔΙΚΑΣΙ': ['ΕΞΑΓΩΓ',
#               'ΑΠΟΤΕΛΕΣΜΑΤ',
#               'ΠΡΟΗΓΟΥΜΕΝ',
#               'ΠΟΛΙΤΙΚ',
#               'ΠΡΟΣΩΠ',
#               'ΟΓΔΟ'],
#              'ΕΠΙΣΤΟΛ': ['ΤΙΜ', 'ΑΝΑΚΟΙΝΩΣ', 'ΣΩΜ'],
#              'ΣΥΝΑΣΠΙΣΜ': ['ΣΩΜ',
#               'ΕΠΙΣΤΟΛ',
#               'ΒΟΥΛΕΥΤ',
#               'ΒΟΥΛ',
#               'ΚΟΙΝΟΒΟΥΛΕΥΤΙΚ',
#               'ΟΜΑΔ'],
#              'ΑΡΙΣΤΕΡ': ['ΕΠΙΣΤΟΛ',
#               'ΒΟΥΛΕΥΤ',
#               'ΣΥΝΑΣΠΙΣΜ',
#               'ΟΜΑΔ',
#               'ΣΥΝΑΣΠΙΣΜ',
#               'ΤΗΣ'],
#              'ΠΡΟΟΔ': ['ΒΟΥΛΕΥΤ', 'ΣΥΝΑΣΠΙΣΜ', 'ΑΡΙΣΤΕΡ'],
#              'ΑΠΕΥΘΥΝΕΤΑ': ['ΣΥΝΑΣΠΙΣΜ', 'ΑΡΙΣΤΕΡ', 'ΠΡΟΟΔ'],
#              'ΠΡΟΕΔΡΕΙ': ['ΑΡΙΣΤΕΡ',
#               'ΠΡΟΟΔ',
#               'ΑΠΕΥΘΥΝΕΤΑ',
#               'Π',
#               'Ρ',
#               'Σ',
#               'ΚΑΤΑΛΑΒ',
#               'ΠΡΟΕΔΡΙΚ',
#               'ΕΔΡ',
#               'ΠΑΡΑΚΑΛ',
#               'ΒΟΥΛ',
#               'ΕΞΟΥΣΙΟΔΟΤΗΣ',
#               'ΨΗΦΟΔΟΧ',
#               'ΚΑΘΙΣ',
#               'ΕΔΡΑΝ'],
#              'Π': ['ΑΠΕΥΘΥΝΕΤΑ',
#               'ΠΡΟΕΔΡΕΙ',
#               'ΒΟΥΛ',
#               'ε`',
#               'ΠΕΡΙΟΔ',
#               'ΒΟΥΛ',
#               'Β',
#               'ΑΡΙΘ',
#               '329/3689',
#               'ΣΑΡΤΖΕΤΑΚ',
#               'ΠΡΩΘΥΠΟΥΡΓ',
#               'ΤΖΑΝΝ'],
#              'Ρ': ['ΠΡΟΕΔΡΕΙ',
#               'ΒΟΥΛ',
#               'Π',
#               'ΠΕΡΙΟΔ',
#               'ΒΟΥΛ',
#               'Π',
#               'Ρ',
#               '',
#               'Δ',
#               'ΠΡΟΤΑΣ',
#               'ΠΡΩΘΥΠΟΥΡΓ',
#               'Κ'],
#              'Σ': ['ΒΟΥΛ',
#               'Π',
#               'Ρ',
#               '',
#               'Δ',
#               'Ρ',
#               'Κ',
#               'Ρ',
#               'Ρ',
#               'Υ',
#               'Υ',
#               'Σ',
#               'ΘΕΤ',
#               'ΒΟΥΛ',
#               'ΕΠΙΣΥΝΑΠΤΟΜΕΝ',
#               'ΚΙΝΗΜΑΤ',
#               'Δ',
#               'Λ'],
#              'ΠΑΡΑΚΑΤ': ['Σ', 'ΠΡΟΕΔΡΕΙ', 'ΒΟΥΛ'],
#              'ΔΗΛΩΝΟΥΜ': ['ΒΟΥΛ',
#               'ΠΑΡΑΚΑΤ',
#               'ΒΟΥΛΕΥΤ',
#               'ΠΛΕΙΟΨΗΦΙ',
#               'ΒΟΥΛ',
#               'ΠΛΕΥΡ',
#               'ΜΙΣΑΛΛΟΔΟΞΙ',
#               'ΡΕΒΑΝΣΙΣΜ',
#               'ΜΕΛΛΟΝ'],
#              'ΣΥΓΚΡΟΤΟΥΜ': ['ΠΑΡΑΚΑΤ', 'ΒΟΥΛΕΥΤ', 'ΔΗΛΩΝΟΥΜ'],
#              'ΚΟΙΝΟΒΟΥΛΕΥΤΙΚ': ['ΔΗΛΩΝΟΥΜ',
#               'ΣΥΓΚΡΟΤΟΥΜ',
#               'ΒΟΥΛ',
#               'ΠΛΑΙΣΙ',
#               'ΚΑΝΟΝ',
#               'ΛΕΙΤΟΥΡΓΙ',
#               'ΣΥΝΕΔΡΙΑΣ',
#               'ΔΙΑΛΥΘΕΙΣ',
#               'ΒΟΥΛ'],
#              'ΟΜΑΔ': ['ΣΥΓΚΡΟΤΟΥΜ', 'ΒΟΥΛ', 'ΚΟΙΝΟΒΟΥΛΕΥΤΙΚ'],
#              'ΤΗΣ': ['ΚΟΙΝΟΒΟΥΛΕΥΤΙΚ',
#               'ΟΜΑΔ',
#               'ΣΥΝΑΣΠΙΣΜ',
#               'ΣΥΝΑΣΠΙΣΜ',
#               'ΤΗΣ',
#               'ΑΡΙΣΤΕΡ',
#               '~εφημερις',
#               '~εφημερις',
#               'ΤΗΣ',
#               'ΚΥΒΕΡΝΗΣ',
#               'Δ',
#               'Ρ',
#               'Σ',
#               'ΙΟΥΛΙ',
#               '1989',
#               'ΠΡΟΕΔΡ'],
#              'προοδου~': ['ΤΗΣ', 'ΑΡΙΣΤΕΡ', 'ΤΗΣ'],
#              'ΧΑΡΙΛΑ': ['ΤΗΣ',
#               'προοδου~',
#               'ΠΡΟΕΔΡ',
#               'ΠΡΟΕΔΡ',
#               'ΧΑΡΙΛΑ',
#               'ΦΛΩΡΑΚ'],
#              'ΦΛΩΡΑΚ': ['προοδου~',
#               'ΠΡΟΕΔΡ',
#               'ΧΑΡΙΛΑ',
#               'ΧΑΡΙΛΑ',
#               'ΦΛΩΡΑΚ',
#               'ΧΑΡΙΛΑ'],
#              'ΛΕΩΝΙΔ': ['ΦΛΩΡΑΚ', 'ΧΑΡΙΛΑ', 'ΦΛΩΡΑΚ'],
#              'ΚΥΡΚ': ['ΧΑΡΙΛΑ', 'ΦΛΩΡΑΚ', 'ΛΕΩΝΙΔ'],
#              'ΝΙΚ': ['ΦΛΩΡΑΚ', 'ΛΕΩΝΙΔ', 'ΚΥΡΚ'],
#              'ΚΑΛΟΥΔ': ['ΛΕΩΝΙΔ', 'ΚΥΡΚ', 'ΝΙΚ'],
#              'ΑΝΔΡΟΥΛΑΚ': ['ΚΥΡΚ', 'ΝΙΚ', 'ΚΑΛΟΥΔ'],
#              'ΓΑΛΑΝ': ['ΚΑΛΟΥΔ', 'ΑΝΔΡΟΥΛΑΚ', 'ΔΗΜΗΤΡΙ'],
#              'ΝΙΚΟΛΑ': ['ΑΝΔΡΟΥΛΑΚ',
#               'ΔΗΜΗΤΡΙ',
#               'ΓΑΛΑΝ',
#               'β`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'Κ'],
#              'ΓΙΑΝΝΑΡ': ['ΔΗΜΗΤΡΙ', 'ΓΑΛΑΝ', 'ΝΙΚΟΛΑ'],
#              'ΓΡΗΓΟΡ': ['ΓΑΛΑΝ',
#               'ΝΙΚΟΛΑ',
#               'ΓΙΑΝΝΑΡ',
#               'ΣΤΡΙΦΤΑΡ',
#               'ΣΠΥΡ',
#               'ΦΑΡΑΚ'],
#              'ΓΙΩΤ': ['ΝΙΚΟΛΑ', 'ΓΙΑΝΝΑΡ', 'ΓΡΗΓΟΡ'],
#              'ΕΥΣΤΑΘΙ': ['ΓΙΑΝΝΑΡ', 'ΓΡΗΓΟΡ', 'ΓΙΩΤ'],
#              'ΔΡΑΓΑΣΑΚ': ['ΕΥΣΤΑΘΙ', 'ΔΑΜΑΝΑΚ', 'ΜΑΡΙ'],
#              'ΔΡΕΤΤΑΚ': ['ΜΑΡΙ', 'ΔΡΑΓΑΣΑΚ', 'ΓΙΑΝΝ'],
#              'ΕΜΜΑΝΟΥΗΛ': ['ΔΡΑΓΑΣΑΚ', 'ΓΙΑΝΝ', 'ΔΡΕΤΤΑΚ'],
#              'ΚΑΠΠ': ['ΓΙΑΝΝ', 'ΔΡΕΤΤΑΚ', 'ΕΜΜΑΝΟΥΗΛ'],
#              'ΚΩΝΣΤΑΝΤΙΝ': ['ΔΡΕΤΤΑΚ',
#               'ΕΜΜΑΝΟΥΗΛ',
#               'ΚΑΠΠ',
#               'ΑΘΑΝΑΣΙΟΣΣΕΛΙΔ',
#               '0007',
#               'ΡΗΓ',
#               '167',
#               'ΨΗΦ',
#               'Κ'],
#              'ΚΑΤΣΑΡ': ['ΕΜΜΑΝΟΥΗΛ',
#               'ΚΑΠΠ',
#               'ΚΩΝΣΤΑΝΤΙΝ',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'Κ',
#               'ΝΙΚΟΛΑ'],
#              'ΚΟΡΑΚ': ['ΚΩΝΣΤΑΝΤΙΝ', 'ΚΑΤΣΑΡ', 'ΙΩΑΝΝ'],
#              'ΕΥΣΤΡΑΤΙ': ['ΚΑΤΣΑΡ', 'ΙΩΑΝΝ', 'ΚΟΡΑΚ'],
#              'ΚΟΣΙΩΝ': ['ΙΩΑΝΝ', 'ΚΟΡΑΚ', 'ΕΥΣΤΡΑΤΙ'],
#              'ΚΟΤΑΜΑΝΙΔ': ['ΕΥΣΤΡΑΤΙ', 'ΚΟΣΙΩΝ', 'ΠΑΝΑΓΙΩΤ'],
#              'ΕΥΑΓΓΕΛΙ': ['ΚΟΣΙΩΝ', 'ΠΑΝΑΓΙΩΤ', 'ΚΟΤΑΜΑΝΙΔ'],
#              'ΚΩΣΤΟΠΟΥΛ': ['ΠΑΝΑΓΙΩΤ', 'ΚΟΤΑΜΑΝΙΔ', 'ΕΥΑΓΓΕΛΙ'],
#              'ΛΕΒΕΝΤ': ['ΕΥΑΓΓΕΛΙ', 'ΚΩΣΤΟΠΟΥΛ', 'ΔΗΜΗΤΡΙ'],
#              'ΛΕΝΤΑΚ': ['ΔΗΜΗΤΡΙ', 'ΛΕΒΕΝΤ', 'ΑΘΑΝΑΣΙ'],
#              'ΑΝΔΡΕ': ['ΛΕΒΕΝΤ',
#               'ΑΘΑΝΑΣΙ',
#               'ΛΕΝΤΑΚ',
#               'ΠΡΟΕΔΡ',
#               'ΠΑΣΟΚ',
#               'Κ',
#               'ΚΑΤΑΧΩΡΗΘ',
#               'ΠΡΑΚΤΙΚ',
#               'ΤΙΜ'],
#              'ΜΠΙΤΣΑΝ': ['ΑΘΑΝΑΣΙ', 'ΛΕΝΤΑΚ', 'ΑΝΔΡΕ'],
#              'ΗΛΙ': ['ΛΕΝΤΑΚ', 'ΑΝΔΡΕ', 'ΜΠΙΤΣΑΝ'],
#              'ΝΕΣΤΩΡ': ['ΑΝΔΡΕ', 'ΜΠΙΤΣΑΝ', 'ΗΛΙ'],
#              'ΣΤΥΛΙΑΝ': ['ΜΠΙΤΣΑΝ', 'ΗΛΙ', 'ΝΕΣΤΩΡ'],
#              'ΠΑΦΙΛ': ['ΗΛΙ', 'ΝΕΣΤΩΡ', 'ΣΤΥΛΙΑΝ'],
#              'ΑΘΑΝΑΣΙΟΣΣΕΛΙΔ': ['ΝΕΣΤΩΡ', 'ΣΤΥΛΙΑΝ', 'ΠΑΦΙΛ'],
#              '0007': ['ΣΤΥΛΙΑΝ', 'ΠΑΦΙΛ', 'ΑΘΑΝΑΣΙΟΣΣΕΛΙΔ'],
#              'ΡΗΓ': ['ΠΑΦΙΛ', 'ΑΘΑΝΑΣΙΟΣΣΕΛΙΔ', '0007'],
#              'ΣΚΟΤΙΝΙΩΤ': ['0007', 'ΡΗΓ', 'ΚΩΝΣΤΑΝΤΙΝ'],
#              'ΣΚΥΛΑΚ': ['ΚΩΝΣΤΑΝΤΙΝ', 'ΣΚΟΤΙΝΙΩΤ', 'ΠΑΝΑΓΙΩΤ'],
#              'ΑΝΤΩΝ': ['ΣΚΟΤΙΝΙΩΤ', 'ΠΑΝΑΓΙΩΤ', 'ΣΚΥΛΑΚ'],
#              'ΣΠΑΘ': ['ΠΑΝΑΓΙΩΤ', 'ΣΚΥΛΑΚ', 'ΑΝΤΩΝ'],
#              'ΘΕΟΔΩΡ': ['ΣΚΥΛΑΚ',
#               'ΑΝΤΩΝ',
#               'ΣΠΑΘ',
#               'γ`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'Κ',
#               '167',
#               'ΨΗΦ',
#               'Κ'],
#              'ΣΤΡΙΦΤΑΡ': ['ΑΝΤΩΝ', 'ΣΠΑΘ', 'ΘΕΟΔΩΡ'],
#              'ΦΑΡΑΚ': ['ΘΕΟΔΩΡ', 'ΣΤΡΙΦΤΑΡ', 'ΣΠΥΡ'],
#              'ΧΑΤΖΗΔΗΜΗΤΡΙ': ['ΣΠΥΡ', 'ΦΑΡΑΚ', 'ΓΡΗΓΟΡ'],
#              'τραϊανος': ['ΦΑΡΑΚ', 'ΓΡΗΓΟΡ', 'ΧΑΤΖΗΔΗΜΗΤΡΙ'],
#              'ΕΠΑΝΑΛΗΠΤΙΚ': ['ΑΝΑΚΟΙΝΩΣ', 'ΑΠΟΤΕΛΕΣΜ', 'ΔΙΕΞΑΧΘΕΙΣ'],
#              'ΣΥΝΟΛΙΚ': ['ΜΥΣΤΙΚ', 'ΨΗΦΟΦΟΡΙ', 'ΨΗΦΙΣ'],
#              '144': ['Κ', 'ΑΘΑΝΑΣΙ', 'ΤΣΑΛΔΑΡ'],
#              '124': ['Κ', 'ΙΩΑΝΝ', 'ΧΑΡΑΛΑΜΠΟΠΟΥΛ'],
#              'ΣΧΕΤΙΚ': ['30',
#               'ΛΕΥΚ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΣΤΟΙΧΕΙ',
#               'ΔΥΟ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ΠΑΡΕΔΩΣ',
#               'ΔΕΥΤΕΡ',
#               'ΤΟΝΙΣ',
#               'ΤΕΛΕΥΤΑΙ'],
#              'παρ3': ['ΣΥΜΦΩΝ', 'ΑΡΘΡ', '7'],
#              'ΕΔΑΦΙ': ['ΑΡΘΡ', '7', 'παρ3'],
#              '2': ['7',
#               'παρ3',
#               'ΕΔΑΦΙ',
#               'ΒΟΥΛ',
#               'ΣΥΜΦΩΝ',
#               'ΑΡΘΡ',
#               'ΑΡΘΡ',
#               '86',
#               'ΠΑΡ'],
#              'ΕΚΛΕΓΕΤΑ': ['2', 'ΚΑΝΟΝΙΣΜ', 'ΒΟΥΛ'],
#              'ε`': ['ΕΚΛΕΓΕΤΑ',
#               'ΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ΠΑΠΑΔΑΚ',
#               'ΚΑΛΠ',
#               'δ`',
#               'ΜΥΣΤΙΚ',
#               'ΨΗΦΟΦΟΡΙ',
#               'δ`',
#               '155',
#               'ΨΗΦ',
#               'ΑΞΙΩΜ',
#               'α`',
#               'ΤΑΚΤΙΚ',
#               'ΣΥΝΟΔ',
#               'α`',
#               'ΤΑΚΤΙΚ',
#               'ΣΥΝΟΔ'],
#              'ΠΕΡΙΟΔ': ['ΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ε`',
#               'ΚΑΘΟΜΑΣΤ',
#               'ΙΔΙΑΙΤΕΡ',
#               'ΔΙΑΝΥΟΥΜ',
#               'ΤΑΚΤΙΚ',
#               'ΣΥΝΟΔ',
#               'ε`',
#               'δ/τοσ',
#               '~ληξη',
#               'ΒΟΥΛΕΥΤΙΚ',
#               'ΤΑΚΤΙΚ',
#               'ΣΥΝΟΔ',
#               'ε`'],
#              'ΚΑΤΑΛΑΒ': ['ΑΘΑΝΑΣΙ',
#               'ΤΣΑΛΔΑΡ',
#               'ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΠΑΡΑΚΑΛ',
#               'Κ',
#               'ΔΑΜΑΝΑΚ',
#               'ΨΗΦ',
#               'ΠΑΡΑΚΑΛ',
#               'ΕΛΘ',
#               'ΨΗΦ',
#               'ΠΑΡΑΚΑΛ',
#               'ΕΛΘ'],
#              'ΠΡΟΕΔΡΙΚ': ['ΤΣΑΛΔΑΡ',
#               'ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΚΑΤΑΛΑΒ',
#               'ΙΟΥΛΙ',
#               '1989',
#               '182',
#               'ΔΙΑΚΟΠ',
#               'ΛΗΞ',
#               'ΚΑΘΟΡΙΣΤ'],
#              'ΕΔΡ': ['ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΚΑΤΑΛΑΒ',
#               'ΠΡΟΕΔΡΙΚ',
#               'ΔΑΜΑΝΑΚ',
#               'ΚΑΤΑΛΑΒ',
#               'ΘΕΣ',
#               'ΕΛΘ',
#               'ΚΑΤΑΛΑΒ',
#               'ΘΕΣ',
#               'ΕΛΘ',
#               'ΚΑΤΑΛΑΒ',
#               'ΘΕΣ'],
#              'ΕΥΧΕΤΑ': ['ΠΡΟΕΔΡΙΚ', 'ΕΔΡ', 'ΠΡΟΕΔΡΕΙ'],
#              'ΕΠΙΤΥΧΙ': ['ΕΔΡ', 'ΠΡΟΕΔΡΕΙ', 'ΕΥΧΕΤΑ'],
#              'ΕΡΓ': ['ΠΡΟΕΔΡΕΙ',
#               'ΕΥΧΕΤΑ',
#               'ΕΠΙΤΥΧΙ',
#               'ΛΕΙΤΟΥΡΓΙΚ',
#               'ΟΥΣΙΑΣΤΙΚ',
#               'ΕΞΑΛΕΙΦΘ',
#               'ΒΡΙΣΚΟΝΤΑ',
#               'ΔΙΕΥΘΥΝΣ',
#               'ΝΟΜΟΘΕΤΙΚ'],
#              'ΑΝΑΛΑΜΒΑΝΟΝΤ': ['ΚΥΡΙ', 'ΚΥΡΙ', 'ΣΥΝΑΔΕΛΦ'],
#              'ΠΡΟΕΔΡΙ': ['ΚΥΡΙ', 'ΣΥΝΑΔΕΛΦ', 'ΑΝΑΛΑΜΒΑΝΟΝΤ'],
#              'ΗΘΕΛ': ['ΑΝΑΛΑΜΒΑΝΟΝΤ',
#               'ΠΡΟΕΔΡΙ',
#               'ΣΩΜΑΤ',
#               'ΑΡΧΗΝ',
#               'ΕΥΧΑΡΙΣΤΗΣ',
#               'ΨΗΦΙΣ'],
#              'ΑΡΧΗΝ': ['ΠΡΟΕΔΡΙ', 'ΣΩΜΑΤ', 'ΗΘΕΛ'],
#              'ΕΥΧΑΡΙΣΤΗΣ': ['ΣΩΜΑΤ',
#               'ΗΘΕΛ',
#               'ΑΡΧΗΝ',
#               'ΕΥΧΑΡΙΣΤΗΣ',
#               'ΨΗΦΙΣ',
#               'ΗΘΕΛ'],
#              'ΤΕΚΜΗΡΙ': ['ΗΘΕΛ', 'ΕΥΧΑΡΙΣΤΗΣ', 'ΕΨΗΦΙΣ'],
#              'ΔΗΜΟΚΡΑΤΙΚΟΤΗΤ': ['ΕΥΧΑΡΙΣΤΗΣ', 'ΕΨΗΦΙΣ', 'ΤΕΚΜΗΡΙ'],
#              'ΝΟΜΙΜΟΤΗΤ': ['ΕΨΗΦΙΣ', 'ΤΕΚΜΗΡΙ', 'ΔΗΜΟΚΡΑΤΙΚΟΤΗΤ'],
#              'ΘΕΤΙΚ': ['ΔΗΜΟΚΡΑΤΙΚΟΤΗΤ', 'ΝΟΜΙΜΟΤΗΤ', 'ΕΚΛΟΓ'],
#              'ΑΡΝΗΤΙΚ': ['ΝΟΜΙΜΟΤΗΤ', 'ΕΚΛΟΓ', 'ΘΕΤΙΚ'],
#              'ΠΙΣΤΟΠΟΙ': ['ΘΕΤΙΚ', 'ΑΡΝΗΤΙΚ', 'ΨΗΦ'],
#              'ΣΥΣΤΗΜ': ['ΑΡΝΗΤΙΚ', 'ΨΗΦ', 'ΠΙΣΤΟΠΟΙ'],
#              'ΛΕΙΤΟΥΡΓ': ['ΨΗΦ', 'ΠΙΣΤΟΠΟΙ', 'ΣΥΣΤΗΜ'],
#              'ΠΡΟΣΩΠ': ['ΛΕΙΤΟΥΡΓ', 'ΠΡΟΕΔΡ', 'ΒΟΥΛ', 'ΘΙΓ', 'ΤΙΜ', 'ΠΟΛΙΤΙΚ'],
#              'ΥΠΕΡΚΟΜΜΑΤΙΚ': ['ΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ΠΡΟΣΩΠ',
#               'ΠΑΙΞ',
#               'ΠΛΑΙΣΙ',
#               'ΠΟΛΙΤΕΥΜΑΤ'],
#              'ΠΡΟΕΡΧΕΤΑ': ['ΒΟΥΛ', 'ΠΡΟΣΩΠ', 'ΥΠΕΡΚΟΜΜΑΤΙΚ'],
#              'ΠΑΡΑΤΑΞ': ['ΠΡΟΣΩΠ',
#               'ΥΠΕΡΚΟΜΜΑΤΙΚ',
#               'ΠΡΟΕΡΧΕΤΑ',
#               'ΣΥΜΦΕΡ',
#               'ΧΩΡ',
#               'ΣΥΜΦΕΡ'],
#              'ΡΟΛ': ['ΥΠΕΡΚΟΜΜΑΤΙΚ',
#               'ΠΡΟΕΡΧΕΤΑ',
#               'ΠΑΡΑΤΑΞ',
#               'ΑΝΤΙΚΕΙΜΕΝΙΚ',
#               'ΑΜΕΡΟΛΗΠΤ',
#               'ΑΠΑΙΤΗΣ'],
#              'ΚΑΛΕΙΤΑ': ['ΠΡΟΕΡΧΕΤΑ', 'ΠΑΡΑΤΑΞ', 'ΡΟΛ'],
#              'ΠΑΙΞ': ['ΠΑΡΑΤΑΞ', 'ΡΟΛ', 'ΚΑΛΕΙΤΑ'],
#              'ΠΛΑΙΣΙ': ['ΡΟΛ',
#               'ΚΑΛΕΙΤΑ',
#               'ΠΑΙΞ',
#               'ΤΑΣΕ',
#               'ΛΑ',
# ...
#               'ΣΥΝΑΔΕΛΦ',
#               'ΑΝΑΚΟΙΝΟΥΤΑ',
#               'ΕΙΣΑΓΓΕΛΕ'],
#              'ΑΝΑΚΡΙΤ': ['294/13689',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΕΦΕΤ',
#               '293',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΕΦΕΤ',
#               '294',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΕΦΕΤ'],
#              'Γ': ['ΕΦΕΤ',
#               'ΑΝΑΚΡΙΤ',
#               'ΚΥΡΙ',
#               'ΠΡΑΚΤΙΚ',
#               'ΤΙΜ',
#               'ΑΝΔΡΕ',
#               'ΠΡΟΕΔΡ',
#               'ΠΑΣΟΚ',
#               '',
#               'ΠΡΟΕΔΡ',
#               'πασοκ~',
#               ''],
#              'ΣΚΑΡΛΑΤ': ['ΑΝΑΚΡΙΤ', 'ΚΥΡΙ', 'Γ', 'ΑΝΑΚΡΙΤ', 'Κ', 'ΓΕΩΡΓΙ'],
#              'ΚΡΟΥΣΤΑΛΛΑΚ': ['Γ', 'ΣΚΑΡΛΑΤ', '', 'ΕΦΕΤ', 'ΑΝΑΚΡΙΤ', 'Κ'],
#              'ΣΥΝΟΔΕΥΟΜΕΝ': ['ΣΚΑΡΛΑΤ', '', 'ΚΡΟΥΣΤΑΛΛΑΚ'],
#              'ΦΩΤΟΤΥΠΙ': ['ΚΡΟΥΣΤΑΛΛΑΚ', 'ΣΥΝΟΔΕΥΟΜΕΝ', 'ΚΑΤΑΣΤΑΣ'],
#              'ΑΠΟΔΕΙΚΤΙΚ': ['ΣΥΝΟΔΕΥΟΜΕΝ',
#               'ΚΑΤΑΣΤΑΣ',
#               'ΦΩΤΟΤΥΠΙ',
#               'ΒΟΥΛ',
#               'ΕΠΙΣΥΝΑΠΤΟΜΕΝ',
#               'σ`',
#               'ΒΟΥΛ',
#               'ΕΠΙΣΥΝΑΠΤΟΜΕΝ',
#               'Σ'],
#              'ΣΤΟΙΧΕΙ': ['ΚΑΤΑΣΤΑΣ',
#               'ΦΩΤΟΤΥΠΙ',
#               'ΑΠΟΔΕΙΚΤΙΚ',
#               'ΔΥΟ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΣΧΕΤΙΚ',
#               'ΕΠΙΣΥΝΑΠΤΟΜΕΝ',
#               'σ`',
#               'ΑΠΟΔΕΙΚΤΙΚ',
#               'ΕΠΙΣΥΝΑΠΤΟΜΕΝ',
#               'Σ',
#               'ΑΠΟΔΕΙΚΤΙΚ'],
#              'ΠΑΡΑΔΟΘ': ['ΑΝΑΚΟΙΝΩΣ', 'ΣΧΕΤΙΚ', 'ΣΤΟΙΧΕΙ'],
#              'ΠΡΟΚΑΤΟΧ': ['ΣΥΓΚΛΗΣ', 'ΠΑΡΟΥΣ', 'ΒΟΥΛ'],
#              'ΑΝΑΔΕΙΞ': ['ΒΟΥΛ', 'Κ', 'ΑΛΕΥΡ'],
#              'ΠΑΡΕΔΩΣ': ['ΑΝΑΔΕΙΞ', 'ΠΡΟΕΔΡ', 'ΒΟΥΛ'],
#              'ΦΑΚΕΛ': ['ΒΟΥΛ', 'ΠΑΡΕΔΩΣ', 'ΣΧΕΤΙΚ', 'ΠΕΤΣ', 'ΤΙΜ', 'ΚΑΤΑΘΕΣ'],
#              'ΘΕΤ': ['Κ', 'ΓΕΩΡΓΙ', 'ΣΚΑΡΛΑΤ', 'ΑΝΑΚΡΙΤ', 'Κ', 'ΚΡΟΥΣΤΑΛΛΑΚ'],
#              'ΕΠΙΣΥΝΑΠΤΟΜΕΝ': ['ΣΚΑΡΛΑΤ',
#               'ΘΕΤ',
#               'ΒΟΥΛ',
#               'ΚΡΟΥΣΤΑΛΛΑΚ',
#               'ΘΕΤ',
#               'ΒΟΥΛ'],
#              'σ`': ['ΘΕΤ', 'ΒΟΥΛ', 'ΕΠΙΣΥΝΑΠΤΟΜΕΝ'],
#              'ΑΠΟΦΑΣΙΣ': ['σ`', 'ΑΠΟΔΕΙΚΤΙΚ', 'ΣΤΟΙΧΕΙ'],
#              'ΑΡΜΟΔΙΟΤΗΤ': ['ΑΠΟΔΕΙΚΤΙΚ',
#               'ΣΤΟΙΧΕΙ',
#               'ΑΠΟΦΑΣΙΣ',
#               'ΔΙΕΒΙΒΑΣ',
#               'ΒΟΥΛ',
#               'ΕΛΛΗΝ'],
#              'ΣΥΝΤΡΕΧ': ['ΣΤΟΙΧΕΙ', 'ΑΠΟΦΑΣΙΣ', 'ΑΡΜΟΔΙΟΤΗΤ'],
#              'ΠΕΡΙΠΤΩΣ': ['ΑΠΟΦΑΣΙΣ', 'ΑΡΜΟΔΙΟΤΗΤ', 'ΣΥΝΤΡΕΧ'],
#              'ΠΟΙΝΙΚ': ['ΑΡΜΟΔΙΟΤΗΤ', 'ΣΥΝΤΡΕΧ', 'ΠΕΡΙΠΤΩΣ'],
#              'ΔΙΩΞ': ['ΣΥΝΤΡΕΧ', 'ΠΕΡΙΠΤΩΣ', 'ΠΟΙΝΙΚ'],
#              'ΠΡΩΗΝ': ['ΠΕΡΙΠΤΩΣ',
#               'ΠΟΙΝΙΚ',
#               'ΔΙΩΞ',
#               'ΤΕΛΕΣ',
#               'ΑΞΙΟΠΟΙΝ',
#               'ΠΡΑΞΕ',
#               'Κ',
#               'ΓΕΩΡΓΙ',
#               'ΜΑΣΤΟΡ',
#               'ΠΡΑΞ',
#               'ΦΕΡΟΝΤΑ',
#               'ΤΕΛΕΣΘΕΙΣ'],
#              'ΑΓΑΜΕΜΝΟΝ': ['ΠΡΩΗΝ', 'ΥΠΟΥΡΓ', 'ΚΥΡΙ'],
#              'ΚΟΥΤΣΟΓΙΩΡΓ': ['ΥΠΟΥΡΓ', 'ΚΥΡΙ', 'ΑΓΑΜΕΜΝΟΝ'],
#              'ΠΕΤΣ': ['ΑΓΑΜΕΜΝΟΝ',
#               'ΚΟΥΤΣΟΓΙΩΡΓ',
#               'ΓΕΩΡΓΙ',
#               'ΥΠΟΥΡΓ',
#               'Κ',
#               'ΓΕΩΡΓΙ'],
#              '294': ['ΚΟΥΤΣΟΓΙΩΡΓ', 'ΓΕΩΡΓΙ', 'ΠΕΤΣ'],
#              'ΤΕΛΕΣ': ['Σ', 'ΑΠΟΔΕΙΚΤΙΚ', 'ΣΤΟΙΧΕΙ'],
#              'ΑΞΙΟΠΟΙΝ': ['ΑΠΟΔΕΙΚΤΙΚ',
#               'ΣΤΟΙΧΕΙ',
#               'ΤΕΛΕΣ',
#               'ΑΝΑΦΕΡΟΜΕΝ',
#               'ΠΑΡΑΠΑΝ',
#               'ΕΓΓΡΑΦ'],
#              'ΠΡΑΞΕ': ['ΣΤΟΙΧΕΙ', 'ΤΕΛΕΣ', 'ΑΞΙΟΠΟΙΝ'],
#              'ΚΑΤΑΘΕΣ': ['ΓΕΩΡΓΙ',
#               'ΠΕΤΣ',
#               'ΤΙΜ',
#               'ΔΙΟΧΕΤΕΥ',
#               'ΑΟΡΙΣΤ',
#               'ΚΑΤΗΓΟΡΙ'],
#              'ΔΙΑΝΕΜΗΘ': ['ΚΑΤΑΘΕΣ', 'ΦΑΚΕΛ', 'ΒΟΥΛ'],
#              'ΑΝΑΚΟΙΝΟΥΤΑ': ['ΔΙΑΝΕΜΗΘ', 'ΚΥΡΙ', 'ΣΥΝΑΔΕΛΦ'],
#              'ΕΙΣΑΓΓΕΛΕ': ['ΚΥΡΙ', 'ΣΥΝΑΔΕΛΦ', 'ΑΝΑΚΟΙΝΟΥΤΑ'],
#              'ΔΩΡ': ['ΕΦΕΤ', 'ΑΘΗΝ', 'Κ'],
#              'ΔΙΕΒΙΒΑΣ': ['ΑΘΗΝ', 'Κ', 'ΔΩΡ'],
#              'ΕΛΛΗΝ': ['ΔΩΡ', 'ΔΙΕΒΙΒΑΣ', 'ΒΟΥΛ'],
#              'ΚΑΤΑΓΓΕΛΙ': ['ΒΟΥΛ', 'ΕΛΛΗΝ', 'ΑΡΜΟΔΙΟΤΗΤ'],
#              'ΙΔΙΩΤ': ['ΕΛΛΗΝ', 'ΑΡΜΟΔΙΟΤΗΤ', 'ΚΑΤΑΓΓΕΛΙ'],
#              'ΜΑΣΤΟΡ': ['ΙΔΙΩΤ', 'Κ', 'ΓΕΩΡΓΙ'],
#              'ΤΣΟΒΟΛ': ['ΠΡΩΗΝ', 'ΥΠΟΥΡΓ', 'Κ'],
#              'ΥΠΗΡΕΣΙΑΚ': ['ΥΠΟΥΡΓ', 'Κ', 'ΤΣΟΒΟΛ'],
#              'ΑΝΤΙΓΡΑΦ': ['Κ', 'ΤΣΟΒΟΛ', 'ΥΠΗΡΕΣΙΑΚ'],
#              'ΜΗΝΥΣ': ['ΤΣΟΒΟΛ', 'ΥΠΗΡΕΣΙΑΚ', 'ΑΝΤΙΓΡΑΦ'],
#              'ΛΑΓ': ['ΑΝΤΙΓΡΑΦ', 'ΜΗΝΥΣ', 'Κ'],
#              'ΔΕΔΟΜΕΝ': ['Κ', 'ΛΑΓ', 'ΥΠΟΥΡΓ'],
#              'ΑΝΑΦΕΡΟΜΕΝ': ['ΛΑΓ', 'ΥΠΟΥΡΓ', 'ΔΕΔΟΜΕΝ'],
#              'ΠΑΡΑΠΑΝ': ['ΥΠΟΥΡΓ', 'ΔΕΔΟΜΕΝ', 'ΑΝΑΦΕΡΟΜΕΝ'],
#              'ΕΓΓΡΑΦ': ['ΔΕΔΟΜΕΝ',
#               'ΑΝΑΦΕΡΟΜΕΝ',
#               'ΠΑΡΑΠΑΝ',
#               'ΥΠΟΥΡΓ',
#               'ΕΚΤΕΛΕΣ',
#               'ΚΑΘΗΚΟΝΤ'],
#              'ΚΑΤΑΓΓΕΛΛΟΝΤ': ['ΠΑΡΑΠΑΝ', 'ΕΓΓΡΑΦ', 'ΑΞΙΟΠΟΙΝ'],
#              'ΠΡΑΞ': ['ΕΓΓΡΑΦ', 'ΑΞΙΟΠΟΙΝ', 'ΚΑΤΑΓΓΕΛΛΟΝΤ'],
#              'ΦΕΡΟΝΤΑ': ['ΑΞΙΟΠΟΙΝ', 'ΚΑΤΑΓΓΕΛΛΟΝΤ', 'ΠΡΑΞ'],
#              'ΤΕΛΕΣΘΕΙΣ': ['ΚΑΤΑΓΓΕΛΛΟΝΤ', 'ΠΡΑΞ', 'ΦΕΡΟΝΤΑ'],
#              'ΕΚΤΕΛΕΣ': ['ΤΕΛΕΣΘΕΙΣ', 'ΠΡΩΗΝ', 'ΥΠΟΥΡΓ'],
#              'ΒΡΙΣΚΟΝΤΑ': ['ΕΚΤΕΛΕΣ',
#               'ΚΑΘΗΚΟΝΤ',
#               'ΕΓΓΡΑΦ',
#               'ΕΠΙΦΑΝΕΙ',
#               'ΠΡΑΓΜΑΤΙΚ',
#               'ΕΝΟΧ'],
#              'ΔΙΕΥΘΥΝΣ': ['ΚΑΘΗΚΟΝΤ', 'ΕΓΓΡΑΦ', 'ΒΡΙΣΚΟΝΤΑ'],
#              'ΝΟΜΟΘΕΤΙΚ': ['ΕΓΓΡΑΦ',
#               'ΒΡΙΣΚΟΝΤΑ',
#               'ΔΙΕΥΘΥΝΣ',
#               'ΤΕΤΑΡΤ',
#               'ΚΑΘΑΡΣ',
#               'προϋποθετει'],
#              'ΕΝΔΙΑΦΕΡΟΜΕΝ': ['ΔΙΕΥΘΥΝΣ', 'ΝΟΜΟΘΕΤΙΚ', 'ΕΡΓ'],
#              'ΛΑΒ': ['ΕΡΓ',
#               'ΕΝΔΙΑΦΕΡΟΜΕΝ',
#               'ΒΟΥΛΕΥΤ',
#               'ΠΑΡΑΚΑΛ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ'],
#              'ΓΝΩΣ': ['ΕΝΔΙΑΦΕΡΟΜΕΝ',
#               'ΒΟΥΛΕΥΤ',
#               'ΛΑΒ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΛΑΒ'],
#              'ΚΑΤΑΘΕΤ': ['ΒΟΥΛΕΥΤ', 'ΛΑΒ', 'ΓΝΩΣ'],
#              'ΔΗΛΩΣ': ['ΛΑΒ',
#               'ΓΝΩΣ',
#               'ΚΑΤΑΘΕΤ',
#               'ΑΝΑΓΝΩΣΘ',
#               'ΣΩΜ',
#               'ΕΣΩΚΛΕΙΣΤ'],
#              'ΠΑΠΑΝΔΡΕ': ['ΠΑΣΟΚ',
#               'Κ',
#               'ΑΝΔΡΕ',
#               'ΤΙΜ',
#               'ΑΝΔΡΕ',
#               'Γ',
#               'ΠΑΣΟΚ',
#               '',
#               'Γ'],
#              'ΔΙΑΚΟΠΤΕΤ': ['ΣΥΝΑΔΕΛΦ', 'ΔΙΑΒΑΣ', 'ΠΑΡΑΚΑΛ'],
#              'ΠΡΟΚΑΛΕΣ': ['ΔΙΑΚΟΠΤΕΤ', 'ΔΙΑΒΑΣ', 'ΔΙΟΤ'],
#              'ΣΥΖΗΤΗΣ': ['ΔΙΑΒΑΣ',
#               'ΔΙΟΤ',
#               'ΠΡΟΚΑΛΕΣ',
#               'ΣΥΖΗΤΗΣ',
#               'ΕΠΙΤΡΕΠΕΤΑ',
#               'ΓΙΝ'],
#              'ΕΠΙΤΡΕΠΕΤΑ': ['ΔΙΟΤ', 'ΠΡΟΚΑΛΕΣ', 'ΣΥΖΗΤΗΣ'],
#              '360983135': ['ΕΠΙΤΡΕΠΕΤΑ', 'ΓΙΝ', 'ΣΥΖΗΤΗΣ'],
#              'ΜΕΓΑΡ': ['ΚΥΡΙ', 'ΑΘΑΝΑΣΙ', 'ΤΣΑΛΔΑΡ'],
#              'ΑΓΑΠΗΤ': ['ΤΣΑΛΔΑΡ', 'ΜΕΓΑΡ', 'ΒΟΥΛ'],
#              'ΑΝΑΓΝΩΣΘ': ['ΚΥΡΙ', 'ΠΡΟΕΔΡ', 'ΠΑΡΑΚΑΛ'],
#              'ΕΣΩΚΛΕΙΣΤ': ['ΠΑΡΑΚΑΛ', 'ΑΝΑΓΝΩΣΘ', 'ΣΩΜ'],
#              'ΚΑΤΑΧΩΡΗΘ': ['ΣΩΜ', 'ΕΣΩΚΛΕΙΣΤ', 'ΔΗΛΩΣ'],
#              'ΠΑΝΕΛΛΗΝΙ': ['Γ', 'ΠΑΠΑΝΔΡΕ', 'ΠΡΟΕΔΡ'],
#              'ΣΟΣΙΑΛΙΣΤΙΚ': ['ΠΑΠΑΝΔΡΕ', 'ΠΡΟΕΔΡ', 'ΠΑΝΕΛΛΗΝΙ'],
#              'ΚΙΝΗΜΑΤ': ['ΠΡΟΕΔΡ', 'ΠΑΝΕΛΛΗΝΙ', 'ΣΟΣΙΑΛΙΣΤΙΚ'],
#              'Λ': ['ΣΟΣΙΑΛΙΣΤΙΚ', 'ΚΙΝΗΜΑΤ', 'Δ'],
#              'ΑΡΝΕΙΤΑ': ['Γ', 'ΠΑΠΑΝΔΡΕ', 'ΚΥΒΕΡΝΗΣ'],
#              'ΠΡΟΣΧΗΜ': ['ΚΥΒΕΡΝΗΣ', 'ΑΡΝΕΙΤΑ', 'ΚΥΒΕΡΝΗΣ'],
#              'ΚΑΘΑΡΣ': ['ΑΡΝΕΙΤΑ',
#               'ΚΥΒΕΡΝΗΣ',
#               'ΠΡΟΣΧΗΜ',
#               'ΚΑΘΑΡΣ',
#               'ΥΠΟΧΡΕΩΜΕΝ',
#               'ΑΡΝΗΘ',
#               'ΤΙΤΛ',
#               'ΑΞΙΩΜΑΤ',
#               'ΤΡΙΤ',
#               'ΕΚΤΟΞΕΥΣ',
#               'ΚΑΤΗΓΟΡΙ',
#               'ΤΕΤΑΡΤ',
#               'ΔΙΑΦΟΡ',
#               'ΛΟΓ',
#               'ΟΛΟΚΛΗΡΩΣ',
#               'ΔΙΑΣΦΑΛΙΖ',
#               'ΕΝΟΤΗΤ',
#               'ΘΕΜ'],
#              'ΥΠΟΧΡΕΩΜΕΝ': ['ΚΥΒΕΡΝΗΣ', 'ΠΡΟΣΧΗΜ', 'ΚΑΘΑΡΣ'],
#              'ΑΡΝΗΘ': ['ΠΡΟΣΧΗΜ', 'ΚΑΘΑΡΣ', 'ΥΠΟΧΡΕΩΜΕΝ'],
#              'ΠΛΕΥΡ': ['ΔΙΑΣΦΑΛΙΣ', 'ΠΛΕΙΟΨΗΦΙ', 'ΒΟΥΛ'],
#              'ΚΑΤΗΓΟΡΗΜΑΤΙΚ': ['ΒΟΥΛ', 'ΠΛΕΥΡ', 'ΔΗΛΩΝΟΥΜ'],
#              'ΚΑΛΟΥΜ': ['ΚΑΤΗΓΟΡΗΜΑΤΙΚ', 'ΤΡΟΠ', 'ΠΡΩΤ'],
#              'ΚΟΜΜΑΤΙΚ': ['ΤΡΟΠ',
#               'ΠΡΩΤ',
#               'ΚΑΛΟΥΜ',
#               'ΑΠΟΦΑΣΕ',
#               'ΕΙΔΙΚ',
#               'ΔΙΚΑΣΤΗΡΙ',
#               'ΕΝΤΥΠΩΣ',
#               'ΛΑΣΠΟΜΑΧΙ',
#               'ΛΟΓ'],
#              'ΔΥΝΑΜ': ['ΠΡΩΤ',
#               'ΚΑΛΟΥΜ',
#               'ΚΟΜΜΑΤΙΚ',
#               'ΚΟΙΝΟΒΟΥΛΕΥΤΙΚ',
#               'ΕΚΠΡΟΣΩΠ',
#               'ΣΥΝΔΡΑΜΟΥΜ'],
#              'ΔΙΟΧΕΤΕΥ': ['ΚΑΛΟΥΜ', 'ΚΟΜΜΑΤΙΚ', 'ΔΥΝΑΜ'],
#              'ΑΟΡΙΣΤ': ['ΚΟΜΜΑΤΙΚ', 'ΔΥΝΑΜ', 'ΔΙΟΧΕΤΕΥ'],
#              'ΚΑΤΗΓΟΡΙ': ['ΔΥΝΑΜ',
#               'ΔΙΟΧΕΤΕΥ',
#               'ΑΟΡΙΣΤ',
#               'ΕΥΘΥΝ',
#               'ΥΠΟΥΡΓ',
#               'ΣΥΓΚΕΚΡΙΜΕΝ',
#               'ΠΛΕΙΟΨΗΦΙ',
#               'ΑΠΛ',
#               'ΕΚΤΟΞΕΥΣ'],
#              'ΚΙΝΗΣ': ['ΚΑΤΗΓΟΡΙ',
#               'ΚΑΤΑΘΕΣ',
#               'ΠΡΟΤΑΣ',
#               'ΒΟΥΛ',
#               'ΠΛΗΡ',
#               'ΔΙΕΛΕΥΚΑΝΣ'],
#              'ΕΥΘΥΝ': ['ΠΡΟΤΑΣ',
#               'ΚΙΝΗΣ',
#               'ΝΟΜ',
#               'ΔΙΕΛΕΥΚΑΝΣ',
#               'ΚΙΝΗΣ',
#               'ΝΟΜ',
#               'ΠΟΛΙΤΙΚ',
#               'ΚΟΣΜ',
#               'ΠΟΛΙΤΙΚ',
#               'ΥΠΕΥΘΥΝ',
#               'ΑΚΥΒΕΡΝΗΣΙ',
#               'ΣΥΓΚΑΛΥΨ'],
#              'ΡΥΘΜΙΣ': ['ΑΡΘΡ', '86', 'ΣΥΝΤΑΓΜΑΤ'],
#              'ΔΕΥΤΕΡ': ['ΡΥΘΜΙΣ', 'ΚΑΝΟΝΙΣΜ', 'ΒΟΥΛ'],
#              'ΤΟΝΙΣ': ['ΚΑΝΟΝΙΣΜ', 'ΒΟΥΛ', 'ΔΕΥΤΕΡ'],
#              'ΤΕΛΕΥΤΑΙ': ['ΒΟΥΛ', 'ΔΕΥΤΕΡ', 'ΤΟΝΙΣ'],
#              'ΔΙΑΛΥΘΕΙΣ': ['ΤΕΛΕΥΤΑΙ', 'ΣΧΕΤΙΚ', 'ΣΥΝΕΔΡΙΑΣ'],
#              'ΕΚΠΡΟΣΩΠ': ['ΔΙΑΛΥΘΕΙΣ', 'ΒΟΥΛ', 'ΚΟΙΝΟΒΟΥΛΕΥΤΙΚ'],
#              'ΣΥΝΔΡΑΜΟΥΜ': ['ΒΟΥΛ', 'ΚΟΙΝΟΒΟΥΛΕΥΤΙΚ', 'ΕΚΠΡΟΣΩΠ'],
#              'ΠΛΗΡ': ['ΣΥΝΔΡΑΜΟΥΜ',
#               'ΔΥΝΑΜ',
#               'ΒΟΥΛ',
#               'ΠΡΟΣΒΛΕΠΟΥΜ',
#               'ΠΑΜΨΗΦΙ',
#               'ΒΟΥΛ'],
#              'ΔΙΕΛΕΥΚΑΝΣ': ['ΔΥΝΑΜ', 'ΒΟΥΛ', 'ΠΛΗΡ'],
#              'μ`': ['ΝΟΜ', 'ΕΥΘΥΝ', 'ΥΠΟΥΡΓ'],
#              'ΕΠΙΦΑΝΕΙ': ['ΤΡΟΠ', 'ΑΛΛΩΣΤΕ', 'ΕΛΘ'],
#              'ΕΝΟΧ': ['ΕΛΘ', 'ΕΠΙΦΑΝΕΙ', 'ΠΡΑΓΜΑΤΙΚ'],
#              'ΑΝΕΞΑΡΤΗΤ': ['ΠΡΑΓΜΑΤΙΚ', 'ΕΝΟΧ', 'ΒΡΙΣΚΟΝΤΑ'],
#              'ΤΙΤΛ': ['ΕΝΟΧ', 'ΒΡΙΣΚΟΝΤΑ', 'ΑΝΕΞΑΡΤΗΤ'],
#              'ΑΞΙΩΜΑΤ': ['ΒΡΙΣΚΟΝΤΑ', 'ΑΝΕΞΑΡΤΗΤ', 'ΤΙΤΛ'],
#              'ΤΡΙΤ': ['ΑΝΕΞΑΡΤΗΤ', 'ΤΙΤΛ', 'ΑΞΙΩΜΑΤ'],
#              'ΒΕΒΑΙ': ['ΑΞΙΩΜΑΤ', 'ΤΡΙΤ', 'ΚΑΘΑΡΣ'],
#              'προϋποθετει': ['ΤΡΙΤ',
#               'ΚΑΘΑΡΣ',
#               'ΒΕΒΑΙ',
#               'ΚΑΤΗΓΟΡΙ',
#               'ΤΕΤΑΡΤ',
#               'ΚΑΘΑΡΣ'],
#              'ΕΚΔΟΣ': ['ΚΑΘΑΡΣ', 'ΒΕΒΑΙ', 'προϋποθετει'],
#              'ΑΠΟΦΑΣΕ': ['ΒΕΒΑΙ', 'προϋποθετει', 'ΕΚΔΟΣ'],
#              'ΕΙΔΙΚ': ['προϋποθετει', 'ΕΚΔΟΣ', 'ΑΠΟΦΑΣΕ'],
#              'ΔΙΚΑΣΤΗΡΙ': ['ΕΚΔΟΣ', 'ΑΠΟΦΑΣΕ', 'ΕΙΔΙΚ'],
#              'ΣΥΜΜΑΧΙΚ': ['ΕΙΔΙΚ', 'ΔΙΚΑΣΤΗΡΙ', 'ΚΟΜΜΑΤΙΚ'],
#              'ΑΠΛ': ['ΚΟΜΜΑΤΙΚ',
#               'ΣΥΜΜΑΧΙΚ',
#               'ΠΛΕΙΟΨΗΦΙ',
#               'ΛΟΓ',
#               'ΟΛΟΚΛΗΡΩΣ',
#               'ΚΑΘΑΡΣ'],
#              'ΕΚΤΟΞΕΥΣ': ['ΣΥΜΜΑΧΙΚ', 'ΠΛΕΙΟΨΗΦΙ', 'ΑΠΛ'],
#              'ΤΕΤΑΡΤ': ['ΑΠΛ', 'ΕΚΤΟΞΕΥΣ', 'ΚΑΤΗΓΟΡΙ'],
#              'ΚΑΤΟΧΥΡΩΣ': ['ΚΑΘΑΡΣ', 'προϋποθετει', 'ΝΟΜΟΘΕΤΙΚ'],
#              'ΕΝΙΣΧΥΣ': ['προϋποθετει', 'ΝΟΜΟΘΕΤΙΚ', 'ΚΑΤΟΧΥΡΩΣ'],
#              'ΚΟΙΝΩΝΙΚ': ['ΚΑΤΟΧΥΡΩΣ', 'ΕΝΙΣΧΥΣ', 'ΘΕΣΜ'],
#              'ΕΛΕΓΧ': ['ΕΝΙΣΧΥΣ',
#               'ΘΕΣΜ',
#               'ΚΟΙΝΩΝΙΚ',
#               'ΕΞΕΤΑΣΤΙΚ',
#               'ΠΡΑΓΜΑΤ',
#               'ΕΠΙΤΡΟΠ',
#               'ΠΡΩΤΟΒΟΥΛΙ',
#               'ΑΥΣΤΗΡ',
#               'ΑΜΕΣ'],
#              'ΔΙΑΦΑΝΕΙ': ['ΘΕΣΜ',
#               'ΚΟΙΝΩΝΙΚ',
#               'ΕΛΕΓΧ',
#               'ΚΟΣΜ',
#               'ΠΟΛΙΤΙΚ',
#               'ΕΥΘΥΝ'],
#              'ΠΕΜΠΤ': ['ΚΟΙΝΩΝΙΚ', 'ΕΛΕΓΧ', 'ΔΙΑΦΑΝΕΙ'],
#              'ΠΑΡΟΥΜ': ['ΕΛΕΓΧ',
#               'ΔΙΑΦΑΝΕΙ',
#               'ΠΕΜΠΤ',
#               'ΑΠΟΔΕΙΞ',
#               'ΑΘΩΟΤΗΤ',
#               'ΕΒΔΟΜ'],
#              'ΠΡΩΤΟΒΟΥΛΙ': ['ΔΙΑΦΑΝΕΙ',
#               'ΠΕΜΠΤ',
#               'ΠΑΡΟΥΜ',
#               'ΑΘΩΟΤΗΤ',
#               'ΕΒΔΟΜ',
#               'ΠΑΡΟΥΜ'],
#              'ΣΥΝΤΕΛΕΣΘ': ['ΠΕΜΠΤ', 'ΠΑΡΟΥΜ', 'ΠΡΩΤΟΒΟΥΛΙ'],
#              'ΠΑΡΑΓΡΑΦ': ['ΠΑΡΟΥΜ',
#               'ΠΡΩΤΟΒΟΥΛΙ',
#               'ΣΥΝΤΕΛΕΣΘ',
#               'ΕΠΙΧΕΙΡΗΜ',
#               'ΑΔΙΚΗΜΑΤ',
#               '1974',
#               'ΔΙΑΦΑΝΕΙ',
#               'ΒΑΣ',
#               'ΑΛΛΩΣΤΕ'],
#              'κι`': ['ΠΡΩΤΟΒΟΥΛΙ', 'ΣΥΝΤΕΛΕΣΘ', 'ΠΑΡΑΓΡΑΦ'],
#              'ΔΕΙΓΜΑΤ': ['ΠΑΡΑΓΡΑΦ', 'κι`', 'ΓΙΑΤΙ'],
#              'ΓΡΑΦ': ['κι`', 'ΓΙΑΤΙ', 'ΔΕΙΓΜΑΤ'],
#              'ΔΙΚΟΜΜΑΤΙΚ': ['ΓΙΑΤΙ', 'ΔΕΙΓΜΑΤ', 'ΓΡΑΦ'],
#              'ΔΙΕΥΘΥΝΤΗΡΙ': ['ΔΕΙΓΜΑΤ', 'ΓΡΑΦ', 'ΔΙΚΟΜΜΑΤΙΚ'],
#              'ΣΥΓΚΥΒΕΡΝΗΣ': ['ΓΡΑΦ', 'ΔΙΚΟΜΜΑΤΙΚ', 'ΔΙΕΥΘΥΝΤΗΡΙ'],
#              'ΟΔΗΓ': ['ΔΙΚΟΜΜΑΤΙΚ', 'ΔΙΕΥΘΥΝΤΗΡΙ', 'ΣΥΓΚΥΒΕΡΝΗΣ'],
#              'ΣΥΜΠΕΡΑΣΜ': ['ΔΙΕΥΘΥΝΤΗΡΙ', 'ΣΥΓΚΥΒΕΡΝΗΣ', 'ΟΔΗΓ'],
#              'ΕΝΝΟ': ['ΣΥΓΚΥΒΕΡΝΗΣ', 'ΟΔΗΓ', 'ΣΥΜΠΕΡΑΣΜ'],
#              'ΔΙΑΦΟΡ': ['ΟΔΗΓ', 'ΣΥΜΠΕΡΑΣΜ', 'ΕΝΝΟ'],
#              'ΛΟΓ': ['ΣΥΜΠΕΡΑΣΜ',
#               'ΕΝΝΟ',
#               'ΔΙΑΦΟΡ',
#               'ΕΠΙΔΙΩΚ',
#               'ΕΝΤΥΠΩΣ',
#               'ΛΑΣΠΟΜΑΧΙ'],
#              'ΟΛΟΚΛΗΡΩΣ': ['ΕΝΝΟ', 'ΔΙΑΦΟΡ', 'ΛΟΓ'],
#              'ΕΠΙΔΙΩΚ': ['ΟΛΟΚΛΗΡΩΣ', 'ΚΑΘΑΡΣ', 'ΑΠΛ'],
#              'ΕΝΤΥΠΩΣ': ['ΚΑΘΑΡΣ', 'ΑΠΛ', 'ΕΠΙΔΙΩΚ'],
#              'ΛΑΣΠΟΜΑΧΙ': ['ΑΠΛ', 'ΕΠΙΔΙΩΚ', 'ΕΝΤΥΠΩΣ'],
#              'ΣΥΜΦΕΡΟΝΤΩΝΣΕΛΙΔ': ['ΛΑΣΠΟΜΑΧΙ', 'ΛΟΓ', 'ΚΟΜΜΑΤΙΚ'],
#              '0011': ['ΛΟΓ', 'ΚΟΜΜΑΤΙΚ', 'ΣΥΜΦΕΡΟΝΤΩΝΣΕΛΙΔ'],
#              'ΕΚΤ': ['ΚΟΜΜΑΤΙΚ', 'ΣΥΜΦΕΡΟΝΤΩΝΣΕΛΙΔ', '0011'],
#              'ΕΠΑΝΑΚΑΤΑΘΕΤΟΥΜ': ['ΣΥΜΦΕΡΟΝΤΩΝΣΕΛΙΔ', '0011', 'ΕΚΤ'],
#              'ΣΥΓΚΡΟΤΗΣ': ['ΕΚΤ', 'ΕΠΑΝΑΚΑΤΑΘΕΤΟΥΜ', 'ΠΡΟΤΑΣ'],
#              'ΕΞΕΤΑΣΤΙΚ': ['ΕΠΑΝΑΚΑΤΑΘΕΤΟΥΜ', 'ΠΡΟΤΑΣ', 'ΣΥΓΚΡΟΤΗΣ'],
#              'ΠΡΑΓΜΑΤ': ['ΠΡΟΤΑΣ', 'ΣΥΓΚΡΟΤΗΣ', 'ΕΞΕΤΑΣΤΙΚ'],
#              'ΕΠΙΤΡΟΠ': ['ΣΥΓΚΡΟΤΗΣ', 'ΕΞΕΤΑΣΤΙΚ', 'ΠΡΑΓΜΑΤ'],
#              'ΠΡΟΜΗΘΕΙ': ['ΠΡΑΓΜΑΤ', 'ΕΠΙΤΡΟΠ', 'ΕΛΕΓΧ'],
#              'ΕΝΟΠΛ': ['ΕΠΙΤΡΟΠ', 'ΕΛΕΓΧ', 'ΠΡΟΜΗΘΕΙ'],
#              'ΔΥΝΑΜΕ': ['ΕΛΕΓΧ', 'ΠΡΟΜΗΘΕΙ', 'ΕΝΟΠΛ'],
#              '1974': ['ΠΡΟΜΗΘΕΙ',
#               'ΕΝΟΠΛ',
#               'ΔΥΝΑΜΕ',
#               '1974',
#               'ΕΠΙΧΕΙΡΗΜ',
#               'ΑΔΙΚΗΜΑΤ'],
#              'ΕΠΙΧΕΙΡΗΜ': ['ΕΝΟΠΛ', 'ΔΥΝΑΜΕ', '1974'],
#              'ΑΔΙΚΗΜΑΤ': ['ΔΥΝΑΜΕ', '1974', 'ΕΠΙΧΕΙΡΗΜ'],
#              'ΕΝΔΙΑΦΕΡ': ['ΠΑΡΑΓΡΑΦ', 'ΣΗΜΑΣΙ', 'ΓΙΑΤΙ'],
#              'ΚΟΣΜ': ['ΕΝΔΙΑΦΕΡ', 'ΛΑ', 'ΠΟΛΙΤΙΚ'],
#              'ΒΑΣ': ['ΠΟΛΙΤΙΚ', 'ΕΥΘΥΝ', 'ΔΙΑΦΑΝΕΙ'],
#              'ΘΙΓΟΜΕΝ': ['ΑΡΘΡ', '86', 'ΣΥΝΤΑΓΜΑΤ'],
#              'ΖΗΤΗΣ': ['ΣΥΝΤΑΓΜΑΤ', 'ΘΙΓΟΜΕΝ', 'ΠΟΛΙΤΙΚ'],
#              'ΠΑΡΑΠΟΜΠ': ['ΘΙΓΟΜΕΝ', 'ΠΟΛΙΤΙΚ', 'ΖΗΤΗΣ'],
#              'ΑΠΟΔΕΙΞ': ['ΠΟΛΙΤΙΚ', 'ΖΗΤΗΣ', 'ΠΑΡΑΠΟΜΠ'],
#              'ΑΘΩΟΤΗΤ': ['ΖΗΤΗΣ', 'ΠΑΡΑΠΟΜΠ', 'ΑΠΟΔΕΙΞ'],
#              'ΕΒΔΟΜ': ['ΠΑΡΑΠΟΜΠ', 'ΑΠΟΔΕΙΞ', 'ΑΘΩΟΤΗΤ'],
#              'ΑΥΣΤΗΡ': ['ΕΒΔΟΜ', 'ΠΑΡΟΥΜ', 'ΠΡΩΤΟΒΟΥΛΙ'],
#              'ΑΜΕΣ': ['ΠΑΡΟΥΜ', 'ΠΡΩΤΟΒΟΥΛΙ', 'ΑΥΣΤΗΡ'],
#              'ΠΟΘ': ['ΑΥΣΤΗΡ', 'ΑΜΕΣ', 'ΕΛΕΓΧ'],
#              'ΕΣΧ': ['ΑΜΕΣ', 'ΕΛΕΓΧ', 'ΠΟΘ'],
#              'ΛΑΜΨ': ['ΕΛΕΓΧ', 'ΠΟΘ', 'ΕΣΧ'],
#              'ΠΡΟΣΒΛΕΠΟΥΜ': ['ΠΟΘ', 'ΕΣΧ', 'ΛΑΜΨ'],
#              'ΠΑΜΨΗΦΙ': ['ΕΣΧ', 'ΛΑΜΨ', 'ΠΡΟΣΒΛΕΠΟΥΜ'],
#              'ΔΙΑΛΕΥΚΑΝΣ': ['ΠΑΜΨΗΦΙ', 'ΒΟΥΛ', 'ΠΛΗΡ'],
#              'ΘΕΜΑΤ': ['ΒΟΥΛ', 'ΠΛΗΡ', 'ΔΙΑΛΕΥΚΑΝΣ'],
#              'ΘΙΓ': ['ΠΛΗΡ', 'ΔΙΑΛΕΥΚΑΝΣ', 'ΘΕΜΑΤ'],
#              'ΟΓΔΟ': ['ΤΙΜ', 'ΠΟΛΙΤΙΚ', 'ΠΡΟΣΩΠ'],
#              'ΠΡΟΤΕΙΝΟΥΜ': ['ΠΡΟΣΩΠ', 'ΟΓΔΟ', 'ΔΙΑΔΙΚΑΣΙ'],
#              'ΔΙΑΣΦΑΛΙΖ': ['ΟΓΔΟ', 'ΔΙΑΔΙΚΑΣΙ', 'ΠΡΟΤΕΙΝΟΥΜ'],
#              'ΕΝΟΤΗΤ': ['ΔΙΑΔΙΚΑΣΙ', 'ΠΡΟΤΕΙΝΟΥΜ', 'ΔΙΑΣΦΑΛΙΖ'],
#              'ΘΕΜ': ['ΠΡΟΤΕΙΝΟΥΜ', 'ΔΙΑΣΦΑΛΙΖ', 'ΕΝΟΤΗΤ'],
#              'ΑΠΟΤΡΕΠ': ['ΕΝΟΤΗΤ', 'ΘΕΜ', 'ΚΑΘΑΡΣ'],
#              'ΜΙΣΑΛΛΟΔΟΞΙ': ['ΘΕΜ', 'ΚΑΘΑΡΣ', 'ΑΠΟΤΡΕΠ'],
#              'ΡΕΒΑΝΣΙΣΜ': ['ΚΑΘΑΡΣ', 'ΑΠΟΤΡΕΠ', 'ΜΙΣΑΛΛΟΔΟΞΙ'],
#              'ΜΕΛΛΟΝ': ['ΑΠΟΤΡΕΠ', 'ΜΙΣΑΛΛΟΔΟΞΙ', 'ΡΕΒΑΝΣΙΣΜ'],
#              'ΤΕΛ': ['ΡΕΒΑΝΣΙΣΜ', 'ΜΕΛΛΟΝ', 'ΔΗΛΩΝΟΥΜ'],
#              'ΣΥΜΒ': ['ΜΕΛΛΟΝ', 'ΔΗΛΩΝΟΥΜ', 'ΤΕΛ'],
#              'ΥΠΕΥΘΥΝ': ['ΤΕΛ', 'ΣΥΜΒ', 'ΚΥΒΕΡΝΗΣ'],
#              'ΑΚΥΒΕΡΝΗΣΙ': ['ΣΥΜΒ', 'ΚΥΒΕΡΝΗΣ', 'ΥΠΕΥΘΥΝ'],
#              'ΣΥΓΚΑΛΥΨ': ['ΚΥΒΕΡΝΗΣ', 'ΥΠΕΥΘΥΝ', 'ΑΚΥΒΕΡΝΗΣΙ'],
#              'πασοκ~': ['ΣΥΓΚΑΛΥΨ', 'ΕΥΘΥΝ', 'ΠΡΟΕΔΡ']})

# %%
# more info here https://www.altcademy.com/blog/calculate-the-k-core-of-a-graph/
def k_core_decomposition(graph, k):
    """
    Perform K-Core Decomposition in a given graph 
    :param graph: A dictionary where keys are vertices and values are the adjacent vertices
    :param k: The minimum degreee of vertices in the K-Core subgraph
    :return: The K-Core subgraph as a dictionary
    """
    
    # initialize the k-core subgraph as the initial graph
    k_core = defaultdict(list)
    for vertex, neighbors in graph.items():
        k_core[vertex] = neighbors[:] # copy the neighbors for each key
    
    # Update degrees of vertices
    def update_degrees(vertex):
        for neighbor in k_core[vertex]:
            k_core[neighbor].remove(vertex)

    # Iterate until all vertices have a degree >= to k
    while True:
        low_degree_vertices = [v for v, neighbors in k_core.items() if len(neighbors) < k]
        if not low_degree_vertices:
            break

        vertex = low_degree_vertices.pop()
        update_degrees(vertex)
        del k_core[vertex]

    return k_core # return the updated graph

# %%
graph = k_core_decomposition(keywords, 3)
# the keys of the graph are the keywords 
graph
# Out:
# defaultdict(list,
#             {'ΚΥΡΙ': ['ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΥΠΑΡΧ',
#               'ΕΚ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΠΑΡΑΚΑΛΟΥΝΤΑ',
#               'ΣΥΝΕΠΕΙ',
#               'ΒΛΑΒ',
#               'ΑΕΡΟΣΚΑΦ',
#               'ΤΣΑΛΔΑΡ',
#               'Κ',
#               'ΧΑΡΑΛΑΜΠΟΠΟΥΛ',
#               'ΤΡΟΠ',
#               'ΚΑΛΟΥΝΤΑ',
#               'ΚΑΤΑΛΟΓ',
#               'ΦΟΥΝΤ',
#               'ΠΑΣΟΚ',
#               'ΨΗΦΟΔΟΧ',
#               'ΥΠΑΡΧ',
#               'ΕΚ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΠΑΡΑΚΑΛΟΥΝΤΑ',
#               'ΑΠΟΤΕΛΕΣΜΑΤ',
#               'ΠΡΟΗΓΟΥΜΕΝ',
#               'ΔΙΑΔΙΚΑΣΙ',
#               'ΨΗΦΙΣ',
#               'ΣΥΝΟΛΙΚ',
#               '298',
#               'ΚΥΡΙ',
#               'ΣΥΜΦΕΡ',
#               'ΑΠΑΙΤ',
#               'ΑΠΑΙΤ',
#               'ΛΑ',
#               'ΛΑ',
#               'ΚΥΡΙ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΚΑΘΗΚΟΝ',
#               'ΥΠΑΡΧ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΠΑΡΑΚΑΛ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΕΦΕΤ',
#               'ΑΝΑΚΡΙΤ',
#               'ΔΙΩΞ',
#               'ΠΡΩΗΝ',
#               'ΥΠΟΥΡΓ',
#               'ΦΑΚΕΛ',
#               'ΒΟΥΛ',
#               'ΔΙΑΝΕΜΗΘ',
#               'ΠΡΑΚΤΙΚ',
#               'ΒΟΥΛ',
#               'ΠΑΡΑΚΑΛ',
#               '1989',
#               'ΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ΜΕΓΑΡ',
#               'ΒΟΥΛ',
#               'ΑΓΑΠΗΤ'],
#              'ΓΡΑΜΜΑΤΕ': ['ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΚΥΡΙ',
#               'ΤΡΙΑΡΙΔ',
#               'ΚΑΛΠ',
#               'ΚΟΣΜΗΤΟΡ',
#               'ΣΤΑΜ',
#               'ΚΑΛΠ',
#               'ΚΟΣΜΗΤΟΡ',
#               '151',
#               'ΨΗΦ',
#               'ΑΞΙΩΜ',
#               '167',
#               'ΨΗΦ',
#               'ΑΞΙΩΜ'],
#              'ΣΥΝΟΔΕΥΣ': ['ΠΑΡΑΚΑΛΕΙΤΑ', 'ΚΥΡΙ', 'ΓΡΑΜΜΑΤΕ'],
#              'ΙΕΡ': ['ΚΥΡΙ', 'ΓΡΑΜΜΑΤΕ', 'ΣΥΝΟΔΕΥΣ'],
#              'ΣΥΝΟΔ': ['ΓΡΑΜΜΑΤΕ',
#               'ΣΥΝΟΔΕΥΣ',
#               'ΙΕΡ',
#               'ΔΙΑΒΑΣ',
#               'ΔΙΑΤΑΓΜ',
#               'ΕΝΑΡΞ',
#               'ΕΡΓΑΣΙ',
#               'α`',
#               'ΤΑΚΤΙΚ',
#               'ΕΡΓΑΣΙ',
#               'α`',
#               'ΤΑΚΤΙΚ'],
#              'ΑΙΘΟΥΣ': ['ΣΥΝΟΔΕΥΣ', 'ΙΕΡ', 'ΣΥΝΟΔ'],
#              'ΒΟΥΛ': ['ΙΕΡ',
#               'ΣΥΝΟΔ',
#               'ΑΙΘΟΥΣ',
#               'ΠΡΟΟΔ',
#               'ΑΠΕΥΘΥΝΕΤΑ',
#               'ΠΡΟΕΔΡΕΙ',
#               'Ρ',
#               'Σ',
#               'ΠΡΟΕΔΡΕΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΔΗΛΩΝΟΥΜ',
#               'ΣΥΓΚΡΟΤΟΥΜ',
#               'ΕΔΑΦΙ',
#               '2',
#               'ΚΑΝΟΝΙΣΜ',
#               'ΒΟΥΛ',
#               'ΕΚΛΕΓΕΤΑ',
#               'ΠΡΟΕΔΡ',
#               'ΣΥΣΤΗΜ',
#               'ΛΕΙΤΟΥΡΓ',
#               'ΠΡΟΕΔΡ',
#               'ΚΑΛΥΤΕΡ',
#               'ΠΡΟΣΠΑΘΕΙ',
#               'ΕΠΙΤΕΛΕΣ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΠΑΡΑΚΑΛ',
#               'ΑΞΙΩΜ',
#               'δ`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΑΞΙΩΜ',
#               'ε`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΣΥΝΟΔ',
#               'ε`',
#               'ΠΕΡΙΟΔ',
#               'ΣΥΝΟΔ',
#               'ε`',
#               'ΠΕΡΙΟΔ',
#               'ΔΗΜΟΣΙΕΥΣ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΔΙΑΤΑΓΜ',
#               'ΑΡΘΡ',
#               '2',
#               'ΚΑΝΟΝΙΣΜ',
#               '153',
#               'παρ4',
#               'ΚΑΝΟΝΙΣΜ',
#               'ΒΟΥΛ',
#               'ΠΕΡΙΗΛΘ',
#               'ΠΡΟΕΔΡ',
#               'ΠΑΡΑΔΟΘ',
#               'ΣΥΓΚΛΗΣ',
#               'ΠΑΡΟΥΣ',
#               'ΒΟΥΛ',
#               'ΠΡΟΚΑΤΟΧ',
#               'ΠΡΟΕΔΡ',
#               'ΑΛΕΥΡ',
#               'ΑΝΑΔΕΙΞ',
#               'ΠΡΟΕΔΡ',
#               'ΓΕΩΡΓΙ',
#               'ΣΚΑΡΛΑΤ',
#               'ΘΕΤ',
#               'Κ',
#               'ΚΡΟΥΣΤΑΛΛΑΚ',
#               'ΘΕΤ',
#               'ΤΙΜ',
#               'ΚΑΤΑΘΕΣ',
#               'ΦΑΚΕΛ',
#               'Κ',
#               'ΔΩΡ',
#               'ΔΙΕΒΙΒΑΣ',
#               'ΑΝΔΡΕ',
#               'ΠΑΠΑΝΔΡΕ',
#               'ΠΡΑΚΤΙΚ',
#               'ΙΟΥΛΙ',
#               '1989',
#               'ΠΡΟΕΔΡ',
#               'ΑΘΑΝΑΣΙ',
#               'ΤΣΑΛΔΑΡ',
#               'ΜΕΓΑΡ',
#               'ΚΑΘΑΡΣ',
#               'ΔΙΑΣΦΑΛΙΣ',
#               'ΠΛΕΙΟΨΗΦΙ',
#               'ΣΥΝΤΑΓΜΑΤ',
#               'ΡΥΘΜΙΣ',
#               'ΚΑΝΟΝΙΣΜ',
#               'ΣΧΕΤΙΚ',
#               'ΣΥΝΕΔΡΙΑΣ',
#               'ΔΙΑΛΥΘΕΙΣ',
#               'ΕΚΠΡΟΣΩΠ',
#               'ΣΥΝΔΡΑΜΟΥΜ',
#               'ΔΥΝΑΜ',
#               'ΛΑΜΨ',
#               'ΠΡΟΣΒΛΕΠΟΥΜ',
#               'ΠΑΜΨΗΦΙ'],
#              'ΠΑΡΑΚΑΛΕΙΤΑ': ['ΣΥΝΟΔ',
#               'ΑΙΘΟΥΣ',
#               'ΒΟΥΛ',
#               'ΑΠΟΤΕΛΕΣΜΑΤ',
#               'Κ',
#               'ΣΤΑΘΟΠΟΥΛ',
#               'Κ',
#               'ΑΘΑΝΑΣΙ',
#               'ΤΣΑΛΔΑΡ'],
#              'ΣΥΝΑΔΕΛΦ': ['ΑΙΘΟΥΣ',
#               'ΒΟΥΛ',
#               'ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΥΠΑΡΧ',
#               'ΕΚ',
#               'ΚΥΡΙ',
#               'ΚΑΝΟΝΙΣΜ',
#               'ΕΚ',
#               'ΥΠΟΨΗΦΙ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΔΥΟ',
#               'ΠΛΕΙΟΨΗΦΗΣΑΝΤ',
#               'Κ',
#               'ΧΑΡΑΛΑΜΠΟΠΟΥΛ',
#               'ΚΥΡΙ',
#               'ΥΠΑΡΧ',
#               'ΕΚ',
#               'ΚΥΡΙ',
#               'ΚΥΡΙ',
#               'ΨΗΦΟΛΕΚΤ',
#               'ΕΠΟΠΤΕΥΟΝΤ',
#               'ΚΥΡΙ',
#               'ΚΥΡΙ',
#               'ΚΥΡΙ',
#               'ΛΑ',
#               'ΚΥΡΙ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΚΑΘΗΚΟΝ',
#               'ΚΥΡΙ',
#               'ΥΠΑΡΧ',
#               'ΚΥΡΙ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΠΑΡΑΚΑΛ',
#               'ΚΥΡΙ',
#               'ΚΥΡΙ',
#               'ΚΥΡΙ',
#               'ΒΟΥΛ',
#               'ΔΙΑΝΕΜΗΘ',
#               'ΚΥΡΙ',
#               'ΒΟΥΛ',
#               'ΠΑΡΑΚΑΛ',
#               'ΚΥΡΙ',
#               'ΚΥΡΙ'],
#              'ΒΟΥΛΕΥΤ': ['ΒΟΥΛ',
#               'ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΚΥΡΙ',
#               'ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΣΩΜ',
#               'ΒΛΑΒ',
#               'ΑΕΡΟΣΚΑΦ',
#               'ΚΥΡΙ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΕΨΗΦΙΣ',
#               '298',
#               'ΑΠΟΛΥΤ',
#               'ΠΛΕΙΟΨΗΦΙ',
#               'ΣΥΝΟΛ',
#               'ΠΡΟΗΓΟΥΜΕΝ',
#               'ΔΙΑΔΙΚΑΣΙ',
#               'ΚΥΡΙ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΣΩΜ',
#               'ΕΠΙΣΤΟΛ',
#               'ΠΡΟΕΔΡΕΙ',
#               'ΒΟΥΛ',
#               'ΠΑΡΑΚΑΤ',
#               'ΣΥΝΟΛΙΚ',
#               '298',
#               'ΚΥΡΙ',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΕΨΗΦΙΣ',
#               '292',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΕΨΗΦΙΣ',
#               '296',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΨΗΦΙΣ',
#               '292',
#               'ΟΡΙΣΜ',
#               'ΗΜΕΡ',
#               'ΕΚΛΟΓ',
#               'ΝΟΜΟΘΕΤΙΚ',
#               'ΕΡΓ',
#               'ΕΝΔΙΑΦΕΡΟΜΕΝ'],
#              'Κ': ['ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΒΟΥΛΕΥΤ',
#               'ΓΙΝ',
#               'ΕΞΑΓΩΓ',
#               'ΑΠΟΤΕΛΕΣΜΑΤ',
#               'ΕΒΡ',
#               'ΥΠΟΥΡΓ',
#               'ΜΑΚΕΔΟΝΙΑΣΘΡΑΚ',
#               'ΥΠΟΨΗΦΙ',
#               'ΝΕ',
#               'ΔΗΜΟΚΡΑΤΙ',
#               'ΨΗΦ',
#               'ΕΥΡΕΘΗΣ',
#               'ΕΛΑΒ',
#               'ΤΣΑΛΔΑΡ',
#               '141',
#               'ΨΗΦ',
#               'ΧΑΡΑΛΑΜΠΟΠΟΥΛ',
#               '126',
#               'ΨΗΦ',
#               'ΔΥΟ',
#               'ΠΛΕΙΟΨΗΦΗΣΑΝΤ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΣΥΝΑΔΕΛΦ',
#               'Κ',
#               'ΤΣΑΛΔΑΡ',
#               'ΨΗΦΟΛΕΚΤ',
#               'ΕΠΟΠΤΕΥΟΝΤ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦ',
#               'ΕΛΑΒ',
#               'ΤΣΑΛΔΑΡ',
#               '144',
#               'ΨΗΦ',
#               'ΒΟΥΛ',
#               'ε`',
#               'ΠΕΡΙΟΔ',
#               'ΚΑΛΠ',
#               'α`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'Κ',
#               'ΣΤΑΥΡ',
#               'β`',
#               'γ`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'Κ',
#               'ΓΕΡΟΝΤΟΠΟΥΛ',
#               'δ`',
#               'ε`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'Κ',
#               'ΚΑΠΑΧΤΣ',
#               'ΓΡΑΜΜΑΤΕ',
#               'ΚΟΜΜ',
#               'ΣΥΜΠΟΛΙΤΕΥΣ',
#               'ΣΥΜΠΟΛΙΤΕΥΣ',
#               'Κ',
#               'ΜΑΜΩΝ',
#               'ΓΡΑΜΜΑΤΕ',
#               'ΚΟΜΜ',
#               'ΑΝΤΙΠΟΛΙΤΕΥΣ',
#               'ΑΝΤΙΠΟΛΙΤΕΥΣ',
#               'Κ',
#               'ΠΑΠΑΘΑΝΑΣΙ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦ',
#               'ΕΛΑΒ',
#               'ΑΚΥΡ',
#               '4',
#               'ΠΑΡΑΚΑΛ',
#               'ΑΞΙΩΜ',
#               'β`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΑΞΙΩΜ',
#               'γ`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'δ`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ε`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ΑΞΙΩΜ',
#               'ΚΟΣΜΗΤΟΡ',
#               'ΣΥΜΠΟΛΙΤΕΥΣ',
#               'ΠΟΛΥΔΩΡ',
#               '167',
#               'ΨΗΦ',
#               'ΑΞΙΩΜ',
#               'ΚΟΣΜΗΤΟΡ',
#               'ΑΝΤΙΠΟΛΙΤΕΥΣ',
#               'ΓΡΑΜΜΑΤΕ',
#               'ΣΥΜΠΟΛΙΤΕΥΣ',
#               'ΕΛΑΒ',
#               'ΒΟΥΛΓΑΡΑΚ',
#               '165',
#               'ΨΗΦ',
#               'ΜΠΑΣΙΑΚ',
#               '167',
#               'ΨΗΦ',
#               'ΤΑΛΙΑΔΟΥΡ',
#               '167',
#               'ΨΗΦ',
#               'ΑΞΙΩΜΑΤΙΚ',
#               'ΑΝΤΙΠΟΛΙΤΕΥΣ',
#               'ΕΛΑΒ',
#               'ΘΩΜ',
#               '151',
#               'ΨΗΦ',
#               '151',
#               'ΨΗΦ',
#               'ΠΑΡΑΚΑΛΕΣ',
#               'βουλησ~',
#               'ΠΡΟΤΑΣ',
#               'ΠΡΩΘΥΠΟΥΡΓ',
#               'ΠΕΡΙΗΛΘ',
#               'ΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ΠΡΟΚΑΤΟΧ',
#               'ΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΕΦΕΤ',
#               'ΑΝΑΚΡΙΤ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΕΦΕΤ',
#               'ΑΝΑΚΡΙΤ',
#               'ΠΡΑΞΕ',
#               'ΠΡΩΗΝ',
#               'ΥΠΟΥΡΓ',
#               'ΕΙΣΑΓΓΕΛΕ',
#               'ΕΦΕΤ',
#               'ΑΘΗΝ',
#               'ΑΡΜΟΔΙΟΤΗΤ',
#               'ΚΑΤΑΓΓΕΛΙ',
#               'ΙΔΙΩΤ',
#               'ΜΑΣΤΟΡ',
#               'ΠΡΩΗΝ',
#               'ΥΠΟΥΡΓ',
#               'ΥΠΗΡΕΣΙΑΚ',
#               'ΑΝΤΙΓΡΑΦ',
#               'ΜΗΝΥΣ',
#               'ΔΗΛΩΣ',
#               'ΠΡΟΕΔΡ',
#               'ΠΑΣΟΚ'],
#              'ΣΑΔΙΚ': ['ΣΥΝΑΔΕΛΦ', 'ΒΟΥΛΕΥΤ', 'Κ'],
#              'ΑΜΕΤ': ['ΒΟΥΛΕΥΤ', 'Κ', 'ΣΑΔΙΚ'],
#              'ΑΝΗΚ': ['Κ', 'ΣΑΔΙΚ', 'ΑΜΕΤ'],
#              'ΜΩΑΜΕΘΑΝΙΚ': ['ΣΑΔΙΚ', 'ΑΜΕΤ', 'ΑΝΗΚ'],
#              'ΘΡΗΣΚΕΥΜ': ['ΑΜΕΤ', 'ΑΝΗΚ', 'ΜΩΑΜΕΘΑΝΙΚ'],
#              'ΠΡΟΣΕΛΘ': ['ΑΝΗΚ',
#               'ΜΩΑΜΕΘΑΝΙΚ',
#               'ΘΡΗΣΚΕΥΜ',
#               'ΤΣΑΛΔΑΡ',
#               'ΔΙΟΤ',
#               'ΑΔΥΝΑΤ'],
#              'ΔΩΣ': ['ΜΩΑΜΕΘΑΝΙΚ', 'ΘΡΗΣΚΕΥΜ', 'ΠΡΟΣΕΛΘ'],
#              'ΟΡΙΖΟΜΕΝ': ['ΘΡΗΣΚΕΥΜ', 'ΠΡΟΣΕΛΘ', 'ΔΩΣ'],
#              'ΣΥΝΤΑΓΜ': ['ΠΡΟΣΕΛΘ',
#               'ΔΩΣ',
#               'ΟΡΙΖΟΜΕΝ',
#               'ΔΗΜΟΚΡΑΤΙΚ',
#               'ΠΟΛΙΤΕΥΜ',
#               'ΥΠΑΚΟΥ'],
#              'ΟΡΚ': ['ΔΩΣ', 'ΟΡΙΖΟΜΕΝ', 'ΣΥΝΤΑΓΜ'],
#              'ΚΟΡΑΝΙ': ['ΟΡΙΖΟΜΕΝ', 'ΣΥΝΤΑΓΜ', 'ΟΡΚ'],
#              '~ορκιζομαι': ['ΣΥΝΤΑΓΜ', 'ΟΡΚ', 'ΚΟΡΑΝΙ'],
#              'ΟΝΟΜ': ['ΟΡΚ', 'ΚΟΡΑΝΙ', '~ορκιζομαι'],
#              'ΠΑΝΤΟΔΥΝΑΜ': ['ΚΟΡΑΝΙ', '~ορκιζομαι', 'ΟΝΟΜ'],
#              'ΘΕ': ['~ορκιζομαι', 'ΟΝΟΜ', 'ΠΑΝΤΟΔΥΝΑΜ'],
#              'ΠΡΟΦΗΤ': ['ΟΝΟΜ', 'ΠΑΝΤΟΔΥΝΑΜ', 'ΘΕ'],
#              'ΜΩΑΜΕΘ': ['ΠΑΝΤΟΔΥΝΑΜ', 'ΘΕ', 'ΠΡΟΦΗΤ'],
#              'ΠΙΣΤ': ['ΘΕ', 'ΠΡΟΦΗΤ', 'ΜΩΑΜΕΘ'],
#              'ΠΑΤΡΙΔ': ['ΠΡΟΦΗΤ', 'ΜΩΑΜΕΘ', 'ΠΙΣΤ'],
#              'ΔΗΜΟΚΡΑΤΙΚ': ['ΜΩΑΜΕΘ', 'ΠΙΣΤ', 'ΠΑΤΡΙΔ'],
#              'ΠΟΛΙΤΕΥΜ': ['ΠΙΣΤ', 'ΠΑΤΡΙΔ', 'ΔΗΜΟΚΡΑΤΙΚ'],
#              'ΥΠΑΚΟΥ': ['ΠΑΤΡΙΔ', 'ΔΗΜΟΚΡΑΤΙΚ', 'ΠΟΛΙΤΕΥΜ'],
#              'ΝΟΜ': ['ΠΟΛΙΤΕΥΜ',
#               'ΥΠΑΚΟΥ',
#               'ΣΥΝΤΑΓΜ',
#               'ΚΑΤΑΘΕΣ',
#               'ΠΡΟΤΑΣ',
#               'ΚΙΝΗΣ',
#               'ΠΛΗΡ',
#               'ΔΙΕΛΕΥΚΑΝΣ',
#               'ΚΙΝΗΣ'],
#              'ΕΚΠΛΗΡΩΝ': ['ΥΠΑΚΟΥ', 'ΣΥΝΤΑΓΜ', 'ΝΟΜ'],
#              'ΕΥΣΥΝΕΙΔΗΤ': ['ΣΥΝΤΑΓΜ', 'ΝΟΜ', 'ΕΚΠΛΗΡΩΝ'],
#              'ΚΑΘΗΚΟΝΤ': ['ΝΟΜ',
#               'ΕΚΠΛΗΡΩΝ',
#               'ΕΥΣΥΝΕΙΔΗΤ',
#               'ΕΠΙΤΕΛΕΣ',
#               'ΒΟΥΛ',
#               'ΣΥΓΚΕΚΡΙΜΕΝ',
#               'ΠΡΩΗΝ',
#               'ΥΠΟΥΡΓ',
#               'ΕΚΤΕΛΕΣ'],
#              'ΕΚ': ['ΥΠΑΡΧ',
#               'ΠΑΡ',
#               '3',
#               'ΚΑΝΟΝΙΣΜ',
#               'ΥΠΑΡΧ',
#               'ΛΕΙΤΟΥΡΓΙ',
#               'ΚΟΙΝΟΒΟΥΛΕΥΤΙΣΜ',
#               'ΟΡ'],
#              'ΨΗΦΙΣ': ['ΕΚ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΕΠΑΝΑΛΗΠΤΙΚ',
#               'ΜΥΣΤΙΚ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΗΘΕΛ',
#               'ΑΡΧΗΝ',
#               'ΕΥΧΑΡΙΣΤΗΣ',
#               'ΥΠΑΡΧ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'δ`',
#               'ε`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΑΞΙΩΜ',
#               'ΚΟΣΜΗΤΟΡ'],
#              'ΚΗΡΥΣΣΕΤΑ': ['ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΨΗΦΙΣ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΕΨΗΦΙΣ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΨΗΦΙΣ'],
#              'ΠΕΡΑΙΩΜΕΝ': ['ΣΥΝΑΔΕΛΦ',
#               'ΨΗΦΙΣ',
#               'ΚΗΡΥΣΣΕΤΑ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΕΨΗΦΙΣ',
#               'ΚΗΡΥΣΣΕΤΑ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΨΗΦΙΣ',
#               'ΚΗΡΥΣΣΕΤΑ'],
#              'ΨΗΦΟΦΟΡΙ': ['ΨΗΦΙΣ',
#               'ΚΗΡΥΣΣΕΤΑ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΑΠΟΤΕΛΕΣΜ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΣΥΝΟΛ',
#               'ΒΟΥΛΕΥΤ',
#               'ΕΠΑΝΑΛΗΦΘ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΛΕΥΚ',
#               'ΕΠΑΝΑΛΗΦΘ',
#               'ΕΨΗΦΙΣ',
#               'ΚΗΡΥΣΣΕΤΑ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΕΠΑΝΑΛΗΠΤΙΚ',
#               'ΜΥΣΤΙΚ',
#               'ΨΗΦΙΣ',
#               'ΚΗΡΥΣΣΕΤΑ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΕΔΡ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΕΔΡ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΕΔΡ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ'],
#              'ΠΑΡΑΚΑΛΟΥΝΤΑ': ['ΚΗΡΥΣΣΕΤΑ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΚΗΡΥΣΣΕΤΑ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΨΗΦΟΦΟΡΙ'],
#              'ΨΗΦΟΛΕΚΤ': ['ΨΗΦΟΦΟΡΙ',
#               'ΠΑΡΑΚΑΛΟΥΝΤΑ',
#               'ΚΥΡΙ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΠΑΡΑΚΑΛΟΥΝΤΑ',
#               'ΚΥΡΙ'],
#              'ΜΕΤΑΦΕΡ': ['ΠΑΡΑΚΑΛΟΥΝΤΑ', 'ΚΥΡΙ', 'ΨΗΦΟΛΕΚΤ'],
#              'ΨΗΦΟΔΟΧ': ['ΚΥΡΙ',
#               'ΨΗΦΟΛΕΚΤ',
#               'ΜΕΤΑΦΕΡ',
#               'ΠΑΡΑΣΚΕΥ',
#               'ΦΟΥΝΤ',
#               'ΠΑΣΟΚ',
#               'ΠΑΡΑΚΑΛ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ'],
#              'ΧΩΡ': ['ΨΗΦΟΛΕΚΤ',
#               'ΜΕΤΑΦΕΡ',
#               'ΨΗΦΟΔΟΧ',
#               'ΔΗΜΟΚΡΑΤΙ',
#               'ΥΠΑΓΟΡΕΥ',
#               'ΣΥΜΦΕΡ'],
#              'ΠΡΑΚΤΙΚΟΓΡΑΦ': ['ΜΕΤΑΦΕΡ', 'ΨΗΦΟΔΟΧ', 'ΧΩΡ'],
#              'Ν': ['ΨΗΦΟΔΟΧ', 'ΧΩΡ', 'ΠΡΑΚΤΙΚΟΓΡΑΦ'],
#              'ΑΡΧΙΣ': ['ΧΩΡ',
#               'ΠΡΑΚΤΙΚΟΓΡΑΦ',
#               'Ν',
#               'ΡΕΠΠ',
#               'ΠΑΣΟΚ',
#               'ΠΑΡΑΚΑΛ',
#               'ΚΑΘΙΣ',
#               'ΕΔΡΑΝ',
#               'ΠΡΟΕΔΡΕΙ'],
#              'ΔΙΑΛΟΓ': ['ΠΡΑΚΤΙΚΟΓΡΑΦ',
#               'Ν',
#               'ΑΡΧΙΣ',
#               'ΣΤΑΘΟΠΟΥΛ',
#               'ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΕΠΟΠΤΕΥΣ',
#               '298',
#               'ΒΟΥΛΕΥΤ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'Κ',
#               'ΣΩΤΗΡΟΠΟΥΛ',
#               'ΠΡΟΧΩΡΗΣ',
#               'ΚΥΡΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΕΔΡΑΝ',
#               'ΠΡΟΕΔΡΕΙ',
#               'ΑΡΧΙΣ',
#               '292',
#               'ΒΟΥΛΕΥΤ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               '296',
#               'ΒΟΥΛΕΥΤ',
#               'ΚΑΤΑΜΕΤΡΗΣ'],
#              'ΨΗΦΟΔΕΛΤΙ': ['Ν',
#               'ΑΡΧΙΣ',
#               'ΔΙΑΛΟΓ',
#               'ΣΩΜΑΤ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΕΥΡΕΘ',
#               '1',
#               'ΛΕΥΚ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΜΟΙΡΑΣΘ',
#               'ΔΥΟ',
#               'ΣΩΤΗΡΟΠΟΥΛ',
#               'ΠΡΟΧΩΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΕΥΡΕΘΗΣ',
#               '30',
#               'ΛΕΥΚ'],
#              'ΓΙΝ': ['ΑΡΧΙΣ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΣΤΑΘΕΡΟΤΗΤ',
#               'ΔΙΑΡΚΕΙ',
#               'ΜΠΟΡΟΥΣ',
#               'ΠΡΟΚΑΛΕΣ',
#               'ΣΥΖΗΤΗΣ',
#               'ΕΠΙΤΡΕΠΕΤΑ'],
#              'ΕΞΑΓΩΓ': ['ΔΙΑΛΟΓ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΓΙΝ',
#               'ΠΡΟΧΩΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦΟΔΕΛΤΙ'],
#              'ΑΠΟΤΕΛΕΣΜΑΤ': ['ΨΗΦΟΔΕΛΤΙ',
#               'ΓΙΝ',
#               'ΕΞΑΓΩΓ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΕΞΑΓΩΓ'],
#              'ΣΤΑΘΟΠΟΥΛ': ['ΕΞΑΓΩΓ', 'ΑΠΟΤΕΛΕΣΜΑΤ', 'Κ'],
#              'ΕΠΟΠΤΕΥΣ': ['Κ', 'ΣΤΑΘΟΠΟΥΛ', 'ΠΑΡΑΚΑΛΕΙΤΑ'],
#              'ΤΙΜ': ['ΚΥΡΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΑΕΡΟΣΚΑΦ',
#               'ΚΥΡΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΔΙΑΔΙΚΑΣΙ',
#               'ΚΥΡΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'Κ',
#               'ΓΕΩΡΓΙ',
#               'ΠΕΤΣ',
#               'ΔΗΛΩΣ',
#               'ΚΑΤΑΧΩΡΗΘ',
#               'ΠΡΑΚΤΙΚ',
#               'ΔΙΑΛΕΥΚΑΝΣ',
#               'ΘΕΜΑΤ',
#               'ΘΙΓ'],
#              'ΑΝΑΚΟΙΝΩΣ': ['ΚΥΡΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΤΙΜ',
#               'ΚΥΡΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΤΙΜ',
#               'ΚΥΡΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΤΙΜ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΤΙΜ',
#               'ΔΙΑΤΑΓΜ',
#               'ΠΡΩΘΥΠΟΥΡΓ',
#               'ΔΗΜΟΣΙΕΥΣ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΤΙΜ',
#               'ΑΡΙΘΜ',
#               '293',
#               '294/13689',
#               'ΑΠΟΔΕΙΚΤΙΚ',
#               'ΣΤΟΙΧΕΙ',
#               'ΔΥΟ',
#               'υπ`',
#               'ΑΡΙΘΜ',
#               '293',
#               'ΓΕΩΡΓΙ',
#               'ΠΕΤΣ',
#               '294'],
#              'ΣΩΜ': ['ΒΟΥΛΕΥΤ',
#               'ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΒΟΥΛΕΥΤ',
#               'ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΒΟΥΛΕΥΤ',
#               'ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΠΡΟΕΔΡ',
#               'ΠΑΡΑΚΑΛ',
#               'ΑΝΑΓΝΩΣΘ'],
#              'ΕΒΡ': ['ΑΝΑΚΟΙΝΩΣ', 'ΣΩΜ', 'ΒΟΥΛΕΥΤ'],
#              'ΥΠΟΥΡΓ': ['ΣΩΜ',
#               'ΒΟΥΛΕΥΤ',
#               'ΕΒΡ',
#               'ΠΟΙΝΙΚ',
#               'ΔΙΩΞ',
#               'ΠΡΩΗΝ',
#               'ΑΞΙΟΠΟΙΝ',
#               'ΠΡΑΞΕ',
#               'ΠΡΩΗΝ',
#               'ΓΕΩΡΓΙ',
#               'ΜΑΣΤΟΡ',
#               'ΠΡΩΗΝ',
#               'ΜΗΝΥΣ',
#               'Κ',
#               'ΛΑΓ',
#               'ΦΕΡΟΝΤΑ',
#               'ΤΕΛΕΣΘΕΙΣ',
#               'ΠΡΩΗΝ',
#               'ΚΙΝΗΣ',
#               'ΝΟΜ',
#               'ΕΥΘΥΝ',
#               'ΚΙΝΗΣ',
#               'ΝΟΜ',
#               'ΕΥΘΥΝ'],
#              'ΜΑΚΕΔΟΝΙΑΣΘΡΑΚ': ['ΒΟΥΛΕΥΤ', 'ΕΒΡ', 'ΥΠΟΥΡΓ'],
#              'ΠΑΝΑΓΙΩΤ': ['ΥΠΟΥΡΓ',
#               'ΜΑΚΕΔΟΝΙΑΣΘΡΑΚ',
#               'Κ',
#               'ΚΟΡΑΚ',
#               'ΕΥΣΤΡΑΤΙ',
#               'ΚΟΣΙΩΝ',
#               'ΡΗΓ',
#               'ΚΩΝΣΤΑΝΤΙΝ',
#               'ΣΚΟΤΙΝΙΩΤ',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'Κ'],
#              'ΧΑΤΖΗΝΙΚΟΛΑ': ['ΜΑΚΕΔΟΝΙΑΣΘΡΑΚ', 'Κ', 'ΠΑΝΑΓΙΩΤ'],
#              'ΤΗΛΕΓΡΑΦΗΜ': ['Κ', 'ΠΑΝΑΓΙΩΤ', 'ΧΑΤΖΗΝΙΚΟΛΑ'],
#              'ΔΗΛΩΝ': ['ΠΑΝΑΓΙΩΤ', 'ΧΑΤΖΗΝΙΚΟΛΑ', 'ΤΗΛΕΓΡΑΦΗΜ'],
#              'ΨΗΦΙΖ': ['ΧΑΤΖΗΝΙΚΟΛΑ', 'ΤΗΛΕΓΡΑΦΗΜ', 'ΔΗΛΩΝ'],
#              'ΥΠΟΨΗΦΙ': ['ΤΗΛΕΓΡΑΦΗΜ',
#               'ΔΗΛΩΝ',
#               'ΨΗΦΙΖ',
#               '3',
#               'ΚΑΝΟΝΙΣΜ',
#               'ΕΚ'],
#              'ΝΕ': ['ΔΗΛΩΝ',
#               'ΨΗΦΙΖ',
#               'ΥΠΟΨΗΦΙ',
#               'ΚΥΡΙ',
#               'ΙΩΑΝΝ',
#               'ΤΡΑΓΑΚ',
#               'ΚΥΡΙ',
#               'ΣΠΥΡ',
#               'ΤΑΛΙΑΔΟΥΡ'],
#              'ΔΗΜΟΚΡΑΤΙ': ['ΨΗΦΙΖ',
#               'ΥΠΟΨΗΦΙ',
#               'ΝΕ',
#               'ΙΩΑΝΝ',
#               'ΤΡΑΓΑΚ',
#               'ΝΕ',
#               'ΣΠΥΡ',
#               'ΤΑΛΙΑΔΟΥΡ',
#               'ΝΕ',
#               'ΚΟΙΝΟΒΟΥΛΙ',
#               'ΥΨΙΣΤ',
#               'ΘΕΣΜ',
#               'ΚΑΝΟΝ',
#               'ΛΕΙΤΟΥΡΓΙ',
#               'ΚΟΙΝΟΒΟΥΛΕΥΤΙΚ',
#               'ΚΥΒΕΡΝΗΣ',
#               'ΤΗΣ',
#               'ΕΛΛΗΝΙΚ',
#               'Σ',
#               'ΤΗΣ',
#               'ΕΛΛΗΝΙΚ',
#               '1989',
#               'ΠΡΟΕΔΡ',
#               'ΤΗΣ'],
#              'ΑΘΑΝΑΣΙ': ['ΝΕ',
#               'ΔΗΜΟΚΡΑΤΙ',
#               'Κ',
#               'ΕΥΡΕΘΗΣ',
#               'ΕΛΑΒ',
#               'Κ',
#               'ΚΩΣΤΟΠΟΥΛ',
#               'ΔΗΜΗΤΡΙ',
#               'ΛΕΒΕΝΤ',
#               'ΨΗΦ',
#               'ΕΛΑΒ',
#               'Κ',
#               'ε`',
#               'ΠΕΡΙΟΔ',
#               'Κ',
#               'ΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ΚΥΡΙ'],
#              'ΤΣΑΛΔΑΡ': ['ΔΗΜΟΚΡΑΤΙ',
#               'Κ',
#               'ΑΘΑΝΑΣΙ',
#               'ΕΛΑΒ',
#               'Κ',
#               'ΑΘΑΝΑΣΙ',
#               'ΠΛΕΙΟΨΗΦΗΣΑΝΤ',
#               'ΣΥΝΑΔΕΛΦ',
#               'Κ',
#               'ΕΛΑΒ',
#               'Κ',
#               'ΑΘΑΝΑΣΙ',
#               'ΠΕΡΙΟΔ',
#               'Κ',
#               'ΑΘΑΝΑΣΙ',
#               'ΒΟΥΛ',
#               'ΚΥΡΙ',
#               'ΑΘΑΝΑΣΙ'],
#              'ΔΙΟΤ': ['Κ',
#               'ΑΘΑΝΑΣΙ',
#               'ΤΣΑΛΔΑΡ',
#               'ΠΑΡΑΚΑΛ',
#               'ΔΙΑΚΟΠΤΕΤ',
#               'ΔΙΑΒΑΣ'],
#              'ΑΔΥΝΑΤ': ['ΑΘΑΝΑΣΙ', 'ΤΣΑΛΔΑΡ', 'ΔΙΟΤ'],
#              'ΜΑΤΑΙΩΣ': ['ΔΙΟΤ', 'ΑΔΥΝΑΤ', 'ΠΡΟΣΕΛΘ'],
#              'ΠΤΗΣ': ['ΑΔΥΝΑΤ', 'ΠΡΟΣΕΛΘ', 'ΜΑΤΑΙΩΣ'],
#              'ΣΥΝΕΠΕΙ': ['ΠΡΟΣΕΛΘ', 'ΜΑΤΑΙΩΣ', 'ΠΤΗΣ'],
#              'ΒΛΑΒ': ['ΜΑΤΑΙΩΣ', 'ΠΤΗΣ', 'ΣΥΝΕΠΕΙ'],
#              'ΑΕΡΟΣΚΑΦ': ['ΠΤΗΣ', 'ΣΥΝΕΠΕΙ', 'ΒΛΑΒ'],
#              'ΑΠΟΤΕΛΕΣΜ': ['ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΣΩΜ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ'],
#              'ΔΙΕΞΑΧΘΕΙΣ': ['ΑΝΑΚΟΙΝΩΣ',
#               'ΣΩΜ',
#               'ΑΠΟΤΕΛΕΣΜ',
#               'ΕΚΛΟΓ',
#               'ΠΡΟΕΔΡ',
#               'ΣΩΜΑΤ',
#               'ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΑΠΟΤΕΛΕΣΜ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΚΑΤΑΛΑΒ',
#               'ΘΕΣ',
#               'ΕΔΡ',
#               'ΚΑΤΑΛΑΒ',
#               'ΘΕΣ',
#               'ΕΔΡ',
#               'ΚΑΤΑΛΑΒ',
#               'ΘΕΣ',
#               'ΕΔΡ'],
#              'ΜΥΣΤΙΚ': ['ΣΩΜ',
#               'ΑΠΟΤΕΛΕΣΜ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΠΡΟΕΔΡ',
#               'ΣΩΜΑΤ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΑΠΟΤΕΛΕΣΜ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΕΠΑΝΑΛΗΠΤΙΚ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΘΕΣ',
#               'ΕΔΡ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΘΕΣ',
#               'ΕΔΡ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΘΕΣ',
#               'ΕΔΡ',
#               'ΔΙΕΞΑΧΘΕΙΣ'],
#              'ΕΚΛΟΓ': ['ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΤΕΚΜΗΡΙ',
#               'ΔΗΜΟΚΡΑΤΙΚΟΤΗΤ',
#               'ΝΟΜΙΜΟΤΗΤ',
#               'ΠΕΡΙΟΔ',
#               'ΟΡΙΣΜ',
#               'ΗΜΕΡ'],
#              'ΠΡΟΕΔΡ': ['ΜΥΣΤΙΚ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΕΚΛΟΓ',
#               'ΥΠΟΨΗΦΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΑΞΙΩΜ',
#               'ΑΡΙΣΤΕΡ',
#               'ΤΗΣ',
#               'προοδου~',
#               'ΚΑΝΟΝΙΣΜ',
#               'ΒΟΥΛ',
#               'ΕΚΛΕΓΕΤΑ',
#               'ΠΙΣΤΟΠΟΙ',
#               'ΣΥΣΤΗΜ',
#               'ΛΕΙΤΟΥΡΓ',
#               'ΨΗΦ',
#               'ΠΑΡΑΚΑΛΕΣ',
#               'Κ',
#               '5',
#               'ΙΟΥΛΙ',
#               '1989',
#               'ΚΑΝΟΝΙΣΜ',
#               'ΒΟΥΛ',
#               'ΠΕΡΙΗΛΘ',
#               'ΠΑΡΟΥΣ',
#               'ΒΟΥΛ',
#               'ΠΡΟΚΑΤΟΧ',
#               'Κ',
#               'ΑΛΕΥΡ',
#               'ΑΝΑΔΕΙΞ',
#               'ΓΝΩΣ',
#               'ΚΑΤΑΘΕΤ',
#               'ΔΗΛΩΣ',
#               '5',
#               'ΙΟΥΛΙ',
#               '1989',
#               'ΒΟΥΛ',
#               'ΑΓΑΠΗΤ',
#               'ΚΥΡΙ',
#               'ΑΝΔΡΕ',
#               'Γ',
#               'ΠΑΠΑΝΔΡΕ',
#               'Δ',
#               'Λ',
#               'Σ',
#               'ΑΚΥΒΕΡΝΗΣΙ',
#               'ΣΥΓΚΑΛΥΨ',
#               'ΕΥΘΥΝ'],
#              'ΣΩΜΑΤ': ['ΨΗΦΟΦΟΡΙ',
#               'ΕΚΛΟΓ',
#               'ΠΡΟΕΔΡ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΑΝΑΛΑΜΒΑΝΟΝΤ',
#               'ΠΡΟΕΔΡΙ'],
#              'ΕΨΗΦΙΣ': ['ΜΥΣΤΙΚ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΕΚ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΨΗΦΙΣ',
#               'ΗΘΕΛ',
#               'ΕΥΧΑΡΙΣΤΗΣ',
#               'ΑΞΙΩΜ',
#               'α`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'β`',
#               'γ`',
#               'ΑΝΤΙΠΡΟΕΔΡ'],
#              '298': ['ΨΗΦΟΔΕΛΤΙ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΕΨΗΦΙΣ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΨΗΦΙΣ',
#               'ΣΥΝΟΛΙΚ'],
#              'ΚΑΤΑΜΕΤΡΗΣ': ['ΕΨΗΦΙΣ',
#               '298',
#               'ΒΟΥΛΕΥΤ',
#               '298',
#               'ΚΥΡΙ',
#               'ΒΟΥΛΕΥΤ',
#               'ΕΨΗΦΙΣ',
#               '292',
#               'ΒΟΥΛΕΥΤ',
#               'ΕΨΗΦΙΣ',
#               '296',
#               'ΒΟΥΛΕΥΤ',
#               'ΨΗΦΙΣ',
#               '292',
#               'ΒΟΥΛΕΥΤ'],
#              'ΨΗΦ': ['ΒΟΥΛΕΥΤ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΑΘΑΝΑΣΙ',
#               'ΤΣΑΛΔΑΡ',
#               '141',
#               'ΓΙΑΝΝ',
#               'ΧΑΡΑΛΑΜΠΟΠΟΥΛ',
#               '126',
#               'ΜΑΡΙ',
#               'ΔΑΜΑΝΑΚ',
#               '30',
#               'ΒΟΥΛΕΥΤ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΑΘΑΝΑΣΙ',
#               'ΤΣΑΛΔΑΡ',
#               '144',
#               'ΙΩΑΝΝ',
#               'ΧΑΡΑΛΑΜΠΟΠΟΥΛ',
#               '124',
#               'ΕΚΛΟΓ',
#               'ΘΕΤΙΚ',
#               'ΑΡΝΗΤΙΚ',
#               'ΒΟΥΛΕΥΤ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΜΑΡΙ',
#               'ΔΑΜΑΝΑΚ',
#               '165',
#               'ΒΟΥΛΕΥΤ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΝΙΚΟΛΑ',
#               'ΚΑΤΣΑΡ',
#               '166',
#               'ΘΕΟΔΩΡ',
#               'ΑΝΑΓΝΩΣΤΟΠΟΥΛ',
#               '166',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΣΕΛΙΔ',
#               '0010λογη',
#               'ΠΑΝΑΓΙΩΤ',
#               'ΚΡΗΤΙΚ',
#               '155',
#               'ΓΕΩΡΓΙ',
#               'μωραϊτησ',
#               '155',
#               'ΒΥΡ',
#               'ΠΟΛΥΔΩΡ',
#               '167',
#               'ΘΕΟΔΩΡ',
#               'ΔΑΜΙΑΝ',
#               '167',
#               'ΙΩΑΝΝ',
#               'ΦΛΩΡ',
#               '151',
#               'ΓΕΩΡΓΙ',
#               'ΒΟΥΛΓΑΡΑΚ',
#               '165',
#               'ΕΥΑΓΓΕΛ',
#               'ΜΠΑΣΙΑΚ',
#               '167',
#               'ΣΠΥΡΙΔ',
#               'ΤΑΛΙΑΔΟΥΡ',
#               '167',
#               'ΚΩΝΣΤΑΝΤΙΝ',
#               'ΚΑΡΑΜΑΝΛ',
#               '167',
#               'ΜΑΡΙ',
#               'ΘΩΜ',
#               '151',
#               'ΑΝΤΩΝΙ',
#               'ΚΩΤΣΑΚ',
#               '151'],
#              'ΕΥΡΕΘΗΣ': ['ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦ',
#               'ΧΑΡΑΛΑΜΠΟΠΟΥΛ',
#               '124',
#               'ΨΗΦ'],
#              'ΕΛΑΒ': ['ΔΙΑΛΟΓ',
#               'ΨΗΦ',
#               'ΕΥΡΕΘΗΣ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦ',
#               'ΚΑΤΑΜΕΤΡΗΣ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦ',
#               'ΔΙΑΣΕΛΙΔ',
#               '0010λογη',
#               'ΨΗΦ',
#               'ΚΟΣΜΗΤΟΡ',
#               'ΨΗΦΙΣ',
#               '296',
#               'ΑΞΙΩΜ',
#               'ΓΡΑΜΜΑΤΕ',
#               'ΣΥΜΠΟΛΙΤΕΥΣ',
#               'ΓΡΑΜΜΑΤΕ',
#               'ΑΞΙΩΜΑΤΙΚ',
#               'ΑΝΤΙΠΟΛΙΤΕΥΣ'],
#              '141': ['Κ', 'ΑΘΑΝΑΣΙ', 'ΤΣΑΛΔΑΡ'],
#              'ΓΙΑΝΝ': ['141', 'ΨΗΦ', 'Κ', 'ΔΑΜΑΝΑΚ', 'ΜΑΡΙ', 'ΔΡΑΓΑΣΑΚ'],
#              'ΧΑΡΑΛΑΜΠΟΠΟΥΛ': ['ΨΗΦ',
#               'Κ',
#               'ΓΙΑΝΝ',
#               'Κ',
#               'ΤΣΑΛΔΑΡ',
#               'Κ',
#               'ΨΗΦ',
#               'Κ',
#               'ΙΩΑΝΝ'],
#              '126': ['Κ', 'ΓΙΑΝΝ', 'ΧΑΡΑΛΑΜΠΟΠΟΥΛ'],
#              'ΜΑΡΙ': ['126',
#               'ΨΗΦ',
#               'Κ',
#               'ΓΙΩΤ',
#               'ΕΥΣΤΑΘΙ',
#               'ΔΑΜΑΝΑΚ',
#               'ΨΗΦ',
#               'ΕΛΑΒ',
#               'Κ',
#               'ΑΝΤΙΠΟΛΙΤΕΥΣ',
#               'ΕΛΑΒ',
#               'Κ'],
#              'ΔΑΜΑΝΑΚ': ['ΨΗΦ',
#               'Κ',
#               'ΜΑΡΙ',
#               'ΓΡΗΓΟΡ',
#               'ΓΙΩΤ',
#               'ΕΥΣΤΑΘΙ',
#               'ΕΛΑΒ',
#               'Κ',
#               'ΜΑΡΙ',
#               '4',
#               'ΠΑΡΑΚΑΛ',
#               'Κ'],
#              '30': ['Κ', 'ΜΑΡΙ', 'ΔΑΜΑΝΑΚ', '124', 'ΨΗΦ', 'ΕΥΡΕΘΗΣ'],
#              'ΕΥΡΕΘ': ['ΔΑΜΑΝΑΚ', '30', 'ΨΗΦ'],
#              '1': ['30', 'ΨΗΦ', 'ΕΥΡΕΘ', 'ΑΡΘΡ', '40', 'ΠΑΡ'],
#              'ΛΕΥΚ': ['ΨΗΦ',
#               'ΕΥΡΕΘ',
#               '1',
#               'ΜΟΙΡΑΣΘ',
#               'ΔΥΟ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΨΗΦ',
#               'ΕΥΡΕΘΗΣ',
#               '30',
#               'ΔΑΜΑΝΑΚ',
#               '165',
#               'ΨΗΦ'],
#              'ΣΥΜΦΩΝ': ['1',
#               'ΛΕΥΚ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΣΧΕΤΙΚ',
#               'ΠΛΕΙΟΨΗΦΙ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΔΙΑΤΑΓΜ',
#               'ΒΟΥΛ',
#               'ΤΙΜ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΣΩΜ',
#               'ΥΠΟΥΡΓ',
#               'ΣΥΓΚΕΚΡΙΜΕΝ',
#               'ΚΑΤΗΓΟΡΙ'],
#              'ΑΡΘΡ': ['ΛΕΥΚ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΣΥΜΦΩΝ',
#               'ΣΧΕΤΙΚ',
#               'ΠΛΕΙΟΨΗΦΙ',
#               'ΣΥΜΦΩΝ',
#               'ΕΧΟΝΤ',
#               'ΔΙΑΤΑΞ',
#               '',
#               'ΔΙΑΤΑΓΜ',
#               'ΒΟΥΛ',
#               'ΣΥΜΦΩΝ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΣΩΜ',
#               'ΣΥΜΦΩΝ',
#               'ΚΑΤΗΓΟΡΙ',
#               'ΣΥΜΦΩΝ',
#               'ΔΙΑΤΑΞ',
#               'ΑΛΛΩΣΤΕ',
#               'ΠΑΡΑΓΡΑΦ',
#               '3'],
#              '7': ['ΨΗΦΟΔΕΛΤΙ',
#               'ΣΥΜΦΩΝ',
#               'ΑΡΘΡ',
#               'ΠΛΕΙΟΨΗΦΙ',
#               'ΣΥΜΦΩΝ',
#               'ΑΡΘΡ'],
#              'ΠΑΡ': ['ΣΥΜΦΩΝ',
#               'ΑΡΘΡ',
#               '7',
#               '',
#               'ΑΡΘΡ',
#               '40',
#               'ΣΥΜΦΩΝ',
#               'ΑΡΘΡ',
#               '86'],
#              '3': ['ΑΡΘΡ', '7', 'ΠΑΡ', 'ΒΑΣ', 'ΑΛΛΩΣΤΕ', 'ΠΑΡΑΓΡΑΦ'],
#              'ΚΑΝΟΝΙΣΜ': ['7',
#               'ΠΑΡ',
#               '3',
#               'παρ3',
#               'ΕΔΑΦΙ',
#               '2',
#               'ΠΟΛΛ',
#               'ΕΞΥΨΩΣ',
#               'ΤΡΟΠΟΠΟΙΗΣ',
#               'ΣΥΜΦΩΝ',
#               'ΑΡΘΡ',
#               '2',
#               'ΣΥΝΤΑΓΜΑΤ',
#               '153',
#               'παρ4',
#               '86',
#               'ΣΥΝΤΑΓΜΑΤ',
#               'ΡΥΘΜΙΣ'],
#              'ΑΞΙΩΜ': ['ΕΚ',
#               'ΥΠΟΨΗΦΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΔΙΑΛΟΓ',
#               'ΨΗΦ',
#               'ΕΛΑΒ',
#               'ΚΑΤΣΑΡ',
#               '166',
#               'ΨΗΦ',
#               '0010λογη',
#               'ΨΗΦ',
#               'ΕΛΑΒ',
#               'ΚΡΗΤΙΚ',
#               '155',
#               'ΨΗΦ',
#               'ΔΙΕΞΑΧΘΕΙΣ',
#               'ΜΥΣΤΙΚ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΨΗΦΙΣ',
#               '296',
#               'ΕΛΑΒ',
#               'ΔΑΜΙΑΝ',
#               '167',
#               'ΨΗΦ',
#               'ΦΛΩΡ',
#               '151',
#               'ΨΗΦ',
#               'ΚΑΡΑΜΑΝΛ',
#               '167',
#               'ΨΗΦ'],
#              'ΣΥΓΚΕΝΤΡΩΣ': ['ΣΥΝΑΔΕΛΦ', 'ΑΞΙΩΜ', 'ΠΡΟΕΔΡ'],
#              'ΑΠΟΛΥΤ': ['ΑΞΙΩΜ', 'ΠΡΟΕΔΡ', 'ΣΥΓΚΕΝΤΡΩΣ'],
#              'ΠΛΕΙΟΨΗΦΙ': ['ΠΡΟΕΔΡ',
#               'ΣΥΓΚΕΝΤΡΩΣ',
#               'ΑΠΟΛΥΤ',
#               'ΛΕΥΚ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΣΧΕΤΙΚ',
#               'ΑΡΝΗΘ',
#               'ΚΑΘΑΡΣ',
#               'ΔΙΑΣΦΑΛΙΣ',
#               'ΔΙΚΑΣΤΗΡΙ',
#               'ΚΟΜΜΑΤΙΚ',
#               'ΣΥΜΜΑΧΙΚ'],
#              'ΣΥΝΟΛ': ['ΣΥΓΚΕΝΤΡΩΣ', 'ΑΠΟΛΥΤ', 'ΠΛΕΙΟΨΗΦΙ'],
#              'ΕΠΑΝΑΛΗΦΘ': ['ΠΛΕΙΟΨΗΦΙ',
#               'ΣΥΝΟΛ',
#               'ΒΟΥΛΕΥΤ',
#               'ΔΥΟ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΛΕΥΚ'],
#              'ΔΥΟ': ['ΒΟΥΛΕΥΤ',
#               'ΕΠΑΝΑΛΗΦΘ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΜΟΙΡΑΣΘ',
#               'ΦΩΤΟΤΥΠΙ',
#               'ΑΠΟΔΕΙΚΤΙΚ',
#               'ΣΤΟΙΧΕΙ'],
#              'ΠΛΕΙΟΨΗΦΗΣΑΝΤ': ['ΕΠΑΝΑΛΗΦΘ', 'ΨΗΦΟΦΟΡΙ', 'ΔΥΟ'],
#              'ΜΟΙΡΑΣΘ': ['ΧΑΡΑΛΑΜΠΟΠΟΥΛ', 'ΚΥΡΙ', 'ΣΥΝΑΔΕΛΦ'],
#              'ΤΡΟΠ': ['ΛΕΥΚ',
#               'ΕΠΑΝΑΛΗΦΘ',
#               'ΨΗΦΟΦΟΡΙ',
#               'ΠΟΛΙΤΙΚ',
#               'ΥΠΑΡΞ',
#               'ΕΝΕΡΓΟΥΜ',
#               'ΠΛΕΥΡ',
#               'ΔΗΛΩΝΟΥΜ',
#               'ΚΑΤΗΓΟΡΗΜΑΤΙΚ',
#               'ΕΥΘΥΝ',
#               'ΥΠΟΥΡΓ',
#               'μ`'],
#              'ΚΑΛΟΥΝΤΑ': ['ΕΠΑΝΑΛΗΦΘ', 'ΨΗΦΟΦΟΡΙ', 'ΤΡΟΠ'],
#              'ΚΑΤΑΛΟΓ': ['ΨΗΦΟΦΟΡΙ',
#               'ΤΡΟΠ',
#               'ΚΑΛΟΥΝΤΑ',
#               'ΠΑΡΑΚΑΛ',
#               'ΑΡΧΙΣ',
#               'ΑΝΑΓΝΩΣ'],
#              'ΙΩΑΝΝ': ['ΚΑΛΟΥΝΤΑ',
#               'ΚΑΤΑΛΟΓ',
#               'ΚΥΡΙ',
#               'ΚΑΠΠ',
#               'ΚΩΝΣΤΑΝΤΙΝ',
#               'ΚΑΤΣΑΡ',
#               '144',
#               'ΨΗΦ',
#               'Κ',
#               'ΚΟΣΜΗΤΟΡ',
#               'ΑΝΤΙΠΟΛΙΤΕΥΣ',
#               'Κ'],
#              'ΤΡΑΓΑΚ': ['ΚΑΤΑΛΟΓ', 'ΚΥΡΙ', 'ΙΩΑΝΝ'],
#              'ΠΑΡΑΣΚΕΥ': ['ΤΡΑΓΑΚ', 'ΝΕ', 'ΔΗΜΟΚΡΑΤΙ'],
#              'ΦΟΥΝΤ': ['ΝΕ', 'ΔΗΜΟΚΡΑΤΙ', 'ΠΑΡΑΣΚΕΥ'],
#              'ΠΑΣΟΚ': ['ΔΗΜΟΚΡΑΤΙ',
#               'ΠΑΡΑΣΚΕΥ',
#               'ΦΟΥΝΤ',
#               'ΔΗΜΟΚΡΑΤΙ',
#               'ΔΗΜΗΤΡΙ',
#               'ΡΕΠΠ',
#               'ΚΑΤΑΘΕΤ',
#               'ΔΗΛΩΣ',
#               'ΠΡΟΕΔΡ',
#               'Λ',
#               'Σ',
#               'ΠΡΟΕΔΡ'],
#              'ΣΠΥΡ': ['ΠΑΣΟΚ',
#               'ΨΗΦΟΔΟΧ',
#               'ΚΥΡΙ',
#               'ΣΠΑΘ',
#               'ΘΕΟΔΩΡ',
#               'ΣΤΡΙΦΤΑΡ'],
#              'ΤΑΛΙΑΔΟΥΡ': ['ΨΗΦΟΔΟΧ', 'ΚΥΡΙ', 'ΣΠΥΡ', 'ΨΗΦ', 'Κ', 'ΣΠΥΡΙΔ'],
#              'ΔΗΜΗΤΡΙ': ['ΤΑΛΙΑΔΟΥΡ',
#               'ΝΕ',
#               'ΔΗΜΟΚΡΑΤΙ',
#               'ΝΙΚ',
#               'ΚΑΛΟΥΔ',
#               'ΑΝΔΡΟΥΛΑΚ',
#               'ΚΟΤΑΜΑΝΙΔ',
#               'ΕΥΑΓΓΕΛΙ',
#               'ΚΩΣΤΟΠΟΥΛ'],
#              'ΡΕΠΠ': ['ΝΕ', 'ΔΗΜΟΚΡΑΤΙ', 'ΔΗΜΗΤΡΙ', 'Κ', 'ΣΤΑΥΡ', 'Κ'],
#              'ΠΑΡΑΚΑΛ': ['ΔΗΜΗΤΡΙ',
#               'ΡΕΠΠ',
#               'ΠΑΣΟΚ',
#               'ΚΑΘΗΚΟΝ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΚΗΡΥΣΣΕΤΑ',
#               'ΠΕΡΑΙΩΜΕΝ',
#               'ΨΗΦΟΦΟΡΙ',
#               '123',
#               'ΑΚΥΡ',
#               '4',
#               'ΑΝΑΓΝΩΣΤΟΠΟΥΛ',
#               '166',
#               'ΨΗΦ',
#               'μωραϊτησ',
#               '155',
#               'ΨΗΦ',
#               'ΠΑΠΑΝΔΡΕ',
#               'ΠΡΑΚΤΙΚ',
#               'ΒΟΥΛ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΔΙΑΒΑΣ',
#               'ΑΓΑΠΗΤ',
#               'ΚΥΡΙ',
#               'ΠΡΟΕΔΡ'],
#              'ΑΝΑΓΝΩΣ': ['ΠΑΣΟΚ', 'ΠΑΡΑΚΑΛ', 'ΑΡΧΙΣ'],
#              'ΕΠΟΠΤΕΥΟΝΤ': ['ΠΑΡΑΚΑΛΟΥΝΤΑ', 'ΚΥΡΙ', 'ΨΗΦΟΛΕΚΤ'],
#              'ΣΩΤΗΡΟΠΟΥΛ': ['ΕΠΟΠΤΕΥΟΝΤ', 'ΣΥΝΑΔΕΛΦ', 'Κ'],
#              'ΠΡΟΧΩΡΗΣ': ['ΣΥΝΑΔΕΛΦ', 'Κ', 'ΣΩΤΗΡΟΠΟΥΛ'],
#              'ΠΡΟΗΓΟΥΜΕΝ': ['ΨΗΦΟΔΕΛΤΙ', 'ΕΞΑΓΩΓ', 'ΑΠΟΤΕΛΕΣΜΑΤ'],
#              'ΔΙΑΔΙΚΑΣΙ': ['ΕΞΑΓΩΓ',
#               'ΑΠΟΤΕΛΕΣΜΑΤ',
#               'ΠΡΟΗΓΟΥΜΕΝ',
#               'ΠΟΛΙΤΙΚ',
#               'ΠΡΟΣΩΠ',
#               'ΟΓΔΟ'],
#              'ΕΠΙΣΤΟΛ': ['ΤΙΜ', 'ΑΝΑΚΟΙΝΩΣ', 'ΣΩΜ'],
#              'ΣΥΝΑΣΠΙΣΜ': ['ΣΩΜ',
#               'ΕΠΙΣΤΟΛ',
#               'ΒΟΥΛΕΥΤ',
#               'ΒΟΥΛ',
#               'ΚΟΙΝΟΒΟΥΛΕΥΤΙΚ',
#               'ΟΜΑΔ'],
#              'ΑΡΙΣΤΕΡ': ['ΕΠΙΣΤΟΛ',
#               'ΒΟΥΛΕΥΤ',
#               'ΣΥΝΑΣΠΙΣΜ',
#               'ΟΜΑΔ',
#               'ΣΥΝΑΣΠΙΣΜ',
#               'ΤΗΣ'],
#              'ΠΡΟΟΔ': ['ΒΟΥΛΕΥΤ', 'ΣΥΝΑΣΠΙΣΜ', 'ΑΡΙΣΤΕΡ'],
#              'ΑΠΕΥΘΥΝΕΤΑ': ['ΣΥΝΑΣΠΙΣΜ', 'ΑΡΙΣΤΕΡ', 'ΠΡΟΟΔ'],
#              'ΠΡΟΕΔΡΕΙ': ['ΑΡΙΣΤΕΡ',
#               'ΠΡΟΟΔ',
#               'ΑΠΕΥΘΥΝΕΤΑ',
#               'Π',
#               'Ρ',
#               'Σ',
#               'ΚΑΤΑΛΑΒ',
#               'ΠΡΟΕΔΡΙΚ',
#               'ΕΔΡ',
#               'ΠΑΡΑΚΑΛ',
#               'ΒΟΥΛ',
#               'ΕΞΟΥΣΙΟΔΟΤΗΣ',
#               'ΨΗΦΟΔΟΧ',
#               'ΚΑΘΙΣ',
#               'ΕΔΡΑΝ'],
#              'Π': ['ΑΠΕΥΘΥΝΕΤΑ',
#               'ΠΡΟΕΔΡΕΙ',
#               'ΒΟΥΛ',
#               'ε`',
#               'ΠΕΡΙΟΔ',
#               'ΒΟΥΛ',
#               'Β',
#               'ΑΡΙΘ',
#               '329/3689',
#               'ΣΑΡΤΖΕΤΑΚ',
#               'ΠΡΩΘΥΠΟΥΡΓ',
#               'ΤΖΑΝΝ'],
#              'Ρ': ['ΠΡΟΕΔΡΕΙ',
#               'ΒΟΥΛ',
#               'Π',
#               'ΠΕΡΙΟΔ',
#               'ΒΟΥΛ',
#               'Π',
#               'Ρ',
#               '',
#               'Δ',
#               'ΠΡΟΤΑΣ',
#               'ΠΡΩΘΥΠΟΥΡΓ',
#               'Κ'],
#              'Σ': ['ΒΟΥΛ',
#               'Π',
#               'Ρ',
#               '',
#               'Δ',
#               'Ρ',
#               'Κ',
#               'Ρ',
#               'Ρ',
#               'Υ',
#               'Υ',
#               'Σ',
#               'ΘΕΤ',
#               'ΒΟΥΛ',
#               'ΕΠΙΣΥΝΑΠΤΟΜΕΝ',
#               'ΚΙΝΗΜΑΤ',
#               'Δ',
#               'Λ'],
#              'ΠΑΡΑΚΑΤ': ['Σ', 'ΠΡΟΕΔΡΕΙ', 'ΒΟΥΛ'],
#              'ΔΗΛΩΝΟΥΜ': ['ΒΟΥΛ',
#               'ΠΑΡΑΚΑΤ',
#               'ΒΟΥΛΕΥΤ',
#               'ΠΛΕΙΟΨΗΦΙ',
#               'ΒΟΥΛ',
#               'ΠΛΕΥΡ',
#               'ΜΙΣΑΛΛΟΔΟΞΙ',
#               'ΡΕΒΑΝΣΙΣΜ',
#               'ΜΕΛΛΟΝ'],
#              'ΣΥΓΚΡΟΤΟΥΜ': ['ΠΑΡΑΚΑΤ', 'ΒΟΥΛΕΥΤ', 'ΔΗΛΩΝΟΥΜ'],
#              'ΚΟΙΝΟΒΟΥΛΕΥΤΙΚ': ['ΔΗΛΩΝΟΥΜ',
#               'ΣΥΓΚΡΟΤΟΥΜ',
#               'ΒΟΥΛ',
#               'ΠΛΑΙΣΙ',
#               'ΚΑΝΟΝ',
#               'ΛΕΙΤΟΥΡΓΙ',
#               'ΣΥΝΕΔΡΙΑΣ',
#               'ΔΙΑΛΥΘΕΙΣ',
#               'ΒΟΥΛ'],
#              'ΟΜΑΔ': ['ΣΥΓΚΡΟΤΟΥΜ', 'ΒΟΥΛ', 'ΚΟΙΝΟΒΟΥΛΕΥΤΙΚ'],
#              'ΤΗΣ': ['ΚΟΙΝΟΒΟΥΛΕΥΤΙΚ',
#               'ΟΜΑΔ',
#               'ΣΥΝΑΣΠΙΣΜ',
#               'ΣΥΝΑΣΠΙΣΜ',
#               'ΤΗΣ',
#               'ΑΡΙΣΤΕΡ',
#               '~εφημερις',
#               '~εφημερις',
#               'ΤΗΣ',
#               'ΚΥΒΕΡΝΗΣ',
#               'Δ',
#               'Ρ',
#               'Σ',
#               'ΙΟΥΛΙ',
#               '1989',
#               'ΠΡΟΕΔΡ'],
#              'προοδου~': ['ΤΗΣ', 'ΑΡΙΣΤΕΡ', 'ΤΗΣ'],
#              'ΧΑΡΙΛΑ': ['ΤΗΣ',
#               'προοδου~',
#               'ΠΡΟΕΔΡ',
#               'ΠΡΟΕΔΡ',
#               'ΧΑΡΙΛΑ',
#               'ΦΛΩΡΑΚ'],
#              'ΦΛΩΡΑΚ': ['προοδου~',
#               'ΠΡΟΕΔΡ',
#               'ΧΑΡΙΛΑ',
#               'ΧΑΡΙΛΑ',
#               'ΦΛΩΡΑΚ',
#               'ΧΑΡΙΛΑ'],
#              'ΛΕΩΝΙΔ': ['ΦΛΩΡΑΚ', 'ΧΑΡΙΛΑ', 'ΦΛΩΡΑΚ'],
#              'ΚΥΡΚ': ['ΧΑΡΙΛΑ', 'ΦΛΩΡΑΚ', 'ΛΕΩΝΙΔ'],
#              'ΝΙΚ': ['ΦΛΩΡΑΚ', 'ΛΕΩΝΙΔ', 'ΚΥΡΚ'],
#              'ΚΑΛΟΥΔ': ['ΛΕΩΝΙΔ', 'ΚΥΡΚ', 'ΝΙΚ'],
#              'ΑΝΔΡΟΥΛΑΚ': ['ΚΥΡΚ', 'ΝΙΚ', 'ΚΑΛΟΥΔ'],
#              'ΓΑΛΑΝ': ['ΚΑΛΟΥΔ', 'ΑΝΔΡΟΥΛΑΚ', 'ΔΗΜΗΤΡΙ'],
#              'ΝΙΚΟΛΑ': ['ΑΝΔΡΟΥΛΑΚ',
#               'ΔΗΜΗΤΡΙ',
#               'ΓΑΛΑΝ',
#               'β`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'Κ'],
#              'ΓΙΑΝΝΑΡ': ['ΔΗΜΗΤΡΙ', 'ΓΑΛΑΝ', 'ΝΙΚΟΛΑ'],
#              'ΓΡΗΓΟΡ': ['ΓΑΛΑΝ',
#               'ΝΙΚΟΛΑ',
#               'ΓΙΑΝΝΑΡ',
#               'ΣΤΡΙΦΤΑΡ',
#               'ΣΠΥΡ',
#               'ΦΑΡΑΚ'],
#              'ΓΙΩΤ': ['ΝΙΚΟΛΑ', 'ΓΙΑΝΝΑΡ', 'ΓΡΗΓΟΡ'],
#              'ΕΥΣΤΑΘΙ': ['ΓΙΑΝΝΑΡ', 'ΓΡΗΓΟΡ', 'ΓΙΩΤ'],
#              'ΔΡΑΓΑΣΑΚ': ['ΕΥΣΤΑΘΙ', 'ΔΑΜΑΝΑΚ', 'ΜΑΡΙ'],
#              'ΔΡΕΤΤΑΚ': ['ΜΑΡΙ', 'ΔΡΑΓΑΣΑΚ', 'ΓΙΑΝΝ'],
#              'ΕΜΜΑΝΟΥΗΛ': ['ΔΡΑΓΑΣΑΚ', 'ΓΙΑΝΝ', 'ΔΡΕΤΤΑΚ'],
#              'ΚΑΠΠ': ['ΓΙΑΝΝ', 'ΔΡΕΤΤΑΚ', 'ΕΜΜΑΝΟΥΗΛ'],
#              'ΚΩΝΣΤΑΝΤΙΝ': ['ΔΡΕΤΤΑΚ',
#               'ΕΜΜΑΝΟΥΗΛ',
#               'ΚΑΠΠ',
#               'ΑΘΑΝΑΣΙΟΣΣΕΛΙΔ',
#               '0007',
#               'ΡΗΓ',
#               '167',
#               'ΨΗΦ',
#               'Κ'],
#              'ΚΑΤΣΑΡ': ['ΕΜΜΑΝΟΥΗΛ',
#               'ΚΑΠΠ',
#               'ΚΩΝΣΤΑΝΤΙΝ',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'Κ',
#               'ΝΙΚΟΛΑ'],
#              'ΚΟΡΑΚ': ['ΚΩΝΣΤΑΝΤΙΝ', 'ΚΑΤΣΑΡ', 'ΙΩΑΝΝ'],
#              'ΕΥΣΤΡΑΤΙ': ['ΚΑΤΣΑΡ', 'ΙΩΑΝΝ', 'ΚΟΡΑΚ'],
#              'ΚΟΣΙΩΝ': ['ΙΩΑΝΝ', 'ΚΟΡΑΚ', 'ΕΥΣΤΡΑΤΙ'],
#              'ΚΟΤΑΜΑΝΙΔ': ['ΕΥΣΤΡΑΤΙ', 'ΚΟΣΙΩΝ', 'ΠΑΝΑΓΙΩΤ'],
#              'ΕΥΑΓΓΕΛΙ': ['ΚΟΣΙΩΝ', 'ΠΑΝΑΓΙΩΤ', 'ΚΟΤΑΜΑΝΙΔ'],
#              'ΚΩΣΤΟΠΟΥΛ': ['ΠΑΝΑΓΙΩΤ', 'ΚΟΤΑΜΑΝΙΔ', 'ΕΥΑΓΓΕΛΙ'],
#              'ΛΕΒΕΝΤ': ['ΕΥΑΓΓΕΛΙ', 'ΚΩΣΤΟΠΟΥΛ', 'ΔΗΜΗΤΡΙ'],
#              'ΛΕΝΤΑΚ': ['ΔΗΜΗΤΡΙ', 'ΛΕΒΕΝΤ', 'ΑΘΑΝΑΣΙ'],
#              'ΑΝΔΡΕ': ['ΛΕΒΕΝΤ',
#               'ΑΘΑΝΑΣΙ',
#               'ΛΕΝΤΑΚ',
#               'ΠΡΟΕΔΡ',
#               'ΠΑΣΟΚ',
#               'Κ',
#               'ΚΑΤΑΧΩΡΗΘ',
#               'ΠΡΑΚΤΙΚ',
#               'ΤΙΜ'],
#              'ΜΠΙΤΣΑΝ': ['ΑΘΑΝΑΣΙ', 'ΛΕΝΤΑΚ', 'ΑΝΔΡΕ'],
#              'ΗΛΙ': ['ΛΕΝΤΑΚ', 'ΑΝΔΡΕ', 'ΜΠΙΤΣΑΝ'],
#              'ΝΕΣΤΩΡ': ['ΑΝΔΡΕ', 'ΜΠΙΤΣΑΝ', 'ΗΛΙ'],
#              'ΣΤΥΛΙΑΝ': ['ΜΠΙΤΣΑΝ', 'ΗΛΙ', 'ΝΕΣΤΩΡ'],
#              'ΠΑΦΙΛ': ['ΗΛΙ', 'ΝΕΣΤΩΡ', 'ΣΤΥΛΙΑΝ'],
#              'ΑΘΑΝΑΣΙΟΣΣΕΛΙΔ': ['ΝΕΣΤΩΡ', 'ΣΤΥΛΙΑΝ', 'ΠΑΦΙΛ'],
#              '0007': ['ΣΤΥΛΙΑΝ', 'ΠΑΦΙΛ', 'ΑΘΑΝΑΣΙΟΣΣΕΛΙΔ'],
#              'ΡΗΓ': ['ΠΑΦΙΛ', 'ΑΘΑΝΑΣΙΟΣΣΕΛΙΔ', '0007'],
#              'ΣΚΟΤΙΝΙΩΤ': ['0007', 'ΡΗΓ', 'ΚΩΝΣΤΑΝΤΙΝ'],
#              'ΣΚΥΛΑΚ': ['ΚΩΝΣΤΑΝΤΙΝ', 'ΣΚΟΤΙΝΙΩΤ', 'ΠΑΝΑΓΙΩΤ'],
#              'ΑΝΤΩΝ': ['ΣΚΟΤΙΝΙΩΤ', 'ΠΑΝΑΓΙΩΤ', 'ΣΚΥΛΑΚ'],
#              'ΣΠΑΘ': ['ΠΑΝΑΓΙΩΤ', 'ΣΚΥΛΑΚ', 'ΑΝΤΩΝ'],
#              'ΘΕΟΔΩΡ': ['ΣΚΥΛΑΚ',
#               'ΑΝΤΩΝ',
#               'ΣΠΑΘ',
#               'γ`',
#               'ΑΝΤΙΠΡΟΕΔΡ',
#               'Κ',
#               '167',
#               'ΨΗΦ',
#               'Κ'],
#              'ΣΤΡΙΦΤΑΡ': ['ΑΝΤΩΝ', 'ΣΠΑΘ', 'ΘΕΟΔΩΡ'],
#              'ΦΑΡΑΚ': ['ΘΕΟΔΩΡ', 'ΣΤΡΙΦΤΑΡ', 'ΣΠΥΡ'],
#              'ΧΑΤΖΗΔΗΜΗΤΡΙ': ['ΣΠΥΡ', 'ΦΑΡΑΚ', 'ΓΡΗΓΟΡ'],
#              'τραϊανος': ['ΦΑΡΑΚ', 'ΓΡΗΓΟΡ', 'ΧΑΤΖΗΔΗΜΗΤΡΙ'],
#              'ΕΠΑΝΑΛΗΠΤΙΚ': ['ΑΝΑΚΟΙΝΩΣ', 'ΑΠΟΤΕΛΕΣΜ', 'ΔΙΕΞΑΧΘΕΙΣ'],
#              'ΣΥΝΟΛΙΚ': ['ΜΥΣΤΙΚ', 'ΨΗΦΟΦΟΡΙ', 'ΨΗΦΙΣ'],
#              '144': ['Κ', 'ΑΘΑΝΑΣΙ', 'ΤΣΑΛΔΑΡ'],
#              '124': ['Κ', 'ΙΩΑΝΝ', 'ΧΑΡΑΛΑΜΠΟΠΟΥΛ'],
#              'ΣΧΕΤΙΚ': ['30',
#               'ΛΕΥΚ',
#               'ΨΗΦΟΔΕΛΤΙ',
#               'ΣΤΟΙΧΕΙ',
#               'ΔΥΟ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ΠΑΡΕΔΩΣ',
#               'ΔΕΥΤΕΡ',
#               'ΤΟΝΙΣ',
#               'ΤΕΛΕΥΤΑΙ'],
#              'παρ3': ['ΣΥΜΦΩΝ', 'ΑΡΘΡ', '7'],
#              'ΕΔΑΦΙ': ['ΑΡΘΡ', '7', 'παρ3'],
#              '2': ['7',
#               'παρ3',
#               'ΕΔΑΦΙ',
#               'ΒΟΥΛ',
#               'ΣΥΜΦΩΝ',
#               'ΑΡΘΡ',
#               'ΑΡΘΡ',
#               '86',
#               'ΠΑΡ'],
#              'ΕΚΛΕΓΕΤΑ': ['2', 'ΚΑΝΟΝΙΣΜ', 'ΒΟΥΛ'],
#              'ε`': ['ΕΚΛΕΓΕΤΑ',
#               'ΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ΠΑΠΑΔΑΚ',
#               'ΚΑΛΠ',
#               'δ`',
#               'ΜΥΣΤΙΚ',
#               'ΨΗΦΟΦΟΡΙ',
#               'δ`',
#               '155',
#               'ΨΗΦ',
#               'ΑΞΙΩΜ',
#               'α`',
#               'ΤΑΚΤΙΚ',
#               'ΣΥΝΟΔ',
#               'α`',
#               'ΤΑΚΤΙΚ',
#               'ΣΥΝΟΔ'],
#              'ΠΕΡΙΟΔ': ['ΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ε`',
#               'ΚΑΘΟΜΑΣΤ',
#               'ΙΔΙΑΙΤΕΡ',
#               'ΔΙΑΝΥΟΥΜ',
#               'ΤΑΚΤΙΚ',
#               'ΣΥΝΟΔ',
#               'ε`',
#               'δ/τοσ',
#               '~ληξη',
#               'ΒΟΥΛΕΥΤΙΚ',
#               'ΤΑΚΤΙΚ',
#               'ΣΥΝΟΔ',
#               'ε`'],
#              'ΚΑΤΑΛΑΒ': ['ΑΘΑΝΑΣΙ',
#               'ΤΣΑΛΔΑΡ',
#               'ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΠΑΡΑΚΑΛ',
#               'Κ',
#               'ΔΑΜΑΝΑΚ',
#               'ΨΗΦ',
#               'ΠΑΡΑΚΑΛ',
#               'ΕΛΘ',
#               'ΨΗΦ',
#               'ΠΑΡΑΚΑΛ',
#               'ΕΛΘ'],
#              'ΠΡΟΕΔΡΙΚ': ['ΤΣΑΛΔΑΡ',
#               'ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΚΑΤΑΛΑΒ',
#               'ΙΟΥΛΙ',
#               '1989',
#               '182',
#               'ΔΙΑΚΟΠ',
#               'ΛΗΞ',
#               'ΚΑΘΟΡΙΣΤ'],
#              'ΕΔΡ': ['ΠΑΡΑΚΑΛΕΙΤΑ',
#               'ΚΑΤΑΛΑΒ',
#               'ΠΡΟΕΔΡΙΚ',
#               'ΔΑΜΑΝΑΚ',
#               'ΚΑΤΑΛΑΒ',
#               'ΘΕΣ',
#               'ΕΛΘ',
#               'ΚΑΤΑΛΑΒ',
#               'ΘΕΣ',
#               'ΕΛΘ',
#               'ΚΑΤΑΛΑΒ',
#               'ΘΕΣ'],
#              'ΕΥΧΕΤΑ': ['ΠΡΟΕΔΡΙΚ', 'ΕΔΡ', 'ΠΡΟΕΔΡΕΙ'],
#              'ΕΠΙΤΥΧΙ': ['ΕΔΡ', 'ΠΡΟΕΔΡΕΙ', 'ΕΥΧΕΤΑ'],
#              'ΕΡΓ': ['ΠΡΟΕΔΡΕΙ',
#               'ΕΥΧΕΤΑ',
#               'ΕΠΙΤΥΧΙ',
#               'ΛΕΙΤΟΥΡΓΙΚ',
#               'ΟΥΣΙΑΣΤΙΚ',
#               'ΕΞΑΛΕΙΦΘ',
#               'ΒΡΙΣΚΟΝΤΑ',
#               'ΔΙΕΥΘΥΝΣ',
#               'ΝΟΜΟΘΕΤΙΚ'],
#              'ΑΝΑΛΑΜΒΑΝΟΝΤ': ['ΚΥΡΙ', 'ΚΥΡΙ', 'ΣΥΝΑΔΕΛΦ'],
#              'ΠΡΟΕΔΡΙ': ['ΚΥΡΙ', 'ΣΥΝΑΔΕΛΦ', 'ΑΝΑΛΑΜΒΑΝΟΝΤ'],
#              'ΗΘΕΛ': ['ΑΝΑΛΑΜΒΑΝΟΝΤ',
#               'ΠΡΟΕΔΡΙ',
#               'ΣΩΜΑΤ',
#               'ΑΡΧΗΝ',
#               'ΕΥΧΑΡΙΣΤΗΣ',
#               'ΨΗΦΙΣ'],
#              'ΑΡΧΗΝ': ['ΠΡΟΕΔΡΙ', 'ΣΩΜΑΤ', 'ΗΘΕΛ'],
#              'ΕΥΧΑΡΙΣΤΗΣ': ['ΣΩΜΑΤ',
#               'ΗΘΕΛ',
#               'ΑΡΧΗΝ',
#               'ΕΥΧΑΡΙΣΤΗΣ',
#               'ΨΗΦΙΣ',
#               'ΗΘΕΛ'],
#              'ΤΕΚΜΗΡΙ': ['ΗΘΕΛ', 'ΕΥΧΑΡΙΣΤΗΣ', 'ΕΨΗΦΙΣ'],
#              'ΔΗΜΟΚΡΑΤΙΚΟΤΗΤ': ['ΕΥΧΑΡΙΣΤΗΣ', 'ΕΨΗΦΙΣ', 'ΤΕΚΜΗΡΙ'],
#              'ΝΟΜΙΜΟΤΗΤ': ['ΕΨΗΦΙΣ', 'ΤΕΚΜΗΡΙ', 'ΔΗΜΟΚΡΑΤΙΚΟΤΗΤ'],
#              'ΘΕΤΙΚ': ['ΔΗΜΟΚΡΑΤΙΚΟΤΗΤ', 'ΝΟΜΙΜΟΤΗΤ', 'ΕΚΛΟΓ'],
#              'ΑΡΝΗΤΙΚ': ['ΝΟΜΙΜΟΤΗΤ', 'ΕΚΛΟΓ', 'ΘΕΤΙΚ'],
#              'ΠΙΣΤΟΠΟΙ': ['ΘΕΤΙΚ', 'ΑΡΝΗΤΙΚ', 'ΨΗΦ'],
#              'ΣΥΣΤΗΜ': ['ΑΡΝΗΤΙΚ', 'ΨΗΦ', 'ΠΙΣΤΟΠΟΙ'],
#              'ΛΕΙΤΟΥΡΓ': ['ΨΗΦ', 'ΠΙΣΤΟΠΟΙ', 'ΣΥΣΤΗΜ'],
#              'ΠΡΟΣΩΠ': ['ΛΕΙΤΟΥΡΓ', 'ΠΡΟΕΔΡ', 'ΒΟΥΛ', 'ΘΙΓ', 'ΤΙΜ', 'ΠΟΛΙΤΙΚ'],
#              'ΥΠΕΡΚΟΜΜΑΤΙΚ': ['ΠΡΟΕΔΡ',
#               'ΒΟΥΛ',
#               'ΠΡΟΣΩΠ',
#               'ΠΑΙΞ',
#               'ΠΛΑΙΣΙ',
#               'ΠΟΛΙΤΕΥΜΑΤ'],
#              'ΠΡΟΕΡΧΕΤΑ': ['ΒΟΥΛ', 'ΠΡΟΣΩΠ', 'ΥΠΕΡΚΟΜΜΑΤΙΚ'],
#              'ΠΑΡΑΤΑΞ': ['ΠΡΟΣΩΠ',
#               'ΥΠΕΡΚΟΜΜΑΤΙΚ',
#               'ΠΡΟΕΡΧΕΤΑ',
#               'ΣΥΜΦΕΡ',
#               'ΧΩΡ',
#               'ΣΥΜΦΕΡ'],
#              'ΡΟΛ': ['ΥΠΕΡΚΟΜΜΑΤΙΚ',
#               'ΠΡΟΕΡΧΕΤΑ',
#               'ΠΑΡΑΤΑΞ',
#               'ΑΝΤΙΚΕΙΜΕΝΙΚ',
#               'ΑΜΕΡΟΛΗΠΤ',
#               'ΑΠΑΙΤΗΣ'],
#              'ΚΑΛΕΙΤΑ': ['ΠΡΟΕΡΧΕΤΑ', 'ΠΑΡΑΤΑΞ', 'ΡΟΛ'],
#              'ΠΑΙΞ': ['ΠΑΡΑΤΑΞ', 'ΡΟΛ', 'ΚΑΛΕΙΤΑ'],
#              'ΠΛΑΙΣΙ': ['ΡΟΛ',
#               'ΚΑΛΕΙΤΑ',
#               'ΠΑΙΞ',
#               'ΤΑΣΕ',
#               'ΛΑ',
#               'ΑΝΑΓΚΑΙ',
#               'ΖΩ',
#               'ΕΞΕΛΙΞ',
#               'ΑΔΙΑΝΟΗΤ'],
#              'ΠΟΛΙΤΕΥΜΑΤ': ['ΚΑΛΕΙΤΑ',
#               'ΠΑΙΞ',
#               'ΠΛΑΙΣΙ',
#               'ΠΡΟΣΗΛΩΜΕΝ',
#               'ΚΑΝΟΝ',
#               'ΛΕΙΤΟΥΡΓΙ'],
# ...
#               'ΣΥΝΑΔΕΛΦ',
#               'ΑΝΑΚΟΙΝΟΥΤΑ',
#               'ΕΙΣΑΓΓΕΛΕ'],
#              'ΑΝΑΚΡΙΤ': ['294/13689',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΕΦΕΤ',
#               '293',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΕΦΕΤ',
#               '294',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΕΦΕΤ'],
#              'Γ': ['ΕΦΕΤ',
#               'ΑΝΑΚΡΙΤ',
#               'ΚΥΡΙ',
#               'ΠΡΑΚΤΙΚ',
#               'ΤΙΜ',
#               'ΑΝΔΡΕ',
#               'ΠΡΟΕΔΡ',
#               'ΠΑΣΟΚ',
#               '',
#               'ΠΡΟΕΔΡ',
#               'πασοκ~',
#               ''],
#              'ΣΚΑΡΛΑΤ': ['ΑΝΑΚΡΙΤ', 'ΚΥΡΙ', 'Γ', 'ΑΝΑΚΡΙΤ', 'Κ', 'ΓΕΩΡΓΙ'],
#              'ΚΡΟΥΣΤΑΛΛΑΚ': ['Γ', 'ΣΚΑΡΛΑΤ', '', 'ΕΦΕΤ', 'ΑΝΑΚΡΙΤ', 'Κ'],
#              'ΣΥΝΟΔΕΥΟΜΕΝ': ['ΣΚΑΡΛΑΤ', '', 'ΚΡΟΥΣΤΑΛΛΑΚ'],
#              'ΦΩΤΟΤΥΠΙ': ['ΚΡΟΥΣΤΑΛΛΑΚ', 'ΣΥΝΟΔΕΥΟΜΕΝ', 'ΚΑΤΑΣΤΑΣ'],
#              'ΑΠΟΔΕΙΚΤΙΚ': ['ΣΥΝΟΔΕΥΟΜΕΝ',
#               'ΚΑΤΑΣΤΑΣ',
#               'ΦΩΤΟΤΥΠΙ',
#               'ΒΟΥΛ',
#               'ΕΠΙΣΥΝΑΠΤΟΜΕΝ',
#               'σ`',
#               'ΒΟΥΛ',
#               'ΕΠΙΣΥΝΑΠΤΟΜΕΝ',
#               'Σ'],
#              'ΣΤΟΙΧΕΙ': ['ΚΑΤΑΣΤΑΣ',
#               'ΦΩΤΟΤΥΠΙ',
#               'ΑΠΟΔΕΙΚΤΙΚ',
#               'ΔΥΟ',
#               'ΑΝΑΚΟΙΝΩΣ',
#               'ΣΧΕΤΙΚ',
#               'ΕΠΙΣΥΝΑΠΤΟΜΕΝ',
#               'σ`',
#               'ΑΠΟΔΕΙΚΤΙΚ',
#               'ΕΠΙΣΥΝΑΠΤΟΜΕΝ',
#               'Σ',
#               'ΑΠΟΔΕΙΚΤΙΚ'],
#              'ΠΑΡΑΔΟΘ': ['ΑΝΑΚΟΙΝΩΣ', 'ΣΧΕΤΙΚ', 'ΣΤΟΙΧΕΙ'],
#              'ΠΡΟΚΑΤΟΧ': ['ΣΥΓΚΛΗΣ', 'ΠΑΡΟΥΣ', 'ΒΟΥΛ'],
#              'ΑΝΑΔΕΙΞ': ['ΒΟΥΛ', 'Κ', 'ΑΛΕΥΡ'],
#              'ΠΑΡΕΔΩΣ': ['ΑΝΑΔΕΙΞ', 'ΠΡΟΕΔΡ', 'ΒΟΥΛ'],
#              'ΦΑΚΕΛ': ['ΒΟΥΛ', 'ΠΑΡΕΔΩΣ', 'ΣΧΕΤΙΚ', 'ΠΕΤΣ', 'ΤΙΜ', 'ΚΑΤΑΘΕΣ'],
#              'ΘΕΤ': ['Κ', 'ΓΕΩΡΓΙ', 'ΣΚΑΡΛΑΤ', 'ΑΝΑΚΡΙΤ', 'Κ', 'ΚΡΟΥΣΤΑΛΛΑΚ'],
#              'ΕΠΙΣΥΝΑΠΤΟΜΕΝ': ['ΣΚΑΡΛΑΤ',
#               'ΘΕΤ',
#               'ΒΟΥΛ',
#               'ΚΡΟΥΣΤΑΛΛΑΚ',
#               'ΘΕΤ',
#               'ΒΟΥΛ'],
#              'σ`': ['ΘΕΤ', 'ΒΟΥΛ', 'ΕΠΙΣΥΝΑΠΤΟΜΕΝ'],
#              'ΑΠΟΦΑΣΙΣ': ['σ`', 'ΑΠΟΔΕΙΚΤΙΚ', 'ΣΤΟΙΧΕΙ'],
#              'ΑΡΜΟΔΙΟΤΗΤ': ['ΑΠΟΔΕΙΚΤΙΚ',
#               'ΣΤΟΙΧΕΙ',
#               'ΑΠΟΦΑΣΙΣ',
#               'ΔΙΕΒΙΒΑΣ',
#               'ΒΟΥΛ',
#               'ΕΛΛΗΝ'],
#              'ΣΥΝΤΡΕΧ': ['ΣΤΟΙΧΕΙ', 'ΑΠΟΦΑΣΙΣ', 'ΑΡΜΟΔΙΟΤΗΤ'],
#              'ΠΕΡΙΠΤΩΣ': ['ΑΠΟΦΑΣΙΣ', 'ΑΡΜΟΔΙΟΤΗΤ', 'ΣΥΝΤΡΕΧ'],
#              'ΠΟΙΝΙΚ': ['ΑΡΜΟΔΙΟΤΗΤ', 'ΣΥΝΤΡΕΧ', 'ΠΕΡΙΠΤΩΣ'],
#              'ΔΙΩΞ': ['ΣΥΝΤΡΕΧ', 'ΠΕΡΙΠΤΩΣ', 'ΠΟΙΝΙΚ'],
#              'ΠΡΩΗΝ': ['ΠΕΡΙΠΤΩΣ',
#               'ΠΟΙΝΙΚ',
#               'ΔΙΩΞ',
#               'ΤΕΛΕΣ',
#               'ΑΞΙΟΠΟΙΝ',
#               'ΠΡΑΞΕ',
#               'Κ',
#               'ΓΕΩΡΓΙ',
#               'ΜΑΣΤΟΡ',
#               'ΠΡΑΞ',
#               'ΦΕΡΟΝΤΑ',
#               'ΤΕΛΕΣΘΕΙΣ'],
#              'ΑΓΑΜΕΜΝΟΝ': ['ΠΡΩΗΝ', 'ΥΠΟΥΡΓ', 'ΚΥΡΙ'],
#              'ΚΟΥΤΣΟΓΙΩΡΓ': ['ΥΠΟΥΡΓ', 'ΚΥΡΙ', 'ΑΓΑΜΕΜΝΟΝ'],
#              'ΠΕΤΣ': ['ΑΓΑΜΕΜΝΟΝ',
#               'ΚΟΥΤΣΟΓΙΩΡΓ',
#               'ΓΕΩΡΓΙ',
#               'ΥΠΟΥΡΓ',
#               'Κ',
#               'ΓΕΩΡΓΙ'],
#              '294': ['ΚΟΥΤΣΟΓΙΩΡΓ', 'ΓΕΩΡΓΙ', 'ΠΕΤΣ'],
#              'ΤΕΛΕΣ': ['Σ', 'ΑΠΟΔΕΙΚΤΙΚ', 'ΣΤΟΙΧΕΙ'],
#              'ΑΞΙΟΠΟΙΝ': ['ΑΠΟΔΕΙΚΤΙΚ',
#               'ΣΤΟΙΧΕΙ',
#               'ΤΕΛΕΣ',
#               'ΑΝΑΦΕΡΟΜΕΝ',
#               'ΠΑΡΑΠΑΝ',
#               'ΕΓΓΡΑΦ'],
#              'ΠΡΑΞΕ': ['ΣΤΟΙΧΕΙ', 'ΤΕΛΕΣ', 'ΑΞΙΟΠΟΙΝ'],
#              'ΚΑΤΑΘΕΣ': ['ΓΕΩΡΓΙ',
#               'ΠΕΤΣ',
#               'ΤΙΜ',
#               'ΔΙΟΧΕΤΕΥ',
#               'ΑΟΡΙΣΤ',
#               'ΚΑΤΗΓΟΡΙ'],
#              'ΔΙΑΝΕΜΗΘ': ['ΚΑΤΑΘΕΣ', 'ΦΑΚΕΛ', 'ΒΟΥΛ'],
#              'ΑΝΑΚΟΙΝΟΥΤΑ': ['ΔΙΑΝΕΜΗΘ', 'ΚΥΡΙ', 'ΣΥΝΑΔΕΛΦ'],
#              'ΕΙΣΑΓΓΕΛΕ': ['ΚΥΡΙ', 'ΣΥΝΑΔΕΛΦ', 'ΑΝΑΚΟΙΝΟΥΤΑ'],
#              'ΔΩΡ': ['ΕΦΕΤ', 'ΑΘΗΝ', 'Κ'],
#              'ΔΙΕΒΙΒΑΣ': ['ΑΘΗΝ', 'Κ', 'ΔΩΡ'],
#              'ΕΛΛΗΝ': ['ΔΩΡ', 'ΔΙΕΒΙΒΑΣ', 'ΒΟΥΛ'],
#              'ΚΑΤΑΓΓΕΛΙ': ['ΒΟΥΛ', 'ΕΛΛΗΝ', 'ΑΡΜΟΔΙΟΤΗΤ'],
#              'ΙΔΙΩΤ': ['ΕΛΛΗΝ', 'ΑΡΜΟΔΙΟΤΗΤ', 'ΚΑΤΑΓΓΕΛΙ'],
#              'ΜΑΣΤΟΡ': ['ΙΔΙΩΤ', 'Κ', 'ΓΕΩΡΓΙ'],
#              'ΤΣΟΒΟΛ': ['ΠΡΩΗΝ', 'ΥΠΟΥΡΓ', 'Κ'],
#              'ΥΠΗΡΕΣΙΑΚ': ['ΥΠΟΥΡΓ', 'Κ', 'ΤΣΟΒΟΛ'],
#              'ΑΝΤΙΓΡΑΦ': ['Κ', 'ΤΣΟΒΟΛ', 'ΥΠΗΡΕΣΙΑΚ'],
#              'ΜΗΝΥΣ': ['ΤΣΟΒΟΛ', 'ΥΠΗΡΕΣΙΑΚ', 'ΑΝΤΙΓΡΑΦ'],
#              'ΛΑΓ': ['ΑΝΤΙΓΡΑΦ', 'ΜΗΝΥΣ', 'Κ'],
#              'ΔΕΔΟΜΕΝ': ['Κ', 'ΛΑΓ', 'ΥΠΟΥΡΓ'],
#              'ΑΝΑΦΕΡΟΜΕΝ': ['ΛΑΓ', 'ΥΠΟΥΡΓ', 'ΔΕΔΟΜΕΝ'],
#              'ΠΑΡΑΠΑΝ': ['ΥΠΟΥΡΓ', 'ΔΕΔΟΜΕΝ', 'ΑΝΑΦΕΡΟΜΕΝ'],
#              'ΕΓΓΡΑΦ': ['ΔΕΔΟΜΕΝ',
#               'ΑΝΑΦΕΡΟΜΕΝ',
#               'ΠΑΡΑΠΑΝ',
#               'ΥΠΟΥΡΓ',
#               'ΕΚΤΕΛΕΣ',
#               'ΚΑΘΗΚΟΝΤ'],
#              'ΚΑΤΑΓΓΕΛΛΟΝΤ': ['ΠΑΡΑΠΑΝ', 'ΕΓΓΡΑΦ', 'ΑΞΙΟΠΟΙΝ'],
#              'ΠΡΑΞ': ['ΕΓΓΡΑΦ', 'ΑΞΙΟΠΟΙΝ', 'ΚΑΤΑΓΓΕΛΛΟΝΤ'],
#              'ΦΕΡΟΝΤΑ': ['ΑΞΙΟΠΟΙΝ', 'ΚΑΤΑΓΓΕΛΛΟΝΤ', 'ΠΡΑΞ'],
#              'ΤΕΛΕΣΘΕΙΣ': ['ΚΑΤΑΓΓΕΛΛΟΝΤ', 'ΠΡΑΞ', 'ΦΕΡΟΝΤΑ'],
#              'ΕΚΤΕΛΕΣ': ['ΤΕΛΕΣΘΕΙΣ', 'ΠΡΩΗΝ', 'ΥΠΟΥΡΓ'],
#              'ΒΡΙΣΚΟΝΤΑ': ['ΕΚΤΕΛΕΣ',
#               'ΚΑΘΗΚΟΝΤ',
#               'ΕΓΓΡΑΦ',
#               'ΕΠΙΦΑΝΕΙ',
#               'ΠΡΑΓΜΑΤΙΚ',
#               'ΕΝΟΧ'],
#              'ΔΙΕΥΘΥΝΣ': ['ΚΑΘΗΚΟΝΤ', 'ΕΓΓΡΑΦ', 'ΒΡΙΣΚΟΝΤΑ'],
#              'ΝΟΜΟΘΕΤΙΚ': ['ΕΓΓΡΑΦ',
#               'ΒΡΙΣΚΟΝΤΑ',
#               'ΔΙΕΥΘΥΝΣ',
#               'ΤΕΤΑΡΤ',
#               'ΚΑΘΑΡΣ',
#               'προϋποθετει'],
#              'ΕΝΔΙΑΦΕΡΟΜΕΝ': ['ΔΙΕΥΘΥΝΣ', 'ΝΟΜΟΘΕΤΙΚ', 'ΕΡΓ'],
#              'ΛΑΒ': ['ΕΡΓ',
#               'ΕΝΔΙΑΦΕΡΟΜΕΝ',
#               'ΒΟΥΛΕΥΤ',
#               'ΠΑΡΑΚΑΛ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ'],
#              'ΓΝΩΣ': ['ΕΝΔΙΑΦΕΡΟΜΕΝ',
#               'ΒΟΥΛΕΥΤ',
#               'ΛΑΒ',
#               'ΚΥΡΙ',
#               'ΣΥΝΑΔΕΛΦ',
#               'ΛΑΒ'],
#              'ΚΑΤΑΘΕΤ': ['ΒΟΥΛΕΥΤ', 'ΛΑΒ', 'ΓΝΩΣ'],
#              'ΔΗΛΩΣ': ['ΛΑΒ',
#               'ΓΝΩΣ',
#               'ΚΑΤΑΘΕΤ',
#               'ΑΝΑΓΝΩΣΘ',
#               'ΣΩΜ',
#               'ΕΣΩΚΛΕΙΣΤ'],
#              'ΠΑΠΑΝΔΡΕ': ['ΠΑΣΟΚ',
#               'Κ',
#               'ΑΝΔΡΕ',
#               'ΤΙΜ',
#               'ΑΝΔΡΕ',
#               'Γ',
#               'ΠΑΣΟΚ',
#               '',
#               'Γ'],
#              'ΔΙΑΚΟΠΤΕΤ': ['ΣΥΝΑΔΕΛΦ', 'ΔΙΑΒΑΣ', 'ΠΑΡΑΚΑΛ'],
#              'ΠΡΟΚΑΛΕΣ': ['ΔΙΑΚΟΠΤΕΤ', 'ΔΙΑΒΑΣ', 'ΔΙΟΤ'],
#              'ΣΥΖΗΤΗΣ': ['ΔΙΑΒΑΣ',
#               'ΔΙΟΤ',
#               'ΠΡΟΚΑΛΕΣ',
#               'ΣΥΖΗΤΗΣ',
#               'ΕΠΙΤΡΕΠΕΤΑ',
#               'ΓΙΝ'],
#              'ΕΠΙΤΡΕΠΕΤΑ': ['ΔΙΟΤ', 'ΠΡΟΚΑΛΕΣ', 'ΣΥΖΗΤΗΣ'],
#              '360983135': ['ΕΠΙΤΡΕΠΕΤΑ', 'ΓΙΝ', 'ΣΥΖΗΤΗΣ'],
#              'ΜΕΓΑΡ': ['ΚΥΡΙ', 'ΑΘΑΝΑΣΙ', 'ΤΣΑΛΔΑΡ'],
#              'ΑΓΑΠΗΤ': ['ΤΣΑΛΔΑΡ', 'ΜΕΓΑΡ', 'ΒΟΥΛ'],
#              'ΑΝΑΓΝΩΣΘ': ['ΚΥΡΙ', 'ΠΡΟΕΔΡ', 'ΠΑΡΑΚΑΛ'],
#              'ΕΣΩΚΛΕΙΣΤ': ['ΠΑΡΑΚΑΛ', 'ΑΝΑΓΝΩΣΘ', 'ΣΩΜ'],
#              'ΚΑΤΑΧΩΡΗΘ': ['ΣΩΜ', 'ΕΣΩΚΛΕΙΣΤ', 'ΔΗΛΩΣ'],
#              'ΠΑΝΕΛΛΗΝΙ': ['Γ', 'ΠΑΠΑΝΔΡΕ', 'ΠΡΟΕΔΡ'],
#              'ΣΟΣΙΑΛΙΣΤΙΚ': ['ΠΑΠΑΝΔΡΕ', 'ΠΡΟΕΔΡ', 'ΠΑΝΕΛΛΗΝΙ'],
#              'ΚΙΝΗΜΑΤ': ['ΠΡΟΕΔΡ', 'ΠΑΝΕΛΛΗΝΙ', 'ΣΟΣΙΑΛΙΣΤΙΚ'],
#              'Λ': ['ΣΟΣΙΑΛΙΣΤΙΚ', 'ΚΙΝΗΜΑΤ', 'Δ'],
#              'ΑΡΝΕΙΤΑ': ['Γ', 'ΠΑΠΑΝΔΡΕ', 'ΚΥΒΕΡΝΗΣ'],
#              'ΠΡΟΣΧΗΜ': ['ΚΥΒΕΡΝΗΣ', 'ΑΡΝΕΙΤΑ', 'ΚΥΒΕΡΝΗΣ'],
#              'ΚΑΘΑΡΣ': ['ΑΡΝΕΙΤΑ',
#               'ΚΥΒΕΡΝΗΣ',
#               'ΠΡΟΣΧΗΜ',
#               'ΚΑΘΑΡΣ',
#               'ΥΠΟΧΡΕΩΜΕΝ',
#               'ΑΡΝΗΘ',
#               'ΤΙΤΛ',
#               'ΑΞΙΩΜΑΤ',
#               'ΤΡΙΤ',
#               'ΕΚΤΟΞΕΥΣ',
#               'ΚΑΤΗΓΟΡΙ',
#               'ΤΕΤΑΡΤ',
#               'ΔΙΑΦΟΡ',
#               'ΛΟΓ',
#               'ΟΛΟΚΛΗΡΩΣ',
#               'ΔΙΑΣΦΑΛΙΖ',
#               'ΕΝΟΤΗΤ',
#               'ΘΕΜ'],
#              'ΥΠΟΧΡΕΩΜΕΝ': ['ΚΥΒΕΡΝΗΣ', 'ΠΡΟΣΧΗΜ', 'ΚΑΘΑΡΣ'],
#              'ΑΡΝΗΘ': ['ΠΡΟΣΧΗΜ', 'ΚΑΘΑΡΣ', 'ΥΠΟΧΡΕΩΜΕΝ'],
#              'ΠΛΕΥΡ': ['ΔΙΑΣΦΑΛΙΣ', 'ΠΛΕΙΟΨΗΦΙ', 'ΒΟΥΛ'],
#              'ΚΑΤΗΓΟΡΗΜΑΤΙΚ': ['ΒΟΥΛ', 'ΠΛΕΥΡ', 'ΔΗΛΩΝΟΥΜ'],
#              'ΚΑΛΟΥΜ': ['ΚΑΤΗΓΟΡΗΜΑΤΙΚ', 'ΤΡΟΠ', 'ΠΡΩΤ'],
#              'ΚΟΜΜΑΤΙΚ': ['ΤΡΟΠ',
#               'ΠΡΩΤ',
#               'ΚΑΛΟΥΜ',
#               'ΑΠΟΦΑΣΕ',
#               'ΕΙΔΙΚ',
#               'ΔΙΚΑΣΤΗΡΙ',
#               'ΕΝΤΥΠΩΣ',
#               'ΛΑΣΠΟΜΑΧΙ',
#               'ΛΟΓ'],
#              'ΔΥΝΑΜ': ['ΠΡΩΤ',
#               'ΚΑΛΟΥΜ',
#               'ΚΟΜΜΑΤΙΚ',
#               'ΚΟΙΝΟΒΟΥΛΕΥΤΙΚ',
#               'ΕΚΠΡΟΣΩΠ',
#               'ΣΥΝΔΡΑΜΟΥΜ'],
#              'ΔΙΟΧΕΤΕΥ': ['ΚΑΛΟΥΜ', 'ΚΟΜΜΑΤΙΚ', 'ΔΥΝΑΜ'],
#              'ΑΟΡΙΣΤ': ['ΚΟΜΜΑΤΙΚ', 'ΔΥΝΑΜ', 'ΔΙΟΧΕΤΕΥ'],
#              'ΚΑΤΗΓΟΡΙ': ['ΔΥΝΑΜ',
#               'ΔΙΟΧΕΤΕΥ',
#               'ΑΟΡΙΣΤ',
#               'ΕΥΘΥΝ',
#               'ΥΠΟΥΡΓ',
#               'ΣΥΓΚΕΚΡΙΜΕΝ',
#               'ΠΛΕΙΟΨΗΦΙ',
#               'ΑΠΛ',
#               'ΕΚΤΟΞΕΥΣ'],
#              'ΚΙΝΗΣ': ['ΚΑΤΗΓΟΡΙ',
#               'ΚΑΤΑΘΕΣ',
#               'ΠΡΟΤΑΣ',
#               'ΒΟΥΛ',
#               'ΠΛΗΡ',
#               'ΔΙΕΛΕΥΚΑΝΣ'],
#              'ΕΥΘΥΝ': ['ΠΡΟΤΑΣ',
#               'ΚΙΝΗΣ',
#               'ΝΟΜ',
#               'ΔΙΕΛΕΥΚΑΝΣ',
#               'ΚΙΝΗΣ',
#               'ΝΟΜ',
#               'ΠΟΛΙΤΙΚ',
#               'ΚΟΣΜ',
#               'ΠΟΛΙΤΙΚ',
#               'ΥΠΕΥΘΥΝ',
#               'ΑΚΥΒΕΡΝΗΣΙ',
#               'ΣΥΓΚΑΛΥΨ'],
#              'ΡΥΘΜΙΣ': ['ΑΡΘΡ', '86', 'ΣΥΝΤΑΓΜΑΤ'],
#              'ΔΕΥΤΕΡ': ['ΡΥΘΜΙΣ', 'ΚΑΝΟΝΙΣΜ', 'ΒΟΥΛ'],
#              'ΤΟΝΙΣ': ['ΚΑΝΟΝΙΣΜ', 'ΒΟΥΛ', 'ΔΕΥΤΕΡ'],
#              'ΤΕΛΕΥΤΑΙ': ['ΒΟΥΛ', 'ΔΕΥΤΕΡ', 'ΤΟΝΙΣ'],
#              'ΔΙΑΛΥΘΕΙΣ': ['ΤΕΛΕΥΤΑΙ', 'ΣΧΕΤΙΚ', 'ΣΥΝΕΔΡΙΑΣ'],
#              'ΕΚΠΡΟΣΩΠ': ['ΔΙΑΛΥΘΕΙΣ', 'ΒΟΥΛ', 'ΚΟΙΝΟΒΟΥΛΕΥΤΙΚ'],
#              'ΣΥΝΔΡΑΜΟΥΜ': ['ΒΟΥΛ', 'ΚΟΙΝΟΒΟΥΛΕΥΤΙΚ', 'ΕΚΠΡΟΣΩΠ'],
#              'ΠΛΗΡ': ['ΣΥΝΔΡΑΜΟΥΜ',
#               'ΔΥΝΑΜ',
#               'ΒΟΥΛ',
#               'ΠΡΟΣΒΛΕΠΟΥΜ',
#               'ΠΑΜΨΗΦΙ',
#               'ΒΟΥΛ'],
#              'ΔΙΕΛΕΥΚΑΝΣ': ['ΔΥΝΑΜ', 'ΒΟΥΛ', 'ΠΛΗΡ'],
#              'μ`': ['ΝΟΜ', 'ΕΥΘΥΝ', 'ΥΠΟΥΡΓ'],
#              'ΕΠΙΦΑΝΕΙ': ['ΤΡΟΠ', 'ΑΛΛΩΣΤΕ', 'ΕΛΘ'],
#              'ΕΝΟΧ': ['ΕΛΘ', 'ΕΠΙΦΑΝΕΙ', 'ΠΡΑΓΜΑΤΙΚ'],
#              'ΑΝΕΞΑΡΤΗΤ': ['ΠΡΑΓΜΑΤΙΚ', 'ΕΝΟΧ', 'ΒΡΙΣΚΟΝΤΑ'],
#              'ΤΙΤΛ': ['ΕΝΟΧ', 'ΒΡΙΣΚΟΝΤΑ', 'ΑΝΕΞΑΡΤΗΤ'],
#              'ΑΞΙΩΜΑΤ': ['ΒΡΙΣΚΟΝΤΑ', 'ΑΝΕΞΑΡΤΗΤ', 'ΤΙΤΛ'],
#              'ΤΡΙΤ': ['ΑΝΕΞΑΡΤΗΤ', 'ΤΙΤΛ', 'ΑΞΙΩΜΑΤ'],
#              'ΒΕΒΑΙ': ['ΑΞΙΩΜΑΤ', 'ΤΡΙΤ', 'ΚΑΘΑΡΣ'],
#              'προϋποθετει': ['ΤΡΙΤ',
#               'ΚΑΘΑΡΣ',
#               'ΒΕΒΑΙ',
#               'ΚΑΤΗΓΟΡΙ',
#               'ΤΕΤΑΡΤ',
#               'ΚΑΘΑΡΣ'],
#              'ΕΚΔΟΣ': ['ΚΑΘΑΡΣ', 'ΒΕΒΑΙ', 'προϋποθετει'],
#              'ΑΠΟΦΑΣΕ': ['ΒΕΒΑΙ', 'προϋποθετει', 'ΕΚΔΟΣ'],
#              'ΕΙΔΙΚ': ['προϋποθετει', 'ΕΚΔΟΣ', 'ΑΠΟΦΑΣΕ'],
#              'ΔΙΚΑΣΤΗΡΙ': ['ΕΚΔΟΣ', 'ΑΠΟΦΑΣΕ', 'ΕΙΔΙΚ'],
#              'ΣΥΜΜΑΧΙΚ': ['ΕΙΔΙΚ', 'ΔΙΚΑΣΤΗΡΙ', 'ΚΟΜΜΑΤΙΚ'],
#              'ΑΠΛ': ['ΚΟΜΜΑΤΙΚ',
#               'ΣΥΜΜΑΧΙΚ',
#               'ΠΛΕΙΟΨΗΦΙ',
#               'ΛΟΓ',
#               'ΟΛΟΚΛΗΡΩΣ',
#               'ΚΑΘΑΡΣ'],
#              'ΕΚΤΟΞΕΥΣ': ['ΣΥΜΜΑΧΙΚ', 'ΠΛΕΙΟΨΗΦΙ', 'ΑΠΛ'],
#              'ΤΕΤΑΡΤ': ['ΑΠΛ', 'ΕΚΤΟΞΕΥΣ', 'ΚΑΤΗΓΟΡΙ'],
#              'ΚΑΤΟΧΥΡΩΣ': ['ΚΑΘΑΡΣ', 'προϋποθετει', 'ΝΟΜΟΘΕΤΙΚ'],
#              'ΕΝΙΣΧΥΣ': ['προϋποθετει', 'ΝΟΜΟΘΕΤΙΚ', 'ΚΑΤΟΧΥΡΩΣ'],
#              'ΚΟΙΝΩΝΙΚ': ['ΚΑΤΟΧΥΡΩΣ', 'ΕΝΙΣΧΥΣ', 'ΘΕΣΜ'],
#              'ΕΛΕΓΧ': ['ΕΝΙΣΧΥΣ',
#               'ΘΕΣΜ',
#               'ΚΟΙΝΩΝΙΚ',
#               'ΕΞΕΤΑΣΤΙΚ',
#               'ΠΡΑΓΜΑΤ',
#               'ΕΠΙΤΡΟΠ',
#               'ΠΡΩΤΟΒΟΥΛΙ',
#               'ΑΥΣΤΗΡ',
#               'ΑΜΕΣ'],
#              'ΔΙΑΦΑΝΕΙ': ['ΘΕΣΜ',
#               'ΚΟΙΝΩΝΙΚ',
#               'ΕΛΕΓΧ',
#               'ΚΟΣΜ',
#               'ΠΟΛΙΤΙΚ',
#               'ΕΥΘΥΝ'],
#              'ΠΕΜΠΤ': ['ΚΟΙΝΩΝΙΚ', 'ΕΛΕΓΧ', 'ΔΙΑΦΑΝΕΙ'],
#              'ΠΑΡΟΥΜ': ['ΕΛΕΓΧ',
#               'ΔΙΑΦΑΝΕΙ',
#               'ΠΕΜΠΤ',
#               'ΑΠΟΔΕΙΞ',
#               'ΑΘΩΟΤΗΤ',
#               'ΕΒΔΟΜ'],
#              'ΠΡΩΤΟΒΟΥΛΙ': ['ΔΙΑΦΑΝΕΙ',
#               'ΠΕΜΠΤ',
#               'ΠΑΡΟΥΜ',
#               'ΑΘΩΟΤΗΤ',
#               'ΕΒΔΟΜ',
#               'ΠΑΡΟΥΜ'],
#              'ΣΥΝΤΕΛΕΣΘ': ['ΠΕΜΠΤ', 'ΠΑΡΟΥΜ', 'ΠΡΩΤΟΒΟΥΛΙ'],
#              'ΠΑΡΑΓΡΑΦ': ['ΠΑΡΟΥΜ',
#               'ΠΡΩΤΟΒΟΥΛΙ',
#               'ΣΥΝΤΕΛΕΣΘ',
#               'ΕΠΙΧΕΙΡΗΜ',
#               'ΑΔΙΚΗΜΑΤ',
#               '1974',
#               'ΔΙΑΦΑΝΕΙ',
#               'ΒΑΣ',
#               'ΑΛΛΩΣΤΕ'],
#              'κι`': ['ΠΡΩΤΟΒΟΥΛΙ', 'ΣΥΝΤΕΛΕΣΘ', 'ΠΑΡΑΓΡΑΦ'],
#              'ΔΕΙΓΜΑΤ': ['ΠΑΡΑΓΡΑΦ', 'κι`', 'ΓΙΑΤΙ'],
#              'ΓΡΑΦ': ['κι`', 'ΓΙΑΤΙ', 'ΔΕΙΓΜΑΤ'],
#              'ΔΙΚΟΜΜΑΤΙΚ': ['ΓΙΑΤΙ', 'ΔΕΙΓΜΑΤ', 'ΓΡΑΦ'],
#              'ΔΙΕΥΘΥΝΤΗΡΙ': ['ΔΕΙΓΜΑΤ', 'ΓΡΑΦ', 'ΔΙΚΟΜΜΑΤΙΚ'],
#              'ΣΥΓΚΥΒΕΡΝΗΣ': ['ΓΡΑΦ', 'ΔΙΚΟΜΜΑΤΙΚ', 'ΔΙΕΥΘΥΝΤΗΡΙ'],
#              'ΟΔΗΓ': ['ΔΙΚΟΜΜΑΤΙΚ', 'ΔΙΕΥΘΥΝΤΗΡΙ', 'ΣΥΓΚΥΒΕΡΝΗΣ'],
#              'ΣΥΜΠΕΡΑΣΜ': ['ΔΙΕΥΘΥΝΤΗΡΙ', 'ΣΥΓΚΥΒΕΡΝΗΣ', 'ΟΔΗΓ'],
#              'ΕΝΝΟ': ['ΣΥΓΚΥΒΕΡΝΗΣ', 'ΟΔΗΓ', 'ΣΥΜΠΕΡΑΣΜ'],
#              'ΔΙΑΦΟΡ': ['ΟΔΗΓ', 'ΣΥΜΠΕΡΑΣΜ', 'ΕΝΝΟ'],
#              'ΛΟΓ': ['ΣΥΜΠΕΡΑΣΜ',
#               'ΕΝΝΟ',
#               'ΔΙΑΦΟΡ',
#               'ΕΠΙΔΙΩΚ',
#               'ΕΝΤΥΠΩΣ',
#               'ΛΑΣΠΟΜΑΧΙ'],
#              'ΟΛΟΚΛΗΡΩΣ': ['ΕΝΝΟ', 'ΔΙΑΦΟΡ', 'ΛΟΓ'],
#              'ΕΠΙΔΙΩΚ': ['ΟΛΟΚΛΗΡΩΣ', 'ΚΑΘΑΡΣ', 'ΑΠΛ'],
#              'ΕΝΤΥΠΩΣ': ['ΚΑΘΑΡΣ', 'ΑΠΛ', 'ΕΠΙΔΙΩΚ'],
#              'ΛΑΣΠΟΜΑΧΙ': ['ΑΠΛ', 'ΕΠΙΔΙΩΚ', 'ΕΝΤΥΠΩΣ'],
#              'ΣΥΜΦΕΡΟΝΤΩΝΣΕΛΙΔ': ['ΛΑΣΠΟΜΑΧΙ', 'ΛΟΓ', 'ΚΟΜΜΑΤΙΚ'],
#              '0011': ['ΛΟΓ', 'ΚΟΜΜΑΤΙΚ', 'ΣΥΜΦΕΡΟΝΤΩΝΣΕΛΙΔ'],
#              'ΕΚΤ': ['ΚΟΜΜΑΤΙΚ', 'ΣΥΜΦΕΡΟΝΤΩΝΣΕΛΙΔ', '0011'],
#              'ΕΠΑΝΑΚΑΤΑΘΕΤΟΥΜ': ['ΣΥΜΦΕΡΟΝΤΩΝΣΕΛΙΔ', '0011', 'ΕΚΤ'],
#              'ΣΥΓΚΡΟΤΗΣ': ['ΕΚΤ', 'ΕΠΑΝΑΚΑΤΑΘΕΤΟΥΜ', 'ΠΡΟΤΑΣ'],
#              'ΕΞΕΤΑΣΤΙΚ': ['ΕΠΑΝΑΚΑΤΑΘΕΤΟΥΜ', 'ΠΡΟΤΑΣ', 'ΣΥΓΚΡΟΤΗΣ'],
#              'ΠΡΑΓΜΑΤ': ['ΠΡΟΤΑΣ', 'ΣΥΓΚΡΟΤΗΣ', 'ΕΞΕΤΑΣΤΙΚ'],
#              'ΕΠΙΤΡΟΠ': ['ΣΥΓΚΡΟΤΗΣ', 'ΕΞΕΤΑΣΤΙΚ', 'ΠΡΑΓΜΑΤ'],
#              'ΠΡΟΜΗΘΕΙ': ['ΠΡΑΓΜΑΤ', 'ΕΠΙΤΡΟΠ', 'ΕΛΕΓΧ'],
#              'ΕΝΟΠΛ': ['ΕΠΙΤΡΟΠ', 'ΕΛΕΓΧ', 'ΠΡΟΜΗΘΕΙ'],
#              'ΔΥΝΑΜΕ': ['ΕΛΕΓΧ', 'ΠΡΟΜΗΘΕΙ', 'ΕΝΟΠΛ'],
#              '1974': ['ΠΡΟΜΗΘΕΙ',
#               'ΕΝΟΠΛ',
#               'ΔΥΝΑΜΕ',
#               '1974',
#               'ΕΠΙΧΕΙΡΗΜ',
#               'ΑΔΙΚΗΜΑΤ'],
#              'ΕΠΙΧΕΙΡΗΜ': ['ΕΝΟΠΛ', 'ΔΥΝΑΜΕ', '1974'],
#              'ΑΔΙΚΗΜΑΤ': ['ΔΥΝΑΜΕ', '1974', 'ΕΠΙΧΕΙΡΗΜ'],
#              'ΕΝΔΙΑΦΕΡ': ['ΠΑΡΑΓΡΑΦ', 'ΣΗΜΑΣΙ', 'ΓΙΑΤΙ'],
#              'ΚΟΣΜ': ['ΕΝΔΙΑΦΕΡ', 'ΛΑ', 'ΠΟΛΙΤΙΚ'],
#              'ΒΑΣ': ['ΠΟΛΙΤΙΚ', 'ΕΥΘΥΝ', 'ΔΙΑΦΑΝΕΙ'],
#              'ΘΙΓΟΜΕΝ': ['ΑΡΘΡ', '86', 'ΣΥΝΤΑΓΜΑΤ'],
#              'ΖΗΤΗΣ': ['ΣΥΝΤΑΓΜΑΤ', 'ΘΙΓΟΜΕΝ', 'ΠΟΛΙΤΙΚ'],
#              'ΠΑΡΑΠΟΜΠ': ['ΘΙΓΟΜΕΝ', 'ΠΟΛΙΤΙΚ', 'ΖΗΤΗΣ'],
#              'ΑΠΟΔΕΙΞ': ['ΠΟΛΙΤΙΚ', 'ΖΗΤΗΣ', 'ΠΑΡΑΠΟΜΠ'],
#              'ΑΘΩΟΤΗΤ': ['ΖΗΤΗΣ', 'ΠΑΡΑΠΟΜΠ', 'ΑΠΟΔΕΙΞ'],
#              'ΕΒΔΟΜ': ['ΠΑΡΑΠΟΜΠ', 'ΑΠΟΔΕΙΞ', 'ΑΘΩΟΤΗΤ'],
#              'ΑΥΣΤΗΡ': ['ΕΒΔΟΜ', 'ΠΑΡΟΥΜ', 'ΠΡΩΤΟΒΟΥΛΙ'],
#              'ΑΜΕΣ': ['ΠΑΡΟΥΜ', 'ΠΡΩΤΟΒΟΥΛΙ', 'ΑΥΣΤΗΡ'],
#              'ΠΟΘ': ['ΑΥΣΤΗΡ', 'ΑΜΕΣ', 'ΕΛΕΓΧ'],
#              'ΕΣΧ': ['ΑΜΕΣ', 'ΕΛΕΓΧ', 'ΠΟΘ'],
#              'ΛΑΜΨ': ['ΕΛΕΓΧ', 'ΠΟΘ', 'ΕΣΧ'],
#              'ΠΡΟΣΒΛΕΠΟΥΜ': ['ΠΟΘ', 'ΕΣΧ', 'ΛΑΜΨ'],
#              'ΠΑΜΨΗΦΙ': ['ΕΣΧ', 'ΛΑΜΨ', 'ΠΡΟΣΒΛΕΠΟΥΜ'],
#              'ΔΙΑΛΕΥΚΑΝΣ': ['ΠΑΜΨΗΦΙ', 'ΒΟΥΛ', 'ΠΛΗΡ'],
#              'ΘΕΜΑΤ': ['ΒΟΥΛ', 'ΠΛΗΡ', 'ΔΙΑΛΕΥΚΑΝΣ'],
#              'ΘΙΓ': ['ΠΛΗΡ', 'ΔΙΑΛΕΥΚΑΝΣ', 'ΘΕΜΑΤ'],
#              'ΟΓΔΟ': ['ΤΙΜ', 'ΠΟΛΙΤΙΚ', 'ΠΡΟΣΩΠ'],
#              'ΠΡΟΤΕΙΝΟΥΜ': ['ΠΡΟΣΩΠ', 'ΟΓΔΟ', 'ΔΙΑΔΙΚΑΣΙ'],
#              'ΔΙΑΣΦΑΛΙΖ': ['ΟΓΔΟ', 'ΔΙΑΔΙΚΑΣΙ', 'ΠΡΟΤΕΙΝΟΥΜ'],
#              'ΕΝΟΤΗΤ': ['ΔΙΑΔΙΚΑΣΙ', 'ΠΡΟΤΕΙΝΟΥΜ', 'ΔΙΑΣΦΑΛΙΖ'],
#              'ΘΕΜ': ['ΠΡΟΤΕΙΝΟΥΜ', 'ΔΙΑΣΦΑΛΙΖ', 'ΕΝΟΤΗΤ'],
#              'ΑΠΟΤΡΕΠ': ['ΕΝΟΤΗΤ', 'ΘΕΜ', 'ΚΑΘΑΡΣ'],
#              'ΜΙΣΑΛΛΟΔΟΞΙ': ['ΘΕΜ', 'ΚΑΘΑΡΣ', 'ΑΠΟΤΡΕΠ'],
#              'ΡΕΒΑΝΣΙΣΜ': ['ΚΑΘΑΡΣ', 'ΑΠΟΤΡΕΠ', 'ΜΙΣΑΛΛΟΔΟΞΙ'],
#              'ΜΕΛΛΟΝ': ['ΑΠΟΤΡΕΠ', 'ΜΙΣΑΛΛΟΔΟΞΙ', 'ΡΕΒΑΝΣΙΣΜ'],
#              'ΤΕΛ': ['ΡΕΒΑΝΣΙΣΜ', 'ΜΕΛΛΟΝ', 'ΔΗΛΩΝΟΥΜ'],
#              'ΣΥΜΒ': ['ΜΕΛΛΟΝ', 'ΔΗΛΩΝΟΥΜ', 'ΤΕΛ'],
#              'ΥΠΕΥΘΥΝ': ['ΤΕΛ', 'ΣΥΜΒ', 'ΚΥΒΕΡΝΗΣ'],
#              'ΑΚΥΒΕΡΝΗΣΙ': ['ΣΥΜΒ', 'ΚΥΒΕΡΝΗΣ', 'ΥΠΕΥΘΥΝ'],
#              'ΣΥΓΚΑΛΥΨ': ['ΚΥΒΕΡΝΗΣ', 'ΥΠΕΥΘΥΝ', 'ΑΚΥΒΕΡΝΗΣΙ'],
#              'πασοκ~': ['ΣΥΓΚΑΛΥΨ', 'ΕΥΘΥΝ', 'ΠΡΟΕΔΡ']})
